# %%
# Import packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import pymongo
import pickle
import string
import nltk
import re
import os
import sys
from fuzzywuzzy import fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
import warnings
warnings.filterwarnings('ignore')



src_dir = os.path.join(os.getcwd(), '..', '..', 'src')
sys.path.append(src_dir)

# helper functions
from d02_processing.cleaning_signatures import sorted_signatures
from d02_processing.cleaning_signatures import cleaned_signatures
from d01_utils.mongo_cursor_creator import mongo_cursor

# Load the "autoreload" extension
# %load_ext autoreload

# reload modules so that as you change code in src, it gets loaded
# %autoreload

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load relevant data

# %%
df = pd.read_csv('../../data/02_intermediate/no_nan_curl_pattern_df.csv')
df.drop(columns=['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#   curl_pattern density porosity texture  \
# 0           2b     NaN      NaN  coarse
# 1           3b   thick      NaN     NaN
# 2           4a     NaN      NaN     NaN
# 3           3a     NaN      NaN     NaN
# 4           3b     NaN      NaN     NaN
#
#                                             products  curl_catagory
# 0  poo deva nopoo co wash suave naturals rinse ou...              2
# 1  since feb 09 currently using low poo tj s nour...              5
# 2  deeplyenrichedoils com show me some love check...              7
# 3  hair type and lots of it hair color ranges fro...              4
# 4  hair type and lots of it hair color ranges fro...              5

# %%
with open('../../data/02_intermediate/Ulta_products.pkl', 'rb') as f:
    ulta = pickle.load(f)
ulta[:5]
# Out:
# ['Redken All Soft Conditioner',
#  'Paul Mitchell Tea Tree Special Shampoo',
#  'Redken All Soft Shampoo',
#  'Matrix Biolage Colorlast Conditioner',
#  'Matrix Biolage Colorlast Shampoo']

# %%
with open('../../data/02_intermediate/Giovanni_products.pkl', 'rb') as f:
    giovanni = pickle.load(f)
giovanni[:5]
# Out:
# ['giovanni tea tree triple treat invigorating shampoo ',
#  'giovanni tea tree triple treat invigorating conditioner ',
#  'giovanni smooth as silk deep moisture shampoo ',
#  'giovanni smooth as silk deeper moisture conditioner ',
#  'giovanni 5050 balanced hydratingclarifying shampoo ']

# %%
with open('../../data/02_intermediate/jessicurl_products_full_name.pkl', 'rb') as f:
    jessicurl = pickle.load(f)
jessicurl[:5]
# Out:
# ['jessicurl gentle lather shampoo',
#  'jessicurl hair cleansing cream',
#  'jessicurl aloeba daily conditioner',
#  'jessicurl deep treatment',
#  'jessicurl too shea extra moisturizing conditioner']

# %%
with open('../../data/02_intermediate/kinky_curly_products.pkl', 'rb') as f:
    kinky_curly = pickle.load(f)
kinky_curly[:5]
# Out:
# ['kinky curly seriously smooth prep protect',
#  'kinky curly seriously smooth swift set lotion',
#  'kinky curly seriously smooth fast dry foam',
#  'kinky curly knot today',
#  'kinky curly curling custard']

# %%
with open('../../data/02_intermediate/other_products.pkl', 'rb') as f:
    other_products = pickle.load(f)
other_products[:5]
# Out:
# ['LA Looks Sport Look Gel',
#  'TRESemmé Botanique Nourish and Replenish Conditioner',
#  'As I Am Coconut Co-wash',
#  'Yes to Carrots Nourishing Shampoo',
#  'LOreal EverCreme Cleansing Conditioner']

# %%
product_list_full = ulta + giovanni + jessicurl + kinky_curly + other_products
product_list_full
# Out:
# ['Redken All Soft Conditioner',
#  'Paul Mitchell Tea Tree Special Shampoo',
#  'Redken All Soft Shampoo',
#  'Matrix Biolage Colorlast Conditioner',
#  'Matrix Biolage Colorlast Shampoo',
#  'Paul Mitchell Tea Tree Lavender Mint Moisturizing Conditioner',
#  'Paul Mitchell Tea Tree Lavender Mint Moisturizing Shampoo',
#  'Matrix Biolage Ultra Hydrasource Conditioner',
#  'Redken Color Extend Magnetics Shampoo',
#  'Pureology Hydrate Conditioner',
#  'Pureology Hydrate Shampoo',
#  'Redken Color Extend Blondage Color Depositing Purple Shampoo',
#  'Redken Color Extend Shampoo',
#  'Redken Color Extend Magnetics Conditioner',
#  'Redken Extreme Conditioner',
#  'Joico Color Balance Purple Shampoo',
#  'Redken Color Extend Conditioner',
#  'Paul Mitchell Tea Tree Special Conditioner',
#  'Redken Extreme Shampoo',
#  'AG Hair Moisture Fast Food Leave-On Conditioner',
#  'Redken Color Extend Blondage Color Depositing Purple Conditioner',
#  'Matrix Biolage Hydrasource Shampoo',
#  "It's A 10 Miracle Deep Conditioner Plus Keratin",
#  'AG Hair Jumbo Pump',
#  'Redken Frizz Dismiss Sufate-Free Conditioner',
#  'Joico Color Balance Purple Conditioner',
#  'Matrix Biolage Ultra Hydrasource Shampoo',
#  'Redken All Soft Mega Conditioner',
#  'Redken Frizz Dismiss Sulfate-Free Shampoo',
#  'Matrix Biolage Advanced Keratindose Conditioner for Overprocessed Hair',
#  'Sebastian Drench Conditioner',
#  'Matrix Biolage Volumebloom Shampoo',
#  'Joico K-PAK Color Therapy Conditioner',
#  'Wella Fusionplex Shampoo',
#  'Wella Fusionplex Conditioner',
#  'Joico K-PAK Color Therapy Shampoo',
#  'Sebastian Drench Shampoo',
#  'Redken Nature + Science All Soft Conditioner For Dry/Brittle Hair',
#  'Redken Nature + Science All Soft Shampoo For Dry/Brittle Hair',
#  'Matrix Biolage Volumebloom Conditioner',
#  'Paul Mitchell Tea Tree Scalp Care Anti-Thinning Shampoo',
#  'AG Hair Colour Care Colour Savour Sulfate-Free Shampoo',
#  'Matrix Biolage Advanced Keratindose Shampoo for Overprocessed Hair',
#  'Matrix Total Results Mega Sleek Conditioner',
#  'Matrix Biolage Scalpsync Anti-Dandruff Shampoo',
#  'Living Proof Perfect hair Day (PhD) Dry Shampoo',
#  'Drybar The Blowout Brigade Set',
#  'Paul Mitchell Tea Tree Lemon Sage Thickening Shampoo',
#  'Redken All Soft Mega Shampoo',
#  'Matrix Total Results Brass Off Shampoo',
#  'Redken Clean Maniac Hair Cleansing Cream Clarifying Shampoo',
#  'AG Hair Colour Care Colour Savour Colour Protection Conditioner',
#  'Matrix Total Results Mega Sleek Shampoo',
#  'Paul Mitchell Tea Tree Special Color Shampoo',
#  "It's A 10 Miracle Shampoo Plus Keratin",
#  "It's A 10 Miracle Daily Conditioner",
#  'Nexxus Humectress Moisture Conditioner for Normal to Dry Hair',
#  'Joico Moisture Recovery Conditioner',
#  'Redken High Rise Volume Lifting Shampoo',
#  'Redken Clear Moisture Hydrating Shampoo',
#  'Sebastian Penetraitt Conditioner',
#  'American Crew 3-In-1 Shampoo, Conditioner and Body Wash',
#  'Paul Mitchell Tea Tree Scalp Care Anti-Thinning Conditioner',
#  'Matrix Biolage Normalizing Cleanreset Shampoo',
#  'Redken Clear Moisture Hydrating Conditioner',
#  'Hempz Sweet Pineapple & Honey Melon Herbal Volumizing Shampoo',
#  'Wella Invigo Brilliance Shampoo For Fine Hair',
#  'AG Hair Keratin Repair Restore Daily Strengthening Conditioner',
#  'Wella Invigo Brilliance Conditioner For Fine Hair',
#  'Matrix Biolage Hydrasource Detangling Solution',
#  'Pureology Hydrate Sheer Shampoo',
#  'Paul Mitchell Tea Tree Special Color Conditioner',
#  'Matrix Scalpsync Conditioner',
#  'Paul Mitchell Tea Tree Lemon Sage Thickening Conditioner',
#  'Nioxin Cleanser Shampoo System 2 For Fine Hair With Progressed Thinning',
#  'Pureology Hydrate Sheer Condition',
#  'Sebastian Penetraitt Shampoo',
#  'Matrix Biolage Advanced Fiberstrong Conditioner for Fragile Hair',
#  'Joico Moisture Recovery Shampoo',
#  'Matrix Total Results So Silver Shampoo',
#  'AG Hair Keratin Repair Refuel Sulfate-Free Strengthening Shampoo',
#  'DevaCurl One Condition Original Daily Cream Conditioner',
#  'Matrix Biolage Advanced Full Density Shampoo for Thin Hair',
#  'Nioxin Scalp Therapy Conditioner, System 4 (Color Treated Hair/Progressed Thinning)',
#  'Hempz Sweet Pineapple & Honey Melon Herbal Volumizing Conditioner',
#  'Nioxin Cleanser Shampoo, System 4 (Color Treated Hair/ Progressed Thinning)',
#  'Redken High Rise Volume Lifting Conditioner',
#  'Matrix Biolage ColorLast Purple Shampoo',
#  'Tigi Bed Head Urban Antidotes Resurrection Conditioner',
#  'Alterna Caviar Anti-Aging Replenishing Moisture Conditioner',
#  'Alterna Caviar Anti-Aging Replenishing Moisture Shampoo',
#  'Matrix Total Results Brass Off Conditioner',
#  'Tigi Bed Head Urban Antidotes Recovery Conditioner',
#  'Living Proof Online Only No Frizz Favorites Jumbo Bundle',
#  'Tigi Bed Head Urban Antidotes Recovery Shampoo',
#  'Pureology Strength Cure Conditioner',
#  'Hempz Original Herbal Conditioner for Damaged & Color Treated Hair',
#  "It's A 10 Silk Express Miracle Silk Shampoo",
#  'Matrix Biolage Advanced Fiberstrong Shampoo for Fragile Hair',
#  'Pureology Strength Cure Shampoo',
#  'Nioxin Scalp Therapy Conditioner System 2 For Fine Hair With Progressed Thinning',
#  'Kenra Professional Platinum Luxe Shine Conditioner',
#  'Hempz Original Herbal Shampoo for Damaged & Color Treated Hair',
#  'Matrix Biolage Advanced Full Density Conditioner for Thin Hair',
#  'DevaCurl One Condition Decadence Ultra Moisturizing Milk Conditioner',
#  'Kenra Professional Platinum Color Charge Shampoo',
#  'Kenra Professional Platinum Thickening Shampoo',
#  'Paul Mitchell Original Awapuhi Shampoo',
#  'Tigi Bed Head Urban Antidotes Resurrection Shampoo',
#  'Nioxin Scalp Recovery Cleanser',
#  'Hempz Pomegranate Daily Herbal Moisturizing Shampoo',
#  'Hempz Triple Moisture Rich Herbal Whipped Crème Conditioner & Hair Mask',
#  'AG Hair Sleeek Argan & Coconut Conditioner',
#  'American Crew 3-in-1 Tea Tree Shampoo, Conditioner and Body Wash',
#  'Matrix Biolage Smoothproof Conditioner',
#  'dpHUE Apple Cider Vinegar Hair Rinse',
#  'Batiste Original Dry Shampoo - Clean & Classic',
#  'Hempz Pomegranate Daily Herbal Moisturizing Conditioner',
#  'Redken Curvaceous Conditioner',
#  'Pureology Smooth Perfection Shampoo',
#  'Kenra Professional Volumizing Shampoo',
#  'DevaCurl No-Poo Original Zero Lather Conditioning Cleanser',
#  'AG Hair Smooth Smoooth Sulfate-Free Argan & Coconut Shampoo',
#  'Kenra Professional Platinum Color Charge Conditioner',
#  'Pureology Smooth Perfection Conditioner',
#  'Nexxus Therappe Repleneshing System Shampoo for Normal to Dry Hair',
#  'Matrix Total Results High Amplify Shampoo',
#  'Kenra Professional Platinum Thickening Conditioner',
#  'Wella Invigo Nutri-Enrich Conditioner',
#  'Kenra Professional Platinum Luxe Shine Shampoo',
#  'AG Hair Colour Care Sterling Silver Toning Shampoo',
#  'Sexy Hair Big Sexy Hair Volumizing Conditioner',
#  'Curlsmith Curl Quenching Conditioning Wash',
#  'Matrix Total Results So Long Damage Conditioner',
#  'Kenra Professional Moisturizing Conditioner',
#  'AG Hair Moisture Fast Food Sulfate-Free Shampoo',
#  'Paul Mitchell Original The Conditioner',
#  'Pureology Strength Cure Best Blonde Purple Shampoo',
#  'Sexy Hair Big Sexy Hair Extra Volumizing Shampoo',
#  'Matrix Biolage Scalpsync Cooling Mint Shampoo',
#  'Keracolor Online Only Color + Clenditioner Liter',
#  'Sexy Hair Smooth Sexy Hair Smoothing Conditioner',
#  'Matrix Biolage Smoothproof Shampoo',
#  'Matrix Total Results So Long Damage Shampoo',
#  'Pureology Strength Cure Best Blonde Purple Conditioner',
#  'Keratin Complex Smoothing Therapy Keratin Color Care Conditioner',
#  'Kenra Professional Moisturizing Shampoo',
#  'Joico Color Balance Blue Shampoo',
#  'Nioxin Cleanser Shampoo, System 3 (Color Treated Hair/Normal to Light Thinning)',
#  'Wella Invigo Nutri-Enrich Shampoo',
#  'Matrix Total Results Keep Me Vivid Sulfate-Free Shampoo',
#  'Nexxus Color Assure Conditioner for Color Treated Hair',
#  'Joico K-PAK Conditioner',
#  'Paul Mitchell Super Strong Conditioner',
#  'Kenra Professional Color Maintenance Shampoo',
#  'Sexy Hair Healthy Sexy Hair Moisturizing Shampoo',
#  'Drybar Limited Edition Detox Dry Shampoo Coconut Colada Scent',
#  'Keratin Complex Smoothing Therapy Keratin Color Care Shampoo',
#  'Nioxin Scalp Therapy Conditioner, System 3 (Color Treated Hair/Normal to Light Thinning)',
#  'Hempz Online Only Herbal Healthy Hair Fortifying Shampoo',
#  'Tigi Bed Head Colour Goddess Oil Infused Conditioner',
#  'AG Hair Colour Care Sterling Silver Toning Conditioner',
#  'Sexy Hair Healthy Sexy Hair Moisturizing Conditioner',
#  'Matrix Total Results So Silver Conditioner for Blonde and Silver Hair',
#  'Fairy Tales Rosemary Repel Shampoo',
#  'Tigi Bed Head Urban Antidotes Re-Energize Shampoo',
#  "It's A 10 Miracle Moisture Shampoo",
#  'Joico K-PAK Shampoo',
#  "It's A 10 Silk Express Miracle Silk Conditioner",
#  'AG Hair Natural Balance Apple Cider Vinegar Sulfate-Free Shampoo',
#  'Sexy Hair Strong Sexy Hair Strengthening Shampoo',
#  'Matrix Total Results High Amplify Conditioner',
#  'Wella Invigo Brilliance Conditioner For Coarse Hair',
#  'Redken Damage Control Kit',
#  'Drybar Detox Dry Shampoo',
#  'Sebastian Volupt Shampoo',
#  'Redken Color Extend Color Depositing Graydiant Shampoo',
#  'Kenra Professional Volumizing Conditioner',
#  'Tigi Bed Head Colour Goddess Oil Infused Shampoo',
#  'Sexy Hair Blonde Sexy Hair Bombshell Blonde Conditioner Daily Color Preserving Conditioner',
#  'AG Hair Natural Boost Apple Cider Vinegar Conditioner',
#  "It's A 10 Potion 10 Miracle Repair Shampoo",
#  'Nioxin Scalp Recovery Moisturizing Conditioner',
#  'Sexy Hair Strong Sexy Hair Strengthening Conditioner',
#  'Matrix Biolage ExquisiteOil Crème Conditioner',
#  'Nexxus Keraphix Conditioner for Damaged Hair',
#  'Ouidad Curl Quencher Moisturizing Conditioner',
#  'Sexy Hair Smooth Sexy Hair Smoothing Shampoo',
#  'Wella Elements Lightweight Renewing Conditioner',
#  'Tigi Bed Head Urban Antidotes Re-Energize Conditioner',
#  'Living Proof Perfect hair Day (PhD) Shampoo',
#  'DevaCurl Online Only Double Take Curly Hair Kit',
#  'Matrix Total Results Keep Me Vivid Conditioner',
#  'Tigi Bed Head Rockaholic Dirty Secret Dry Shampoo',
#  'Wella Elements Renewing Shampoo',
#  'Hempz Online Only Herbal Healthy Hair Fortifying Conditioner',
#  'AG Hair Curl Thrive Hydrating Conditioner',
#  'Tigi Bed Head Dumb Blonde Shampoo',
#  'Batiste Hint of Color Dry Shampoo - Beautiful Brunette',
#  'Paul Mitchell Original The Detangler',
#  'Sexy Hair Vibrant Sexy Hair Color Lock Shampoo',
#  'Kenra Professional Platinum Detox and Deflect Daily Shampoo',
#  'Shimmer Lights Shimmer Lights Purple Shampoo for Blonde & Silver Hair',
#  'Sexy Hair Blonde Sexy Hair Bright Blonde Shampoo Violet Shampoo for Blonde',
#  'Matrix Total Results Hello Blondie Conditioner',
#  'Redken Color Extend Color Depositing Graydiant Conditioner',
#  'DevaCurl One Condition Delight Weightless Waves Conditioner',
#  'Living Proof Full Shampoo',
#  'Sexy Hair Vibrant Sexy Hair Color Lock Conditioner',
#  'Fairy Tales Rosemary Repel Creme Conditioner',
#  'Joico Color Endure Conditioner',
#  'Joico Color Balance Blue Conditioner',
#  'Joico Color Endure Shampoo',
#  'Wella Invigo Brilliance Shampoo For Coarse Hair',
#  'DevaCurl No-Poo Decadence Zero Lather Ultra Moisturizing Milk Cleanser',
#  'Matrix Total Results Color Obsessed Conditioner',
#  'Pureology Nano Works Gold Conditioner',
#  'Macadamia Professional Weightless Moisture Shampoo',
#  'Living Proof Restore Conditioner',
#  'Matrix Total Results Color Obsessed Shampoo',
#  "Bumble and bumble Bb.Hairdresser's Invisible Oil Conditioner",
#  'Pravana The Perfect Blonde Shampoo',
#  'Kenra Professional Platinum Restorative Conditioner',
#  'Pureology Nano Works Gold Shampoo',
#  'Redken Brews 3-In-1 Shampoo, Conditioner and Body Wash',
#  'Living Proof Perfect Hair Day (PhD) Conditioner',
#  'DevaCurl Online Only Double Take Super Curly Hair Kit',
#  'Nioxin Cleanser Shampoo System 1 for Fine Hair with Light Thinning',
#  'AG Hair Volume Thikk Wash Volumizing Shampoo',
#  'AG Hair Curl Revive Sulfate-Free Hydrating Shampoo',
#  'Living Proof Restore Shampoo',
#  'Tigi Bed Head Dumb Blonde Reconstructor',
#  'Nexxus Color Assure Shampoo for Color Treated Hair',
#  'Joico Defy Damage Care Trial Kit',
#  'IGK First Class Charcoal Detox Dry Shampoo',
#  'Paul Mitchell MITCH Double Hitter 2-in-1 Shampoo & Conditioner',
#  'Matrix Total Results Moisture Me Rich Conditioner',
#  'Joico Defy Damage Protective Shampoo',
#  'Joico Defy Damage Protective Conditioner',
#  'Kenra Professional Platinum Detox and Deflect Daily Conditioner',
#  'Kenra Professional Color Maintenance Conditioner',
#  "Bumble and bumble Bb.Hairdresser's Invisible Oil Shampoo",
#  'Bumble and bumble Bb. Thickening Volume Shampoo',
#  'Macadamia Professional Weightless Moisture Conditioner',
#  'Paul Mitchell Platinum Blonde Shampoo',
#  'Sebastian Volupt Conditioner',
#  'Kenra Professional Brightening Shampoo',
#  'Philosophy Amazing Grace Perfumed Shampoo, Shower Gel & Bubble Bath',
#  'AG Hair Moisture Ultramoist Moisturizing Conditioner',
#  'Pureology Fullfyl Shampoo',
#  'Matrix Biolage HydraSource Conditioning Balm',
#  'Matrix Biolage ExquisiteOil Micro-Oil Shampoo',
#  'DevaCurl Low-Poo Original Mild Lather Cleanser',
#  'Paul Mitchell Original Shampoo One',
#  'Ouidad Advanced Climate Control Defrizzing Conditioner',
#  'Living Proof No Frizz Conditioner',
#  'Philosophy Hula Girl Shampoo, Shower Gel & Bubble Bath',
#  'Paul Mitchell Super Strong Shampoo',
#  'Matrix Total Results Hello Blondie Shampoo',
#  'Keratin Complex Timeless Color Fade-Defy Shampoo',
#  'Keratin Complex Timeless Color Fade-Defy Conditioner',
#  'Macadamia Professional Nourishing Moisture Conditioner',
#  'DevaCurl Low-Poo Delight Weightless Waves Mild Lather Cleanser',
#  'Nexxus Keraphix Damage Healing Shampoo',
#  'Kenra Professional Brightening Conditioner',
#  'Kenra Professional Platinum Restorative Shampoo',
#  'Ouidad Curl Quencher Moisturizing Shampoo',
#  'Nioxin Scalp Therapy Conditioner System 1 for Fine Hair With Light Thinning',
#  'Matrix Biolage Sugar Shine Shampoo',
#  'American Crew Daily Moisturizing Shampoo',
#  'Macadamia Professional Nourishing Moisture Shampoo',
#  'Matrix Total Results Moisture Me Rich Shampoo',
#  "It's A 10 Silk Express Miracle Silk Leave-In",
#  'Matrix Biolage Sugar Shine Conditioner',
#  'Redken Brews Daily Shampoo',
#  'Redken Scalp Relief Dandruff Control Shampoo',
#  'Living Proof Full Conditioner',
#  'Ouidad Advanced Climate Control Defrizzing Shampoo',
#  'Hask Monoi Coconut Oil Nourishing Shampoo',
#  'Tigi Bed Head Fully Loaded Massive Volume Shampoo',
#  'DevaCurl Online Only Double Take Wavy Hair Kit',
#  'Paul Mitchell Color Protect Shampoo',
#  'Living Proof No Frizz Shampoo',
#  'Pureology Fullfyl Condition',
#  'Fairy Tales Rosemary Repel Conditioning Spray',
#  'Hask Argan Oil Repairing Shampoo',
#  'Bosley BosRevive Nourishing Shampoo For Color Treated Hair',
#  'Drybar Triple Sec 3-in-1 Finishing Spray',
#  'AG Hair Volume Thikk Rinse Volumizing Conditioner',
#  'Paul Mitchell Awapuhi Wild Ginger Moisturizing Lather Shampoo',
#  'Nioxin Cleanser Shampoo, System 6 (Chemically Treated/Bleached Hair/Progressed Thinning)',
#  'Mizani Thermasmooth Anti-frizz Conditioner',
#  'Nioxin Scalp Therapy Conditioner, System 6 (Chemically Treated/Bleached Hair/Progressed Thinning)',
#  'Hask Monoi Oil Nourishing Conditioner',
#  'Hempz Online Only Blushing Grapefruit & Raspberry Crème Color Protector Shampoo',
#  'Hask Argan Oil Repairing Conditioner',
#  'dpHUE Online Only Apple Cider Vinegar Travel Trio',
#  'Paul Mitchell Color Protect Conditioner',
#  'Sexy Hair Blonde Sexy Hair Bombshell Blonde Shampoo Daily Color Preserving Shampoo',
#  'Hempz Blushing Grapefruit & Raspberry Crème Color Protector Conditioner',
#  'AG Hair Moisture Xtramoist Moisturizing Shampoo',
#  'Redken Diamond Oil Glow Dry Gloss Shampoo',
#  'Pureology Clean Volume Shampoo',
#  'Kenra Professional Snail Anti-Aging Shampoo',
#  'Bumble and bumble Bb. Thickening Volume Conditioner',
#  'Ouidad VitalCurl+ Plus Balancing Rinse Conditioner',
#  "L'anza Healing Color Care Color-Preserving Shampoo",
#  'Matrix Biolage Hydrasource Daily Leave-In Tonic',
#  "L'anza Keratin Healing Oil Conditioner",
#  "Not Your Mother's Naturals Tahitian Gardenia Flower & Mango Butter Curl Defining Conditioner",
#  'Kenra Professional Snail Anti-Aging Conditioner',
#  'Keranique Volumizing Scalp Stimulating Shampoo',
#  'American Crew Daily Conditioner',
#  'Bosley BosRevive Volumizing Conditioner For Color-Treated Hair',
#  'Sexy Hair Big Sexy Hair Volumizing Shampoo',
#  'Matrix Oil Wonders Volume Rose Conditioner For Fine Hair',
#  'Redken Brews Mint Shampoo',
#  'Kenra Professional Strengthening Conditioner',
#  'Bumble and bumble Bb.Gentle Shampoo',
#  'Bumble and bumble Bb.Super Rich Conditioner',
#  'Eva Nyc Freshen Up Dry Shampoo',
#  'AG Hair Therapy Tech Two Protein-Enriched Shampoo',
#  'Tigi Bed Head Oh Bee Hive! Matte Dry Shampoo',
#  'Ouidad VitalCurl+ Clear and Gentle Shampoo',
#  'Hempz Triple Moisture Rich Daily Herbal Replenishing Shampoo',
#  'Redken Triple Dry 15 Dry Texture Finishing Spray',
#  'DevaCurl Leave-In Decadence',
#  "Not Your Mother's Naturals Royal Honey & Kalahari Desert Melon Repair & Protect Leave-In Conditioner",
#  'Redken Diamond Oil Glow Dry Detangling Conditioner',
#  'DevaCurl Buildup Buster Micellar Water Cleansing Serum',
#  'Sexy Hair Big Sexy Hair Dry Shampoo',
#  'Sun Bum Revitalizing 3 In 1 Leave In Treatment',
#  'DevaCurl DevaFresh',
#  "L'anza Healing Color Care Color-Preserving Conditioner",
#  'DevaCurl Curls On The Go Kit',
#  'Neuma neuMoisture Condition',
#  'Hask Biotin Boost Thickening Shampoo',
#  'Bumble and bumble Bb. Pret-a-Powder Tres Invisible Dry Shampoo with French Pink Clay',
#  'Redken Brews Daily Conditioner',
#  "Not Your Mother's Curl Talk 3-in-1 Conditioner",
#  'Neuma neuVolume Shampoo',
#  'Paul Mitchell Extra-Body Shampoo',
#  "It's A 10 Potion 10 Miracle Repair Conditioner",
#  'Mizani Thermasmooth Anti-Frizz Shampoo',
#  'Bumble and bumble Bb.Hair Powder',
#  "L'anza Keratin Healing Oil Shampoo",
#  'Shimmer Lights Shimmer Lights Purple Conditioner for Blonde & Silver Hair',
#  'Paul Mitchell Clarifying Shampoo Two',
#  'Sebastian Reset Shampoo',
#  'Paul Mitchell Platinum Blonde Conditioner',
#  'Philosophy Lemon Custard Shampoo, Shower Gel & Bubble Bath',
#  "Not Your Mother's Naturals Tahitian Gardenia Flower & Mango Butter Curl Defining Shampoo",
#  'Pravana The Perfect Blonde Conditioner',
#  'Redken Pillow Proof Blow Dry Two Day Extender Dry Shampoo',
#  'OGX Biotin & Collagen Shampoo',
#  "Not Your Mother's Blue Sea Kale & Pure Coconut Water Sea Minerals Conditioner",
#  'Hask Biotin Boost Thickening Conditioner',
#  'Living Proof Travel Size Perfect Hair Day (PhD) Dry Shampoo',
#  "Not Your Mother's Clean Freak Dry Shampoo",
#  'Macadamia Professional Ultra Rich Moisture Conditioner',
#  'Nioxin Scalp Therapy Conditioner, System 5 (Chemically Treated/Bleached Hair/Normal to Light Thinning)',
#  'Unwash Bio-Cleansing Conditioner',
#  'Marc Anthony Grow Long Caffeine Ginseng Shampoo',
#  'Living Proof Perfect hair Day (PhD) Triple Detox Shampoo',
#  'Uberliss Original Bond Sustainer',
#  'Marc Anthony Grow Long Caffeine Ginseng Conditioner',
#  'Pureology Clean Volume Conditioner',
#  'dpHUE Travel Size Apple Cider Vinegar Hair Rinse',
#  'Bosley BosRevive Nourishing Shampoo For Non Color-Treated Hair',
#  "Not Your Mother's Plump For Joy Body Building Dry Shampoo",
#  'Hask Charcoal Purifying Dry Shampoo',
#  'Drybar On The Rocks Clarifying Charcoal Shampoo',
#  'Paul Mitchell Smoothing Super Skinny Shampoo',
#  'Drybar Sake Bomb Nourishing Shampoo',
#  "Not Your Mother's Activated Bamboo Charcoal & Purple Moonstone Restore & Reclaim Scalp Scrub",
#  'Alterna Caviar Anti-Aging Bond Repair Conditioner',
#  "Not Your Mother's Way to Grow Leave-In Conditioner",
#  'Living Proof Color Care Shampoo',
#  'Macadamia Professional Ultra Rich Moisture Shampoo',
#  "Not Your Mother's Blue Sea Kale & Pure Coconut Water Sea Minerals Shampoo",
#  'Kyn. Purple Shampoo',
#  'Ouidad Moisture Lock Leave-In Conditioner',
#  'Redken Curvaceous Lo-Foam Cleanser',
#  'Tigi Dumb Blonde Violet Toning Shampoo',
#  'Kenra Professional Clarifying Shampoo',
#  'Alterna Caviar Anti-Aging Bond Repair Shampoo',
#  'Paul Mitchell Extra-Body Conditioner',
#  "Not Your Mother's Curl Talk Curl Care Shampoo",
#  'IGK Hot Girls Hydrating Conditioner',
#  'Matrix Shampoo or Conditioner Liter Pump',
#  'Paul Mitchell Awapuhi Wild Ginger Moisturizing Lather Shampoo',
#  "Not Your Mother's Beach Babe Texturizing Dry Shampoo",
#  'Philosophy Fresh Cream Shampoo, Shower Gel & Bubble Bath',
#  "It's A 10 Potion 10 Miracle Instant Repair Leave-In",
#  'Drybar Sake Bomb Nourishing Conditioner',
#  'Tigi Bed Head Calma Sutra Cleansing Conditioner',
#  'Bumble and bumble Bb.Pret-A-Powder',
#  "L'anza Healing Volume Thickening Shampoo",
#  'Neuma neuVolume Condition',
#  'Keranique Volumizing Keratin Conditioner',
#  'OGX Biotin & Collagen Conditioner',
#  'Kenra Professional Strengthening Shampoo',
#  'IGK Hot Girls Hydrating Shampoo',
#  'Matrix Biolage Hydrasource Travel Kit',
#  'Nioxin Cleanser Shampoo, System 5 (Chemically Treated/Bleached Hair/Normal to Light Thinning)',
#  'Jack Black All-Over Wash',
#  'Drybar Detox Clear Invisible Dry Shampoo',
#  'Paul Mitchell Lavender Mint Moisturizing Cowash',
#  'Paul Mitchell Instant Moisture Shampoo',
#  'OGX Argan Oil of Morocco Conditioner',
#  'OGX Renewing Moroccan Argan Oil Shampoo',
#  'Pureology Style + Protect Refresh & Go Dry Shampoo',
#  'Living Proof Color Care Conditioner',
#  'Paul Mitchell MITCH Heavy Hitter Deep Cleansing Shampoo',
#  'Paul Mitchell Awapuhi Wild Ginger Keratin Cream Rinse',
#  'Bumble and bumble Online Only Bb.Seaweed Mild Marine Shampoo',
#  'Alterna Travel Size Caviar Professional Styling Sheer Dry Shampoo',
#  'Paul Mitchell Clarifying Shampoo Three',
#  'Redken Brews Extra Clean Shampoo',
#  'IGK Travel Size First Class Charcoal Detox Dry Shampoo',
#  'The One by Frederic Fekkai The Uplifting One Volume Shampoo',
#  'Jack Black Turbo Wash Energizing Cleanser',
#  'Neuma neuMoisture Shampoo',
#  'Babo Botanicals Online Only Swim & Sport Shampoo & Wash',
#  'Joico Color Infuse Red Shampoo',
#  'Keratin Complex Blondeshell Debrass Shampoo',
#  'SheaMoisture Jamaican Black Castor Oil Strengthen & Restore Shampoo',
#  'IGK Bad & Bougie Amla Oil Deep Repair Conditioner',
#  'DevaCurl Super Curly Curls On The Go Kit',
#  'OGX Nourishing Coconut Milk Conditioner',
#  'Bumble and bumble The Mega Moisture Kit',
#  'AG Hair Therapy Conditioner Light Protein-Enriched Conditioner',
#  'Sexy Hair Clean Wave Texturizing Styling Shampoo',
#  'Drybar Limited Edition Detox Dry Shampoo Coastal Cooler Scent',
#  'Philosophy Raspberry Sorbet Shampoo, Shower Gel & Bubble Bath',
#  "Not Your Mother's Matcha Green Tea & Wild Apple Blossom Nutrient Rich Conditioner",
#  "L'anza Healing Moisture Kukui Nut Conditioner",
#  'Grow Gorgeous Online Only Thinning Hair Rescue Kit',
#  'Bosley BosRevive Volumizing Conditioner For Non Color-Treated Hair',
#  'Drybar Online Only The Weekender Travel Hair Essentials',
#  'Bumble and bumble Online Only Bb.Creme De Coco Tropical-Riche Conditioner',
#  'Pureology Protect + Style Girl On-The-Go Travel Kit',
#  'Aquage SeaExtend Strengthening Conditioner',
#  'OGX Nourishing Coconut Milk Shampoo',
#  "L'anza Healing Volume Thickening Conditioner",
#  "Not Your Mother's Matcha Green Tea & Wild Apple Blossom Nutrient Rich Shampoo",
#  "L'anza Healing Moisture Tamanu Cream Shampoo",
#  'Aquage SeaExtend Silkening Conditioner',
#  'Paul Mitchell Instant Moisture Conditioner',
#  'Bumble and bumble Online Only Bb.Sunday Shampoo',
#  'SheaMoisture Coconut & Hibiscus Curl & Shine Conditioner',
#  'Matrix Biolage Hydrasource Daily Leave-In Cream',
#  'Neuma reNeu Shampoo',
#  'Bosley BosDefense Volumizing Conditioner For Color-Treated Hair',
#  "Pura d'or Hair Thinning Therapy Shampoo",
#  'Klorane Dry Shampoo with Nettle',
#  'Bumble and bumble Online Only Bb.Creme De Coco Tropical-Riche Shampoo',
#  'SheaMoisture Jamaican Black Castor Oil Strengthen & Restore Leave-In Conditioner',
#  "Not Your Mother's Way To Grow Long & Strong Shampoo",
#  "Not Your Mother's Blonde Moment Treatment Shampoo",
#  'Joico Color Infuse Red Conditioner',
#  'DevaCurl Wash Day Wonder',
#  'Drybar Blonde Ale Brightening Shampoo',
#  'Chi Infra Moisture Therapy Shampoo',
#  'Paul Mitchell Instant Moisture Awapuhi Moisture Mist',
#  'Philosophy Coconut Splash Shampoo, Shower Gel & Bubble Bath',
#  'Paul Mitchell Invisiblewear Conditioner',
#  'Pureology Strength Cure Best Blonde Girl on-the-go Mini Kit',
#  'Neuma reNeu Condition',
#  'Keratin Complex Blondeshell Debrass Conditioner',
#  'Philosophy Senorita Margarita Shampoo, Shower Gel & Bubble Bath',
#  'Alterna Caviar Anti-Aging Clinical Densifying Shampoo',
#  'Clinique CliniqueFIT Workout + Go Dry Shampoo',
#  'Kenra Professional Daily Provision',
#  'AG Hair Cleansing Cream',
#  "Not Your Mother's Knotty To Nice Conditioning Detangler",
#  'Redken Nature + Science Color Extend Sulfate Free Shampoo for Color Treated Hair',
#  "Not Your Mother's Way To Grow Long & Strong Conditioner",
#  "Not Your Mother's Clean Freak Tapioca Dry Shampoo",
#  'SheaMoisture Coconut & Hibiscus Curl & Shine Shampoo',
#  'Neuma Online Only neuSmooth Leave-On Condition',
#  'Aquage SeaExtend Silkening Shampoo',
#  'Batiste Volumizing Dry Shampoo',
#  'Wella EIMI Dry Me Dry Shampoo',
#  'Aquage SeaExtend Strengthening Shampoo',
#  'Bumble and bumble Bb. Summer Style Air Dry Set',
#  'Joico Blonde Life Brightening Shampoo',
#  'Sexy Hair Big Mini Trio',
#  'Drybar Southern Belle Volume-Boosting Powder',
#  'Batiste Travel Size Dry Shampoo',
#  'Sun Bum Revitalizing Conditioner',
#  'Philosophy Amazing Grace Dry Shampoo',
#  'The One by Frederic Fekkai The Uplifting One Volume Conditioner',
#  'IGK Bad & Bougie Amla Oil Deep Repair Shampoo',
#  'John Frieda Frizz Ease Daily Nourishment Leave-In Conditioning Spray',
#  'Sebastian Preset Conditioner',
#  "Not Your Mother's Activated Bamboo Charcoal & Purple Moonstone Restore & Reclaim Conditioner",
#  'Drybar On The Rocks Lightweight Conditioner',
#  'Matrix Biolage R.A.W. Color Care Shampoo',
#  "Not Your Mother's Activated Bamboo Charcoal & Purple Moonstone Restore & Reclaim Shampoo",
#  'Chi Keratin Leave-In Conditioner Reconstructing Treatment',
#  'John Frieda Sheer Blonde Go Blonder Lightening Shampoo',
#  'Bosley BosDefense Nourishing Shampoo For Color-Treated Hair',
#  'Hask UnWined Rosé Wine Inspired Dry Shampoo',
#  'Klorane Dry Shampoo with Oat Milk for All Hair Types - Non-Aerosol',
#  'Alterna Caviar Anti-Aging Infinite Color Hold Shampoo',
#  "L'anza Healing Strength Manuka Honey Conditioner",
#  'Ouidad Curl Recovery Whipped Curls Daily Conditioner & Styling Primer',
#  'Keranique Deep Hydration Scalp Stimulating Shampoo-For Normal to Dry Hair',
#  'Wella Invigo Blonde Recharge Cool Blonde Shampoo',
#  'Joico Blonde Life Brightening Conditioner',
#  "Not Your Mother's Naturals Royal Honey & Kalahari Desert Melon Repair & Protect Conditioner",
#  'Living Proof No Frizz Leave-In Conditioner',
#  "Not Your Mother's Naturals Coconut Milk & African Marula Tree Oil High Moisture Conditioner",
#  'Redken Nature + Science Color Extend Sulfate Free Conditioner For Color Treated Hair',
#  'Wella Oil Reflections Luminous Instant Conditioner',
#  'Naturalicious Online Only Hello Gorgeous Hair Care System (For Tight Curls & Coils)',
#  'Bumble and bumble Bb.Color Minded Shampoo',
#  'Keratin Complex Keratin Care Smoothing Conditioner',
#  'SheaMoisture Jamaican Black Castor Oil Strengthen & Restore Rinse-Out Conditioner ',
#  'AG Hair Natural Healthy Hair Styling Kit',
#  'SheaMoisture Manuka Honey & Yogurt Hydrate + Repair Shampoo',
#  "L'anza Healing Strength White Tea Shampoo",
#  'Kenra Professional Volume Dry Shampoo',
#  'Bumble and bumble Bb.Curl Custom Conditioner',
#  'Keratin Complex Keratin Care Smoothing Shampoo',
#  'Ouidad Botanical Boost Curl Energizing & Refreshing Spray',
#  'Hask UnWined By Hask Champagne Inspired Volumizing Dry Shampoo',
#  "L'anza Healing Color Care Silver Brightening Shampoo",
#  'SheaMoisture Manuka Honey & Yogurt Hydrate + Repair Conditioner',
#  'Alterna Caviar Anti-Aging Infinite Color Hold Conditioner',
#  'Alterna Caviar Anti-Aging Multiplying Volume Shampoo',
#  'Psssst! Dry Shampoo',
#  'IGK 30,000 Feet Volume Shampoo',
#  'John Frieda Sheer Blonde Go Blonder Lightening Conditioner',
#  'Chi Dry Shampoo',
#  'Keranique Color Boost Scalp Revitalizing Shampoo For Color-Treated Hair',
#  'Alterna Caviar Anti-Aging Multiplying Volume Conditioner',
#  'Bumble and bumble Online Only Bb.Seaweed Mild Marine Conditioner',
#  'Hask Coconut Dry Shampoo',
#  'Drybar Blonde Ale Brightening Conditioner',
#  'Sebastian Dry Clean Only',
#  "L'anza Healing Moisture Noni Fruit Leave-In Conditioner",
#  'Bumble and bumble Scalp Detox',
#  "Pura d'or Hair Thinning Therapy Conditioner ",
#  'Drybar Travel Size Detox Dry Shampoo',
#  'Matrix R.A.W. Color Care Conditioner',
#  'Philosophy Melon Daiquiri Shampoo, Shower Gel & Bubble Bath',
#  'Hask Charcoal Clarifying Shampoo',
#  'Wella Nutricurls Cleansing Conditioner, Gentle Cleansing Co-Wash for Waves & Curls',
#  'Matrix Biolage 3 Butter Control System Conditioner',
#  'Kenra Professional Platinum Dry Shampoo',
#  'Batiste De-Frizz Dry Shampoo',
#  "Tigi Bed Head Totally Beachin' Mellow After-Sun Conditioner",
#  'OGX Thick & Full Biotin & Collagen Shampoo',
#  'Pureology Travel Size Hydrate Conditioner',
#  'Sun Bum Revitalizing Shampoo',
#  'SheaMoisture African Water Mint & Ginger Detox & Refresh Hair & Scalp Gentle Shampoo',
#  'Kenra Professional Dandruff Shampoo',
#  'IGK All Stars Volume, Hydration And Dry Shampoo Kit',
#  'Keratin Complex Vanilla Bean Deep Conditioner',
#  'Redken Nature + Science Extreme Fortifying Shampoo for distressed hair',
#  'DevaCurl No-Comb Detangling Spray Lightweight Curl Tamer',
#  'System Professional Travel Size Silver Shampoo',
#  'Sun Bum Premium Color Enhancing Blonde Shampoo',
#  'Eva Nyc Tone It Down! Blonde Shampoo',
#  "L'anza Healing Nourish Stimulating Shampoo",
#  'Keranique The Complete Hair Regrowth System Damage Control',
#  'Sebastian Dark Oil Lightweight Conditioner',
#  "It's A 10 Miracle Volumizing Shampoo",
#  'Neuma neuSmooth Shampoo',
#  'Redken Nature + Science Extreme Fortifying Conditioner For distressed Hair',
#  'Ouidad Curl Recovery Ultra Nourishing Cleansing Oil',
#  'Pureology Travel Size Hydrate Shampoo',
#  'Wella Nutricurls Detangling Conditioner',
#  'Sebastian Dark Oil Lightweight Shampoo',
#  'The Body Shop Banana Truly Nourishing Shampoo',
#  'IGK Jet Lag Invisible Dry Shampoo',
#  'Ouidad Curl Immersion Triple Treat Deep Conditioner',
#  'Joico Travel Size Color Balance Purple Shampoo',
#  'Paul Mitchell Invisiblewear Shampoo',
#  'Wella Invigo Blonde Recharge Cool Blonde Conditioner',
#  'Chi Argan Oil Plus Moringa Oil Conditioner',
#  "L'anza Healing Smooth Glossifying Conditioner",
#  'Bumble and bumble Bb.Color Minded Conditioner',
#  'Aquage Color Protecting Shampoo',
#  "Not Your Mother's Naturals Royal Honey & Kalahari Desert Melon Repair & Protect Shampoo",
#  'The Body Shop Banana Truly Nourishing Conditioner',
#  "L'anza Healing Smooth Glossifying Shampoo",
#  'Wella Oil Reflections Luminous Reveal Shampoo',
#  'Aquage SeaExtend Volumizing Shampoo',
#  'Sun Bum Premium Color Enhancing Blonde Conditioner',
#  'Drybar Detox Dry Shampoo Lush Scent',
#  'Pravana Travel Size The Perfect Blonde Shampoo',
#  'OGX Hydrating + Teatree Mint Shampoo',
#  'AG Hair Brunette Dry Shampoo',
#  'IGK Direct Flight Multi-Tasking Matcha Dry Shampoo',
#  'dpHUE Cool Blonde Shampoo',
#  'Keranique The Complete Hair Regrowth System Color Boost',
#  'IGK 30,000 Feet Volume Conditioner',
#  'Paul Mitchell Neuro Rinse Conditioner',
#  'The One by Frederic Fekkai The Brilliant One Color Shampoo',
#  'Keranique Deep Hydration Volumizing Keratin Conditioner-For Normal to Dry Hair ',
#  'Bumble and bumble Travel Size Pret-A-Powder',
#  'Alterna Caviar Moisture Consumer Trial Kit',
#  'Sun Bum Revitalizing Dry Shampoo',
#  'Wella Nutricurls Micellar Shampoo For Curls',
#  'Keracolor Clenditioner',
#  "L'anza Healing Remedy Scalp Balancing Cleanser",
#  'Klorane Dry Shampoo with Nettle Natural Tint',
#  "Not Your Mother's Naturals Coconut Milk & African Marula Tree Oil High Moisture Shampoo",
#  'Grow Gorgeous Online Only Grow Gorgeous Repair Shampoo',
#  "Pura d'or Online Only Cleansing Conditioner",
#  'Fairy Tales Static Free Detangling Spray',
#  "Tigi Bed Head Totally Beachin' Cleansing Jelly Shampoo",
#  'Philosophy Travel Size Amazing Grace Dry Shampoo',
#  'Madison Reed Color Protecting Shampoo',
#  'Eva Nyc Mane Magic 10-in-1 Conditioner',
#  'Eva Nyc Tone It Down! Blonde Conditioner',
#  'Matrix Biolage 3 Butter Control System Shampoo',
#  "L'Oréal Hair Expertise EverPure Cleansing Balm",
#  'John Frieda Brilliant Brunette Color Deepening Conditioner',
#  'Keratin Complex Infusion Therapy Hydrating Cream Conditioner',
#  'House 99 by David Beckham Going Big Thickening Shampoo',
#  'John Frieda Brilliant Brunette Color Deepening Shampoo',
#  'The One by Frederic Fekkai One More Day Dry Shampoo',
#  'Chi Argan Oil Plus Moringa Oil Shampoo',
#  'Sun Bum Revitalizing Detox Shampoo',
#  'Keranique Damage Control Replenishing Keratin Conditioner-For Dry, Damaged Hair',
#  'Aquage Healing Conditioner',
#  'Sun Bum Curls & Waves Shampoo',
#  "Pura d'or Online Only Scalp Therapy Shampoo",
#  'Redken Color Extend Vinegar Hair Rinse',
#  'Delectable Online Only The Everything Powder',
#  'SheaMoisture  Manuka Honey & Mafura Oil Intensive Hydration Conditioner',
#  'Matrix Total Results Pro-Solutionist Alternate Action Clarifying Shampoo',
#  'Got 2b Fresh It Up Clean & Refresh Dry Shampoo',
#  'Drybar Travel Size Triple Sec 3-in-1 Finishing Spray',
#  'Matrix Biolage R.A.W. Nourish Conditioner',
#  'Alterna Bamboo Volume Abundant Volume Shampoo',
#  'Matrix Travel Size Biolage Colorlast Shampoo',
#  'SheaMoisture Raw Shea Butter Restorative Conditioner',
#  "L'anza Healing Nourish Stimulating Conditioner",
#  'Matrix Total Results The Re-Bond Conditioner',
#  'Aquage SeaExtend Volumizing Conditioner',
#  'Brite Make Me Pastel Purple Shampoo',
#  'Paul Mitchell Neuro Lather Shampoo',
#  'Matrix Travel Size Biolage Colorlast Conditioner',
#  "It's A 10 Brightening Shampoo For Blondes",
#  'Sun Bum Curls & Waves Conditioner',
#  'Grow Gorgeous Online Only Rescue & Repair Conditioner',
#  'The One by Frederic Fekkai The Brilliant One Color Conditioner',
#  'Keranique Color Boost Revitalizing Keratin Conditioner For Color-Treated Hair',
#  'Alterna Caviar Anti-Aging Restructuring Bond Repair Conditioner',
#  'American Crew Daily Shampoo',
#  "Not Your Mother's Clean Freak Dry Shampoo Unscented",
#  'Redken Travel Size Color Extend Magnetics Shampoo',
#  'Lime Crime Online Only Color Conditioner',
#  'dpHUE Apple Cider Vinegar Dry Shampoo',
#  'The Body Shop Online Only Ginger Scalp Care Shampoo',
#  'Matrix Biolage R.A.W. Scalp Care Antidandruff Shampoo',
#  'Bumble and bumble Online Only Bb.Full Potential Shampoo',
#  'Brite Make Me Pastel Purple Conditioner',
#  'Matrix Biolage R.A.W. Uplift Shampoo',
#  'OGX Thick & Full Biotin & Collagen Conditioner',
#  'OGX Coconut Miracle Oil Conditioner',
#  "Drybar Drybar x Kopari Lil' Charcoal Charmers Kit",
#  'Aquage Equalizing Detangler',
#  'IGK Low Key Cleansing Walnut Scalp Scrub',
#  'Klorane Shampoo with Centaury Shine Enhancing and Anti-Yellowing',
#  'Kyn. Perfect Conditioner',
#  'OGX Hydrating + Teatree Mint Conditioner',
#  "Kiehl's Since 1851 Amino Acid Shampoo",
#  'Matrix Total Results The Re-Bond Shampoo',
#  'Madison Reed Color Protecting Conditioner',
#  'Bumble and bumble Surf Foam Wash Shampoo',
#  "Not Your Mother's Plump For Joy Thickening Shampoo",
#  'tgin Quench 3-In-1 Cleansing Co-Wash Conditioner And Detangler',
#  'Redken Travel Size Color Extend Blondage Color Depositing Purple Shampoo',
#  'ULTA Watermelon 3-IN-1 Juice Smoothie',
#  'Paul Mitchell Travel Size Tea Tree Special Shampoo',
#  'dpHUE Cool Brunette Shampoo',
#  'Redken Travel Size Color Extend Magnetics Conditioner',
#  'Babo Botanicals Online Only Swim & Sport Conditioner',
#  'SheaMoisture Raw Shea Butter Extra-Moisture Detangler',
#  'Ouidad Curl Immersion Coconut Cleansing Cream Conditioner-No Lather',
#  'Eva Nyc Mane Magic 10-in-1 Shampoo',
#  "Not Your Mother's Passion Fruit Kombucha & Awapuhi Ginger Youth Revival Conditioner",
#  'Alterna Caviar Anti-Aging Restructuring Bond Repair Shampoo',
#  'Matrix Biolage R.A.W. Recover Shampoo',
#  'Chi Keratin Reconstructing Conditioner',
#  'Pacifica Pineapple Curls Curl Defining Shampoo',
#  'OGX Quenching Coconut Curls Conditioner',
#  'Keracolor Travel Size Color + Clenditioner',
#  'dpHUE Cool Blonde Conditioner',
#  'frank body Stimulating Scalp Scrub',
#  'Hask Keratin Protein Smoothing Deep Conditioner Packette',
#  'Paul Mitchell Travel Size Tea Tree Special Conditioner',
#  'Matrix Biolage Advanced Oil Renew Conditioner',
#  'Fairy Tales Super Charge Detangling Shampoo',
#  'TXTR. by Cantu ACV + Tea Tree Soothing Shampoo',
#  'Babo Botanicals Online Only Smoothing Conditioner',
#  'Babo Botanicals Online Only Moisturizing Baby Shampoo & Wash',
#  'Chi Aloe Vera with Agave Nectar Detangling Conditioner',
#  'Biosilk Silk Therapy Shampoo',
#  'Pacifica Pineapple Curls Curl Defining Conditioner',
#  'OGX Quenching Coconut Curls Curling Butter Leave In or Rinse Out',
#  'Psssst! Travel Size Instant Dry Shampoo Spray for Normal/Oily Hair',
#  'Matrix Biolage R.A.W. Recover Conditioner',
#  'SheaMoisture 100% Virgin Coconut Oil Daily Hydration Conditioner',
#  'Bumble and bumble Online Only Bb.Quenching Shampoo',
#  'Hask Keratin Protein Smoothing Conditioner',
#  'OGX Coconut Miracle Oil Shampoo',
#  'Hask Chia Seed Volumizing Dry Shampoo',
#  'Matrix Biolage R.A.W. Nourish Shampoo',
#  'Drybar Southern Belle Volume-Boosting Shampoo',
#  'Tigi Travel Size Bed Head Rockaholic Dirty Secret Dry Shampoo',
#  'Sexy Hair Hair Laundry Dry Shampoo',
#  'Alterna Caviar Anti-Aging Smoothing Anti-Frizz Shampoo',
#  'Bumble and bumble Online Only Bb.Quenching Conditioner',
#  'John Frieda Radiant Red Boosting Conditioner',
#  'Hair Food Honey & Apricot Sulfate Free Moisture Shampoo',
#  'Mixed Chicks Deep Conditioner',
#  'Matrix Biolage R.A.W. Uplift Conditioner',
#  'Aquage Color Protecting Conditioner',
#  'Redken Travel Size Color Extend Blondage Color Depositing Purple Conditioner',
#  'Joico Blonde Life Violet Shampoo',
#  "L'Oréal EverCreme Deep Nourish Conditoner",
#  'Drybar Detox Dry Conditioner',
#  'Ouidad PlayCurl Volumizing Conditioner',
#  "Not Your Mother's Travel Size Clean Freak Dry Shampoo",
#  'Babo Botanicals Online Only Smoothing Shampoo & Wash',
#  'SheaMoisture Raw Shea Butter Moisture Retention Shampoo',
#  'Nexxus Humectress Conditioning Mist for Normal to Dry Hair',
#  'Grow Gorgeous Online Only Hair Density Conditioner Intense',
#  'Fairy Tales Super Charge Detangling Conditioner',
#  "Not Your Mother's Plump For Joy Thickening Conditioner",
#  'Brite Make Me Pastel Pink Conditioner',
#  'Tigi Bed Head for Men Daily Clean Up Shampoo',
#  'Sexy Hair Curl Enhancing Conditioner',
#  'Nexxus Emergencée Conditioner for Weak and Damaged Hair',
#  'Ouidad Water Works Clarifying Shampoo',
#  'Living Proof Travel Size Perfect Hair Day (PhD) Shampoo',
#  'SheaMoisture 100% Virgin Coconut Oil Daily Hydration Shampoo',
#  'SheaMoisture Manuka Honey & Mafura Oil Intensive Hydration Shampoo',
#  'IGK Thirsty Girl Coconut Milk Anti-Frizz Shampoo',
#  'Aquage Smoothing Shampoo',
#  'Unwash Dry Cleanser',
#  'TXTR. by Cantu Leave-In + Rinse Out Conditioner',
#  'John Frieda Frizz Ease Beyond Smooth Frizz Immunity Conditioner',
#  'Bumble and bumble Surf Creme Rinse Conditioner',
#  'Sexy Hair Curl Enhancing Shampoo',
#  'The One by Frederic Fekkai The Universal One Everyday Shampoo',
#  'Viviscal Densifying Shampoo',
#  'Hair Food Honey & Apricot Sulfate Free Moisture Conditioner',
#  'Unwash Anti-Residue Cleanse',
#  'IGK Thirsty Girl Coconut Milk Anti-Frizz Conditioner',
#  'Biosilk Silk Therapy Conditioner',
#  'Bumble and bumble Online Only Bb.Full Potential Conditioner',
#  'Bumble and bumble Bb. Pret-a-Powder Tres Invisible Nourishing Dry Shampoo with Hibiscus Extract',
#  'Chi Aloe Vera with Agave nectar Curl Enhancing Shampoo',
#  'Tresemme Moisture Rich Conditioner With Pump',
#  'Maui Moisture Thicken & Restore Bamboo Fibers Shampoo',
#  'Joico JoiFULL Volumizing Shampoo',
#  'Tresemme Moisture Rich Shampoo With Pump',
#  'Pureology Travel Size Hydrate Sheer Shampoo',
#  'Brite Make Me Pastel Pink Shampoo',
#  "L'Oréal EverPure Moisture Shampoo",
#  "L'anza Color Care De-Brass Blue Conditioner",
#  'Living Proof Travel Size Full Shampoo',
#  'Hask Argan Oil Repairing Deep Conditioner Packette',
#  'John Frieda Luxurious Volume Thickening Shampoo',
#  'OGX Extra Strength Tea Tree Mint Shampoo',
#  'Ouidad PlayCurl Volumizing Shampoo',
#  'OGX Quenching Coconut Curls Shampoo',
#  'Chi Keratin Reconstructing Shampoo',
#  'System Professional Color Save Shampoo',
#  'SheaMoisture African Water Mint & Ginger Detox & Refresh Hair & Scalp Conditioner',
#  'Love Beauty and Planet Smooth and Serene Argan Oil & Lavender Conditioner',
#  'Batiste Pink Pineapple Dry Shampoo - Fruity & Carefree',
#  'Paul Mitchell Travel Size Awapuhi Wild Ginger Moisturizing Lather Shampoo',
#  'Jack Black Double-Header Shampoo + Conditioner',
#  "Not Your Mother's Beach Babe Moisturizing Conditioner",
#  'Redken Pillow Proof Two Day Extender Dry Shampoo',
#  'Klorane Nourishing Conditioner with Mango Butter',
#  'Got 2b Fresh It Up Tropical Boost Dry Shampoo',
#  "Carol's Daughter Monoi Repairing Shampoo",
#  'Aquage Vitalizing Shampoo',
#  'Maui Moisture Heal & Hydrate + Shea Butter Conditioner',
#  'SheaMoisture African Black Soap & Bamboo Charcoal Deep Cleansing Shampoo',
#  'Bumble and bumble Online Only Bb.Mending Shampoo',
#  "Not Your Mother's Passion Fruit Kombucha & Awapuhi Ginger Youth Revival Shampoo",
#  'Redken Travel Size All Soft Conditioner',
#  'DevaCurl Travel Size Low-Poo Delight Weightless Waves Mild Lather Cleanser',
#  'Pureology Travel Size Hydrate Sheer Condition',
#  'Hempz Pure Hemp Ultra-Hydrating Healthy Herbal Hair Mask & Deep Conditioner',
#  'Fairy Tales Lifeguard Clarifying Shampoo',
#  'Maui Moisture Curl Quench + Coconut Oil Conditioner',
#  'SheaMoisture Purple Rice Water Shampoo',
#  "Carol's Daughter Monoi Repairing Conditioner",
#  "Not Your Mother's Beach Babe Moisturizing Shampoo",
#  "L'Oréal EverPure Moisture Conditioner",
#  'Aquage SeaExtend Silkening Oil Foam',
#  'Living Proof Ban Brassiness Mini Transformation Kit For Blondes + Highlights',
#  'Hask Keratin Protein Smoothing Shampoo',
#  'Redken Travel Size Frizz Dismiss Sulfate-Free Shampoo',
#  'Psssst! Texture And Body Dry Shampoo for fine hair',
#  'Alterna Caviar Anti-Aging Smoothing Anti-Frizz Conditioner',
#  'Batiste Travel Size Hint of Color Dry Shampoo',
#  'Matrix Biolage Advanced Oil Renew Shampoo',
#  "L'anza Healing Remedy Scalp Balancing Conditioner",
#  'Maui Moisture Thicken & Restore Bamboo Fibers Conditioner',
#  'Jack Black True Volume Thickening Shampoo',
#  'Living Proof Travel Size Perfect Hair Day (PhD) Conditioner',
#  'Pravana Intense Therapy Nourish Lightweight Healing Conditioner',
#  'John Frieda Radiant Red Boosting Shampoo',
#  'Redken Travel Size Frizz Dismiss Sulfate-Free Conditioner',
#  'Eva Nyc Clean It Up Shampoo',
#  'Rusk Hydrate01 Shampoo For Dry Hair',
#  "Kiehl's Since 1851 Amino Acid Conditioner",
#  'House 99 by David Beckham Polish Up Invigorating Body & Hair Wash',
#  'Drybar Detox Brunettes Dry Shampoo',
#  "L'Oréal EverPure Volume Shampoo",
#  'Maui Moisture Color Protection + Sea Minerals Conditioner',
#  'Klorane Shampoo with Quinine and B Vitamins',
#  'Klorane Hydrating Mango Butter Trial Kit',
#  'Eva Nyc Soften Up Conditioner',
#  'Joico JoiFULL Volumizing Conditioner',
#  'Bumble and bumble Online Only Bb.Mending Conditioner',
#  'dpHUE Cool Brunette Conditioner',
#  'Bumble and bumble Bb.Curl Shampoo',
#  'Bosley Online Only BosDefense Nourishing Shampoo For Non Color-Treated Hair',
#  'Pravana Intense Therapy Cleanse Lightweight Healing Shampoo',
#  'SheaMoisture Purple Rice Water Strength + Color Care Conditioner',
#  'Alterna Bamboo Volume Abundant Volume Conditioner',
#  'Philosophy Fresh Cream Dry Shampoo',
#  'Batiste Hint Of Color Dry Shampoo - Divine Dark',
#  'Redken Travel Size All Soft Shampoo',
#  'Maui Moisture Heal & Hydrate + Shea Butter Shampoo',
#  'Batiste Hydrating Dry Shampoo',
#  'John Frieda Luxurious Volume Thickening Conditioner',
#  'Unwash Charcoal Detox Scalp Scrub',
#  'OGX Renewing Argan Oil Of Morocco Intense Moisturizing Treatment',
#  'Living Proof Travel Size Perfect hair Day (PhD) Triple Detox Shampoo',
#  'Wella Nutricurls Shampoo For Waves',
#  'Nioxin Scalp Optimizing Cleanser',
#  'System Professional Repair Conditioner',
#  'Living Proof Travel Size Full Conditioner',
#  'Matrix Travel Size Biolage Hydrasource Conditioner',
#  'Rusk Repair01 Conditioner For Dry Hair',
#  'Paul Mitchell Travel Size Awapuhi Wild Ginger Keratin Cream Rinse',
#  "Not Your Mother's Travel Size Beach Babe Texturizing Dry Shampoo",
#  'Maui Moisture Curl Quench + Coconut Oil Shampoo',
#  'John Frieda Frizz Ease Beyond Smooth Frizz Immunity Shampoo',
#  'The One by Frederic Fekkai The Universal One Everyday Conditioner',
#  'Drybar Southern Belle Volume-Boosting Conditioner',
#  'Phyto PHYTOCYANE Densifying Treatment Shampoo',
#  'We Are Paradoxx Online Only Secret Weapon 3-in-1 Conditioner',
#  'Marc Anthony Frizz Sealing Conditioner',
#  'Klorane Nourishing Shampoo with Mango Butter',
#  'Klorane Oil Control Shampoo with Nettle',
#  'Keranique Damage Control Scalp Replenishing Shampoo-For Dry, Damaged Hair',
#  'Pravana Travel Size The Perfect Blonde Conditioner',
#  'Biosilk Hydrating Therapy Conditioner',
#  'IGK Travel Size Jet Lag Invisible Dry Shampoo',
#  'Macadamia Professional Weightless Moisture Conditioning Mist',
#  'Hair Food Tea Tree Oil & Lavender Sulfate Free Shampoo',
#  'SoCozy Online Only Splash Swim 3 in 1 Shampoo + Conditioner + Body Wash',
#  "Not Your Mother's Clean Freak Tinted Dry Shampoo-Light to Dark Brown",
#  'Kenra Professional Frizz Control Conditioner',
#  'Redken Travel Size Color Extend Shampoo',
#  'Joico Blonde Life Violet Conditioner',
#  'Viviscal Densifying Conditioner',
#  'Pravana Nevo Moisture Rich Sulfate-Free Shampoo',
#  'Batiste Dry Conditioner',
#  'Hask Monoi Coconut Oil Nourishing Deep Conditioner Packette',
#  'Paul Mitchell Travel Size Tea Tree Lavender Mint Moisturizing Shampoo',
#  'Pacifica Salty Waves Texturizing Conditioner',
#  'Hask Orchid & White Truffle Moisture Rich Conditioner',
#  'Hask UnWined Red Wine Inspired Dry Shampoo',
#  'Redken Travel Size Extreme Conditioner',
#  'Matrix Online Only Total Results Length Goals Sulfate-Free Shampoo For Extensions',
#  'Matrix Biolage R.A.W. Scalp Care Rebalance Conditioner',
#  'Redken Travel Size Extreme Shampoo',
#  'Love Beauty and Planet Murumuru Butter and Rose Blooming Color Shampoo',
#  'Paul Mitchell Travel Size Tea Tree Special Color Shampoo',
#  'Pacifica Coconut Damage Mask',
#  'Matrix Travel Size Biolage ColorLast Purple Shampoo',
#  'Unwash Travel Size Dry Cleanser',
#  'Matrix Online Only Total Results Length Goals Conditioner For Extensions',
#  'Maui Moisture Color Protection + Sea Minerals Shampoo',
#  'Nexxus Diametress Volume Shampoo for Fine and Flat Hair',
#  'Paul Mitchell Travel Size Tea Tree Lemon Sage Thickening Shampoo',
#  'Babo Botanicals Online Only Moisturizing Conditioner',
#  'Sun Bum Online Only Sun Bum Hair Tripper',
#  "Carol's Daughter Black Vanilla Moisture & Shine Leave-In Conditioner",
#  'Keranique Curl Preserve Nourishing Keratin Conditioner For Curly, Textured Hair',
#  'SheaMoisture Green Coconut & Activated Charcoal Build-Up Blaster',
#  'Mizani Scalp Care Pyrithione Zinc Antidandruff Conditioner',
#  'DevaCurl Travel Size One Condition Delight Weightless Waves Conditioner',
#  'Hask Chamomile & Argan Oil Blonde Care Shampoo',
#  'Hask Cucumber & Aloe Water Shampoo',
#  'Redken Travel Size Color Extend Conditioner',
#  'Living Proof Online Only Perfect hair Day System Bundle',
#  'Bumble and bumble Travel Size Bb. Pret-a-Powder Tres Invisible Dry Shampoo with French Pink Clay',
#  'Matrix Travel Size Biolage Hydrasource Shampoo',
#  'SheaMoisture Green Coconut & Activated Charcoal Exfoliating Hair Mud',
#  'Hask Superfruit Healthy Deep Conditioner',
#  'Thick Head Online Only Clear Head Anti-Thinning 2-IN-1 Shampoo & Conditioner',
#  'Pureology Travel Size Strength Cure Shampoo',
#  'Flora & Curl Online Only Curl Refresh Clay Wash',
#  'Hask UnWined Caberernet Sauvignon Deep Conditioner',
#  'Matrix Total Results Keep Me Vivid Trial Kit',
#  'Babo Botanicals Online Only Smoothing Detangling Spray',
#  'AG Hair Simply Dry Shampoo',
#  'Duke Cannon Supply Co Online Only News Anchor 2 in 1 Hair Wash Tea Tree Formula',
#  'Hask Cactus Water Conditioner',
#  'Noughty Wave Hello Curl Defining Conditioner',
#  'Marc Anthony Curl Defining Shampoo',
#  'Kenra Professional Frizz Control Shampoo',
#  'Mizani True Textures Cream Cleansing Conditioner',
#  'Living Proof Travel Size No Frizz Conditioner',
#  'Philosophy Pure Grace Dry Shampoo',
#  'Love Beauty and Planet Smooth and Serene Argan Oil & Lavender Shampoo',
#  'Matrix Travel Size Total Results So Silver Shampoo',
#  "L'Oréal EverPure Volume Conditioner",
#  "Carol's Daughter Cactus Rose Water Sulfate-Free Shampoo",
#  'Matrix Style Link Mineral Play Back Dry Shampoo',
#  'Paul Mitchell Travel Size Tea Tree Special Color Conditioner',
#  'Rusk PlatinumX Shampoo',
#  'Aquage Dry Shampoo',
#  'SheaMoisture Red Palm Oil & Cocoa Butter Leave In or Rinse Out Conditioner',
#  "Carol's Daughter Cactus Rose Water Lightweight Conditioner",
#  'System Professional Color Save Conditioner',
#  'Hask Cactus Water Shampoo',
#  'John Frieda Sheer Blonde Color Renew Tone Restoring Conditioner',
#  'Keranique Curl Preserve Scalp Nourishing Shampoo For Curly, Textured Hair',
#  'Punky Colour IntraBond Revitalizing Leave-In Spray Conditioner',
#  'Paul Mitchell Invisiblewear Brunette Dry Shampoo',
#  'Pureology Travel Size Style + Protect Refresh & Go Dry Shampoo',
#  'Sexy Hair Strong Sexy Hair Strengthening Conditioner',
#  'SheaMoisture Green Coconut & Activated Charcoal Shampoo',
#  'Pureology Travel Size Strength Cure Conditioner',
#  "L'Oréal EverCreme Deep Nourish Shampoo",
#  'Biosilk Silk Therapy With Organic Coconut Oil Moisturizing Conditioner',
#  'Tresemme Keratin Smooth Conditioner',
#  'Bosley Online Only BosDefense Volumizing Conditioner For Non Color-Treated Hair',
#  'Neuma neuBlonde Detangling Rinse',
#  'dpHUE Travel Size Apple Cider Vinegar Scalp Scrub',
#  'Hask UnWined Brut Rosé Deep Conditioner',
#  'Hask UnWined Pinot Grigio Deep Conditioner',
#  'Hask Orchid & White Truffle Moisture Rich Shampoo',
#  'Marc Anthony Deep Repair Aloe Vera & Jasmine Oil Deep Conditioning Packet',
#  "Not Your Mother's Travel Size Plump For Joy Body Building Dry Shampoo",
#  'SoCozy Online Only Cinch 3 in 1 Shampoo + Conditioner + Body Wash',
#  'Hair Food Vanilla Bean & Jasmine Sulfate Free Smoothing Shampoo',
#  'System Professional Hydrate Conditioner',
#  "Carol's Daughter Black Vanilla Moisture & Shine Hydrating Conditioner",
#  'Love Beauty and Planet Murumuru Butter and Rose Blooming Color Conditioner',
#  'Hair Food Tea Tree Oil & Lavender Sulfate Free Purifying Conditioner',
#  'OGX Coconut Miracle Oil Dry Shampoo',
#  'Drybar Travel Size On The Rocks Clarifying Charcoal Shampoo',
#  'Pacifica Salty Waves Texturizing Shampoo',
#  'Klorane Soothing & Anti-Irritating Shampoo with Peony',
#  "L'Oréal EverPure Blonde Conditioner",
#  'OGX Anti-Breakage Keratin Oil Conditioner',
#  'House 99 by David Beckham Twice As Smart Taming Shampoo & Conditioner',
#  'Drybar Online Only Travel Size Detox Brunettes Dry Shampoo',
#  'Sexy Hair Healthy Mini Trio',
#  'Fairy Tales Curly-Q Shampoo',
#  'Bumble and bumble Travel Size Bb.Thickening Shampoo',
#  'Paul Mitchell Travel Size Clarifying Shampoo Three',
#  "It's A 10 Blow Dry Glossing Glaze Conditioner",
#  'Noughty Wave Hello Curl Defining Shampoo',
#  'Maui Moisture Lightweight Hydration + Hibiscus Water Shampoo',
#  'Nexxus Emergencée Shampoo for Weak and Damaged Hair',
#  'Neuma neuBlonde Platinum Shampoo',
#  "L'Oréal EverPure Blonde Shampoo",
#  'Living Proof Travel Size Restore Conditioner',
#  'Living Proof Travel Size No Frizz Shampoo',
#  'Love Beauty and Planet Volume and Bounty Coconut Water & Mimosa Flower Shampoo',
#  'Hask Tea Tree & Rosemary Shampoo',
#  "It's A 10 Miracle Blow Dry Glossing Shampoo",
#  'Kenra Professional Travel Size Volume Dry Shampoo',
#  'OGX Ever Straight - Brazilian Keratin Therapy Conditioner',
#  'Maui Moisture Lightweight Hydration + Hibiscus Water Conditioner',
#  'Jack Black Nourishing Hair & Scalp Conditioner',
#  'Kyn. Rose Gold Shampoo',
#  'Hask Argan Dry Shampoo',
#  'OGX Orchid Oil Conditioner',
#  'OGX Orchid Oil Shampoo',
#  'Unwash Curls Dry Cleanser',
#  'SheaMoisture Coconut & Hibiscus Curl & Shine Conditioner',
#  'Biosilk Silk Therapy With Organic Coconut Oil Moisturizing Shampoo',
#  'Nexxus Blonde Assure Shampoo',
#  'Love Beauty and Planet Volume and Bounty Coconut Water & Mimosa Flower Conditioner',
#  'Pureology Travel Size Strength Cure Best Blonde Purple Shampoo',
#  'Hask Biotin Thickening Dry Shampoo',
#  'John Frieda Sheer Blonde Color Renew Tone Restoring Shampoo ',
#  'Redken Travel Size High Rise Volume Lifting Shampoo',
#  ...]

# %%
# Clean up the products for puntation and characters

clean_no_acronymn_fix_products = []

for product in product_list_full:
    product = product.lower()
    product = re.sub(r"\–.*", " ", product)
    product = re.sub(r"\'" , '', product)
    product = re.sub(r'[^a-zA-Z0-9\s]', '', product)
    product = re.sub(r"\,.*", " ", product)
    product = re.sub(r"(leave in)", " ", product)
    product = re.sub(r"(rinse out)", " ", product)
    product = re.sub(r"(conditioner)", " ", product)
    product = re.sub(r"(gel)", " ", product)
    product = re.sub(r"(condition)", " ", product)
    product = re.sub(r"(shampoo)", " ", product)
    #product = re.sub(r"(poo)", " ", product)
    product = re.sub(r"(product)", " ", product)
    product = re.sub(r"(styler)", " ", product)
    product = re.sub(r"(creme)", " ", product)
    product = re.sub(r"(cream)", " ", product)
    product = re.sub(r"(spray)", " ", product)
    product = re.sub(r"(custard)", " ", product)
    product = re.sub('  ', ' ', product) 
    
    
    clean_no_acronymn_fix_products.append(product)

# %%
product_list_full[0]
# Out:
# 'Redken All Soft Conditioner'

# %%
clean_no_acronymn_fix_products
# Out:
# ['redken all soft ',
#  'paul mitchell tea tree special ',
#  'redken all soft ',
#  'matrix biolage colorlast ',
#  'matrix biolage colorlast ',
#  'paul mitchell tea tree lavender mint moisturizing ',
#  'paul mitchell tea tree lavender mint moisturizing ',
#  'matrix biolage ultra hydrasource ',
#  'redken color extend magnetics ',
#  'pureology hydrate ',
#  'pureology hydrate ',
#  'redken color extend blondage color depositing purple ',
#  'redken color extend ',
#  'redken color extend magnetics ',
#  'redken extreme ',
#  'joico color balance purple ',
#  'redken color extend ',
#  'paul mitchell tea tree special ',
#  'redken extreme ',
#  'ag hair moisture fast food leaveon ',
#  'redken color extend blondage color depositing purple ',
#  'matrix biolage hydrasource ',
#  'its a 10 miracle deep  plus keratin',
#  'ag hair jumbo pump',
#  'redken frizz dismiss sufatefree ',
#  'joico color balance purple ',
#  'matrix biolage ultra hydrasource ',
#  'redken all soft mega ',
#  'redken frizz dismiss sulfatefree ',
#  'matrix biolage advanced keratindose  for overprocessed hair',
#  'sebastian drench ',
#  'matrix biolage volumebloom ',
#  'joico kpak color therapy ',
#  'wella fusionplex ',
#  'wella fusionplex ',
#  'joico kpak color therapy ',
#  'sebastian drench ',
#  'redken nature science all soft  for drybrittle hair',
#  'redken nature science all soft  for drybrittle hair',
#  'matrix biolage volumebloom ',
#  'paul mitchell tea tree scalp care antithinning ',
#  'ag hair colour care colour savour sulfatefree ',
#  'matrix biolage advanced keratindose  for overprocessed hair',
#  'matrix total results mega sleek ',
#  'matrix biolage scalpsync antidandruff ',
#  'living proof perfect hair day phd dry ',
#  'drybar the blowout brigade set',
#  'paul mitchell tea tree lemon sage thickening ',
#  'redken all soft mega ',
#  'matrix total results brass off ',
#  'redken clean maniac hair cleansing  clarifying ',
#  'ag hair colour care colour savour colour protection ',
#  'matrix total results mega sleek ',
#  'paul mitchell tea tree special color ',
#  'its a 10 miracle  plus keratin',
#  'its a 10 miracle daily ',
#  'nexxus humectress moisture  for normal to dry hair',
#  'joico moisture recovery ',
#  'redken high rise volume lifting ',
#  'redken clear moisture hydrating ',
#  'sebastian penetraitt ',
#  'american crew 3in1   and body wash',
#  'paul mitchell tea tree scalp care antithinning ',
#  'matrix biolage normalizing cleanreset ',
#  'redken clear moisture hydrating ',
#  'hempz sweet pineapple honey melon herbal volumizing ',
#  'wella invigo brilliance  for fine hair',
#  'ag hair keratin repair restore daily strengthening ',
#  'wella invigo brilliance  for fine hair',
#  'matrix biolage hydrasource detangling solution',
#  'pureology hydrate sheer ',
#  'paul mitchell tea tree special color ',
#  'matrix scalpsync ',
#  'paul mitchell tea tree lemon sage thickening ',
#  'nioxin cleanser  system 2 for fine hair with progressed thinning',
#  'pureology hydrate sheer ',
#  'sebastian penetraitt ',
#  'matrix biolage advanced fiberstrong  for fragile hair',
#  'joico moisture recovery ',
#  'matrix total results so silver ',
#  'ag hair keratin repair refuel sulfatefree strengthening ',
#  'devacurl one  original daily  ',
#  'matrix biolage advanced full density  for thin hair',
#  'nioxin scalp therapy  system 4 color treated hairprogressed thinning',
#  'hempz sweet pineapple honey melon herbal volumizing ',
#  'nioxin cleanser  system 4 color treated hair progressed thinning',
#  'redken high rise volume lifting ',
#  'matrix biolage colorlast purple ',
#  'tigi bed head urban antidotes resurrection ',
#  'alterna caviar antiaging replenishing moisture ',
#  'alterna caviar antiaging replenishing moisture ',
#  'matrix total results brass off ',
#  'tigi bed head urban antidotes recovery ',
#  'living proof online only no frizz favorites jumbo bundle',
#  'tigi bed head urban antidotes recovery ',
#  'pureology strength cure ',
#  'hempz original herbal  for damaged color treated hair',
#  'its a 10 silk express miracle silk ',
#  'matrix biolage advanced fiberstrong  for fragile hair',
#  'pureology strength cure ',
#  'nioxin scalp therapy  system 2 for fine hair with progressed thinning',
#  'kenra professional platinum luxe shine ',
#  'hempz original herbal  for damaged color treated hair',
#  'matrix biolage advanced full density  for thin hair',
#  'devacurl one  decadence ultra moisturizing milk ',
#  'kenra professional platinum color charge ',
#  'kenra professional platinum thickening ',
#  'paul mitchell original awapuhi ',
#  'tigi bed head urban antidotes resurrection ',
#  'nioxin scalp recovery cleanser',
#  'hempz pomegranate daily herbal moisturizing ',
#  'hempz triple moisture rich herbal whipped crme  hair mask',
#  'ag hair sleeek argan coconut ',
#  'american crew 3in1 tea tree   and body wash',
#  'matrix biolage smoothproof ',
#  'dphue apple cider vinegar hair rinse',
#  'batiste original dry  clean classic',
#  'hempz pomegranate daily herbal moisturizing ',
#  'redken curvaceous ',
#  'pureology smooth perfection ',
#  'kenra professional volumizing ',
#  'devacurl nopoo original zero lather ing cleanser',
#  'ag hair smooth smoooth sulfatefree argan coconut ',
#  'kenra professional platinum color charge ',
#  'pureology smooth perfection ',
#  'nexxus therappe repleneshing system  for normal to dry hair',
#  'matrix total results high amplify ',
#  'kenra professional platinum thickening ',
#  'wella invigo nutrienrich ',
#  'kenra professional platinum luxe shine ',
#  'ag hair colour care sterling silver toning ',
#  'sexy hair big sexy hair volumizing ',
#  'curlsmith curl quenching ing wash',
#  'matrix total results so long damage ',
#  'kenra professional moisturizing ',
#  'ag hair moisture fast food sulfatefree ',
#  'paul mitchell original the ',
#  'pureology strength cure best blonde purple ',
#  'sexy hair big sexy hair extra volumizing ',
#  'matrix biolage scalpsync cooling mint ',
#  'keracolor online only color clenditioner liter',
#  'sexy hair smooth sexy hair smoothing ',
#  'matrix biolage smoothproof ',
#  'matrix total results so long damage ',
#  'pureology strength cure best blonde purple ',
#  'keratin complex smoothing therapy keratin color care ',
#  'kenra professional moisturizing ',
#  'joico color balance blue ',
#  'nioxin cleanser  system 3 color treated hairnormal to light thinning',
#  'wella invigo nutrienrich ',
#  'matrix total results keep me vivid sulfatefree ',
#  'nexxus color assure  for color treated hair',
#  'joico kpak ',
#  'paul mitchell super strong ',
#  'kenra professional color maintenance ',
#  'sexy hair healthy sexy hair moisturizing ',
#  'drybar limited edition detox dry  coconut colada scent',
#  'keratin complex smoothing therapy keratin color care ',
#  'nioxin scalp therapy  system 3 color treated hairnormal to light thinning',
#  'hempz online only herbal healthy hair fortifying ',
#  'tigi bed head colour goddess oil infused ',
#  'ag hair colour care sterling silver toning ',
#  'sexy hair healthy sexy hair moisturizing ',
#  'matrix total results so silver  for blonde and silver hair',
#  'fairy tales rosemary repel ',
#  'tigi bed head urban antidotes reenergize ',
#  'its a 10 miracle moisture ',
#  'joico kpak ',
#  'its a 10 silk express miracle silk ',
#  'ag hair natural balance apple cider vinegar sulfatefree ',
#  'sexy hair strong sexy hair strengthening ',
#  'matrix total results high amplify ',
#  'wella invigo brilliance  for coarse hair',
#  'redken damage control kit',
#  'drybar detox dry ',
#  'sebastian volupt ',
#  'redken color extend color depositing graydiant ',
#  'kenra professional volumizing ',
#  'tigi bed head colour goddess oil infused ',
#  'sexy hair blonde sexy hair bombshell blonde  daily color preserving ',
#  'ag hair natural boost apple cider vinegar ',
#  'its a 10 potion 10 miracle repair ',
#  'nioxin scalp recovery moisturizing ',
#  'sexy hair strong sexy hair strengthening ',
#  'matrix biolage exquisiteoil crme ',
#  'nexxus keraphix  for damaged hair',
#  'ouidad curl quencher moisturizing ',
#  'sexy hair smooth sexy hair smoothing ',
#  'wella elements lightweight renewing ',
#  'tigi bed head urban antidotes reenergize ',
#  'living proof perfect hair day phd ',
#  'devacurl online only double take curly hair kit',
#  'matrix total results keep me vivid ',
#  'tigi bed head rockaholic dirty secret dry ',
#  'wella elements renewing ',
#  'hempz online only herbal healthy hair fortifying ',
#  'ag hair curl thrive hydrating ',
#  'tigi bed head dumb blonde ',
#  'batiste hint of color dry  beautiful brunette',
#  'paul mitchell original the detangler',
#  'sexy hair vibrant sexy hair color lock ',
#  'kenra professional platinum detox and deflect daily ',
#  'shimmer lights shimmer lights purple  for blonde silver hair',
#  'sexy hair blonde sexy hair bright blonde  violet  for blonde',
#  'matrix total results hello blondie ',
#  'redken color extend color depositing graydiant ',
#  'devacurl one  delight weightless waves ',
#  'living proof full ',
#  'sexy hair vibrant sexy hair color lock ',
#  'fairy tales rosemary repel  ',
#  'joico color endure ',
#  'joico color balance blue ',
#  'joico color endure ',
#  'wella invigo brilliance  for coarse hair',
#  'devacurl nopoo decadence zero lather ultra moisturizing milk cleanser',
#  'matrix total results color obsessed ',
#  'pureology nano works gold ',
#  'macadamia professional weightless moisture ',
#  'living proof restore ',
#  'matrix total results color obsessed ',
#  'bumble and bumble bbhairdressers invisible oil ',
#  'pravana the perfect blonde ',
#  'kenra professional platinum restorative ',
#  'pureology nano works gold ',
#  'redken brews 3in1   and body wash',
#  'living proof perfect hair day phd ',
#  'devacurl online only double take super curly hair kit',
#  'nioxin cleanser  system 1 for fine hair with light thinning',
#  'ag hair volume thikk wash volumizing ',
#  'ag hair curl revive sulfatefree hydrating ',
#  'living proof restore ',
#  'tigi bed head dumb blonde reconstructor',
#  'nexxus color assure  for color treated hair',
#  'joico defy damage care trial kit',
#  'igk first class charcoal detox dry ',
#  'paul mitchell mitch double hitter 2in1   ',
#  'matrix total results moisture me rich ',
#  'joico defy damage protective ',
#  'joico defy damage protective ',
#  'kenra professional platinum detox and deflect daily ',
#  'kenra professional color maintenance ',
#  'bumble and bumble bbhairdressers invisible oil ',
#  'bumble and bumble bb thickening volume ',
#  'macadamia professional weightless moisture ',
#  'paul mitchell platinum blonde ',
#  'sebastian volupt ',
#  'kenra professional brightening ',
#  'philosophy amazing grace perfumed  shower  bubble bath',
#  'ag hair moisture ultramoist moisturizing ',
#  'pureology fullfyl ',
#  'matrix biolage hydrasource ing balm',
#  'matrix biolage exquisiteoil microoil ',
#  'devacurl lowpoo original mild lather cleanser',
#  'paul mitchell original  one',
#  'ouidad advanced climate control defrizzing ',
#  'living proof no frizz ',
#  'philosophy hula girl  shower  bubble bath',
#  'paul mitchell super strong ',
#  'matrix total results hello blondie ',
#  'keratin complex timeless color fadedefy ',
#  'keratin complex timeless color fadedefy ',
#  'macadamia professional nourishing moisture ',
#  'devacurl lowpoo delight weightless waves mild lather cleanser',
#  'nexxus keraphix damage healing ',
#  'kenra professional brightening ',
#  'kenra professional platinum restorative ',
#  'ouidad curl quencher moisturizing ',
#  'nioxin scalp therapy  system 1 for fine hair with light thinning',
#  'matrix biolage sugar shine ',
#  'american crew daily moisturizing ',
#  'macadamia professional nourishing moisture ',
#  'matrix total results moisture me rich ',
#  'its a 10 silk express miracle silk leavein',
#  'matrix biolage sugar shine ',
#  'redken brews daily ',
#  'redken scalp relief dandruff control ',
#  'living proof full ',
#  'ouidad advanced climate control defrizzing ',
#  'hask monoi coconut oil nourishing ',
#  'tigi bed head fully loaded massive volume ',
#  'devacurl online only double take wavy hair kit',
#  'paul mitchell color protect ',
#  'living proof no frizz ',
#  'pureology fullfyl ',
#  'fairy tales rosemary repel ing ',
#  'hask argan oil repairing ',
#  'bosley bosrevive nourishing  for color treated hair',
#  'drybar triple sec 3in1 finishing ',
#  'ag hair volume thikk rinse volumizing ',
#  'paul mitchell awapuhi wild ginger moisturizing lather ',
#  'nioxin cleanser  system 6 chemically treatedbleached hairprogressed thinning',
#  'mizani thermasmooth antifrizz ',
#  'nioxin scalp therapy  system 6 chemically treatedbleached hairprogressed thinning',
#  'hask monoi oil nourishing ',
#  'hempz online only blushing grapefruit raspberry crme color protector ',
#  'hask argan oil repairing ',
#  'dphue online only apple cider vinegar travel trio',
#  'paul mitchell color protect ',
#  'sexy hair blonde sexy hair bombshell blonde  daily color preserving ',
#  'hempz blushing grapefruit raspberry crme color protector ',
#  'ag hair moisture xtramoist moisturizing ',
#  'redken diamond oil glow dry gloss ',
#  'pureology clean volume ',
#  'kenra professional snail antiaging ',
#  'bumble and bumble bb thickening volume ',
#  'ouidad vitalcurl plus balancing rinse ',
#  'lanza healing color care colorpreserving ',
#  'matrix biolage hydrasource daily leavein tonic',
#  'lanza keratin healing oil ',
#  'not your mothers naturals tahitian gardenia flower mango butter curl defining ',
#  'kenra professional snail antiaging ',
#  'keranique volumizing scalp stimulating ',
#  'american crew daily ',
#  'bosley bosrevive volumizing  for colortreated hair',
#  'sexy hair big sexy hair volumizing ',
#  'matrix oil wonders volume rose  for fine hair',
#  'redken brews mint ',
#  'kenra professional strengthening ',
#  'bumble and bumble bbgentle ',
#  'bumble and bumble bbsuper rich ',
#  'eva nyc freshen up dry ',
#  'ag hair therapy tech two proteinenriched ',
#  'tigi bed head oh bee hive matte dry ',
#  'ouidad vitalcurl clear and gentle ',
#  'hempz triple moisture rich daily herbal replenishing ',
#  'redken triple dry 15 dry texture finishing ',
#  'devacurl leavein decadence',
#  'not your mothers naturals royal honey kalahari desert melon repair protect leavein ',
#  'redken diamond oil glow dry detangling ',
#  'devacurl buildup buster micellar water cleansing serum',
#  'sexy hair big sexy hair dry ',
#  'sun bum revitalizing 3 in 1  treatment',
#  'devacurl devafresh',
#  'lanza healing color care colorpreserving ',
#  'devacurl curls on the go kit',
#  'neuma neumoisture ',
#  'hask biotin boost thickening ',
#  'bumble and bumble bb pretapowder tres invisible dry  with french pink clay',
#  'redken brews daily ',
#  'not your mothers curl talk 3in1 ',
#  'neuma neuvolume ',
#  'paul mitchell extrabody ',
#  'its a 10 potion 10 miracle repair ',
#  'mizani thermasmooth antifrizz ',
#  'bumble and bumble bbhair powder',
#  'lanza keratin healing oil ',
#  'shimmer lights shimmer lights purple  for blonde silver hair',
#  'paul mitchell clarifying  two',
#  'sebastian reset ',
#  'paul mitchell platinum blonde ',
#  'philosophy lemon   shower  bubble bath',
#  'not your mothers naturals tahitian gardenia flower mango butter curl defining ',
#  'pravana the perfect blonde ',
#  'redken pillow proof blow dry two day extender dry ',
#  'ogx biotin collagen ',
#  'not your mothers blue sea kale pure coconut water sea minerals ',
#  'hask biotin boost thickening ',
#  'living proof travel size perfect hair day phd dry ',
#  'not your mothers clean freak dry ',
#  'macadamia professional ultra rich moisture ',
#  'nioxin scalp therapy  system 5 chemically treatedbleached hairnormal to light thinning',
#  'unwash biocleansing ',
#  'marc anthony grow long caffeine ginseng ',
#  'living proof perfect hair day phd triple detox ',
#  'uberliss original bond sustainer',
#  'marc anthony grow long caffeine ginseng ',
#  'pureology clean volume ',
#  'dphue travel size apple cider vinegar hair rinse',
#  'bosley bosrevive nourishing  for non colortreated hair',
#  'not your mothers plump for joy body building dry ',
#  'hask charcoal purifying dry ',
#  'drybar on the rocks clarifying charcoal ',
#  'paul mitchell smoothing super skinny ',
#  'drybar sake bomb nourishing ',
#  'not your mothers activated bamboo charcoal purple moonstone restore reclaim scalp scrub',
#  'alterna caviar antiaging bond repair ',
#  'not your mothers way to grow leavein ',
#  'living proof color care ',
#  'macadamia professional ultra rich moisture ',
#  'not your mothers blue sea kale pure coconut water sea minerals ',
#  'kyn purple ',
#  'ouidad moisture lock leavein ',
#  'redken curvaceous lofoam cleanser',
#  'tigi dumb blonde violet toning ',
#  'kenra professional clarifying ',
#  'alterna caviar antiaging bond repair ',
#  'paul mitchell extrabody ',
#  'not your mothers curl talk curl care ',
#  'igk hot girls hydrating ',
#  'matrix  or  liter pump',
#  'paul mitchell awapuhi wild ginger moisturizing lather ',
#  'not your mothers beach babe texturizing dry ',
#  'philosophy fresh   shower  bubble bath',
#  'its a 10 potion 10 miracle instant repair leavein',
#  'drybar sake bomb nourishing ',
#  'tigi bed head calma sutra cleansing ',
#  'bumble and bumble bbpretapowder',
#  'lanza healing volume thickening ',
#  'neuma neuvolume ',
#  'keranique volumizing keratin ',
#  'ogx biotin collagen ',
#  'kenra professional strengthening ',
#  'igk hot girls hydrating ',
#  'matrix biolage hydrasource travel kit',
#  'nioxin cleanser  system 5 chemically treatedbleached hairnormal to light thinning',
#  'jack black allover wash',
#  'drybar detox clear invisible dry ',
#  'paul mitchell lavender mint moisturizing cowash',
#  'paul mitchell instant moisture ',
#  'ogx argan oil of morocco ',
#  'ogx renewing moroccan argan oil ',
#  'pureology style protect refresh go dry ',
#  'living proof color care ',
#  'paul mitchell mitch heavy hitter deep cleansing ',
#  'paul mitchell awapuhi wild ginger keratin  rinse',
#  'bumble and bumble online only bbseaweed mild marine ',
#  'alterna travel size caviar professional styling sheer dry ',
#  'paul mitchell clarifying  three',
#  'redken brews extra clean ',
#  'igk travel size first class charcoal detox dry ',
#  'the one by frederic fekkai the uplifting one volume ',
#  'jack black turbo wash energizing cleanser',
#  'neuma neumoisture ',
#  'babo botanicals online only swim sport  wash',
#  'joico color infuse red ',
#  'keratin complex blondeshell debrass ',
#  'sheamoisture jamaican black castor oil strengthen restore ',
#  'igk bad bougie amla oil deep repair ',
#  'devacurl super curly curls on the go kit',
#  'ogx nourishing coconut milk ',
#  'bumble and bumble the mega moisture kit',
#  'ag hair therapy  light proteinenriched ',
#  'sexy hair clean wave texturizing styling ',
#  'drybar limited edition detox dry  coastal cooler scent',
#  'philosophy raspberry sorbet  shower  bubble bath',
#  'not your mothers matcha green tea wild apple blossom nutrient rich ',
#  'lanza healing moisture kukui nut ',
#  'grow gorgeous online only thinning hair rescue kit',
#  'bosley bosrevive volumizing  for non colortreated hair',
#  'drybar online only the weekender travel hair essentials',
#  'bumble and bumble online only bb de coco tropicalriche ',
#  'pureology protect style girl onthego travel kit',
#  'aquage seaextend strengthening ',
#  'ogx nourishing coconut milk ',
#  'lanza healing volume thickening ',
#  'not your mothers matcha green tea wild apple blossom nutrient rich ',
#  'lanza healing moisture tamanu  ',
#  'aquage seaextend silkening ',
#  'paul mitchell instant moisture ',
#  'bumble and bumble online only bbsunday ',
#  'sheamoisture coconut hibiscus curl shine ',
#  'matrix biolage hydrasource daily leavein ',
#  'neuma reneu ',
#  'bosley bosdefense volumizing  for colortreated hair',
#  'pura dor hair thinning therapy ',
#  'klorane dry  with nettle',
#  'bumble and bumble online only bb de coco tropicalriche ',
#  'sheamoisture jamaican black castor oil strengthen restore leavein ',
#  'not your mothers way to grow long strong ',
#  'not your mothers blonde moment treatment ',
#  'joico color infuse red ',
#  'devacurl wash day wonder',
#  'drybar blonde ale brightening ',
#  'chi infra moisture therapy ',
#  'paul mitchell instant moisture awapuhi moisture mist',
#  'philosophy coconut splash  shower  bubble bath',
#  'paul mitchell invisiblewear ',
#  'pureology strength cure best blonde girl onthego mini kit',
#  'neuma reneu ',
#  'keratin complex blondeshell debrass ',
#  'philosophy senorita margarita  shower  bubble bath',
#  'alterna caviar antiaging clinical densifying ',
#  'clinique cliniquefit workout go dry ',
#  'kenra professional daily provision',
#  'ag hair cleansing ',
#  'not your mothers knotty to nice ing detangler',
#  'redken nature science color extend sulfate free  for color treated hair',
#  'not your mothers way to grow long strong ',
#  'not your mothers clean freak tapioca dry ',
#  'sheamoisture coconut hibiscus curl shine ',
#  'neuma online only neusmooth leaveon ',
#  'aquage seaextend silkening ',
#  'batiste volumizing dry ',
#  'wella eimi dry me dry ',
#  'aquage seaextend strengthening ',
#  'bumble and bumble bb summer style air dry set',
#  'joico blonde life brightening ',
#  'sexy hair big mini trio',
#  'drybar southern belle volumeboosting powder',
#  'batiste travel size dry ',
#  'sun bum revitalizing ',
#  'philosophy amazing grace dry ',
#  'the one by frederic fekkai the uplifting one volume ',
#  'igk bad bougie amla oil deep repair ',
#  'john frieda frizz ease daily nourishment leavein ing ',
#  'sebastian preset ',
#  'not your mothers activated bamboo charcoal purple moonstone restore reclaim ',
#  'drybar on the rocks lightweight ',
#  'matrix biolage raw color care ',
#  'not your mothers activated bamboo charcoal purple moonstone restore reclaim ',
#  'chi keratin leavein  reconstructing treatment',
#  'john frieda sheer blonde go blonder lightening ',
#  'bosley bosdefense nourishing  for colortreated hair',
#  'hask unwined ros wine inspired dry ',
#  'klorane dry  with oat milk for all hair types nonaerosol',
#  'alterna caviar antiaging infinite color hold ',
#  'lanza healing strength manuka honey ',
#  'ouidad curl recovery whipped curls daily  styling primer',
#  'keranique deep hydration scalp stimulating for normal to dry hair',
#  'wella invigo blonde recharge cool blonde ',
#  'joico blonde life brightening ',
#  'not your mothers naturals royal honey kalahari desert melon repair protect ',
#  'living proof no frizz leavein ',
#  'not your mothers naturals coconut milk african marula tree oil high moisture ',
#  'redken nature science color extend sulfate free  for color treated hair',
#  'wella oil reflections luminous instant ',
#  'naturalicious online only hello gorgeous hair care system for tight curls coils',
#  'bumble and bumble bbcolor minded ',
#  'keratin complex keratin care smoothing ',
#  'sheamoisture jamaican black castor oil strengthen restore rinseout  ',
#  'ag hair natural healthy hair styling kit',
#  'sheamoisture manuka honey yogurt hydrate repair ',
#  'lanza healing strength white tea ',
#  'kenra professional volume dry ',
#  'bumble and bumble bbcurl custom ',
#  'keratin complex keratin care smoothing ',
#  'ouidad botanical boost curl energizing refreshing ',
#  'hask unwined by hask champagne inspired volumizing dry ',
#  'lanza healing color care silver brightening ',
#  'sheamoisture manuka honey yogurt hydrate repair ',
#  'alterna caviar antiaging infinite color hold ',
#  'alterna caviar antiaging multiplying volume ',
#  'psssst dry ',
#  'igk 30000 feet volume ',
#  'john frieda sheer blonde go blonder lightening ',
#  'chi dry ',
#  'keranique color boost scalp revitalizing  for colortreated hair',
#  'alterna caviar antiaging multiplying volume ',
#  'bumble and bumble online only bbseaweed mild marine ',
#  'hask coconut dry ',
#  'drybar blonde ale brightening ',
#  'sebastian dry clean only',
#  'lanza healing moisture noni fruit leavein ',
#  'bumble and bumble scalp detox',
#  'pura dor hair thinning therapy  ',
#  'drybar travel size detox dry ',
#  'matrix raw color care ',
#  'philosophy melon daiquiri  shower  bubble bath',
#  'hask charcoal clarifying ',
#  'wella nutricurls cleansing  gentle cleansing cowash for waves curls',
#  'matrix biolage 3 butter control system ',
#  'kenra professional platinum dry ',
#  'batiste defrizz dry ',
#  'tigi bed head totally beachin mellow aftersun ',
#  'ogx thick full biotin collagen ',
#  'pureology travel size hydrate ',
#  'sun bum revitalizing ',
#  'sheamoisture african water mint ginger detox refresh hair scalp gentle ',
#  'kenra professional dandruff ',
#  'igk all stars volume hydration and dry  kit',
#  'keratin complex vanilla bean deep ',
#  'redken nature science extreme fortifying  for distressed hair',
#  'devacurl nocomb detangling  lightweight curl tamer',
#  'system professional travel size silver ',
#  'sun bum premium color enhancing blonde ',
#  'eva nyc tone it down blonde ',
#  'lanza healing nourish stimulating ',
#  'keranique the complete hair regrowth system damage control',
#  'sebastian dark oil lightweight ',
#  'its a 10 miracle volumizing ',
#  'neuma neusmooth ',
#  'redken nature science extreme fortifying  for distressed hair',
#  'ouidad curl recovery ultra nourishing cleansing oil',
#  'pureology travel size hydrate ',
#  'wella nutricurls detangling ',
#  'sebastian dark oil lightweight ',
#  'the body shop banana truly nourishing ',
#  'igk jet lag invisible dry ',
#  'ouidad curl immersion triple treat deep ',
#  'joico travel size color balance purple ',
#  'paul mitchell invisiblewear ',
#  'wella invigo blonde recharge cool blonde ',
#  'chi argan oil plus moringa oil ',
#  'lanza healing smooth glossifying ',
#  'bumble and bumble bbcolor minded ',
#  'aquage color protecting ',
#  'not your mothers naturals royal honey kalahari desert melon repair protect ',
#  'the body shop banana truly nourishing ',
#  'lanza healing smooth glossifying ',
#  'wella oil reflections luminous reveal ',
#  'aquage seaextend volumizing ',
#  'sun bum premium color enhancing blonde ',
#  'drybar detox dry  lush scent',
#  'pravana travel size the perfect blonde ',
#  'ogx hydrating teatree mint ',
#  'ag hair brunette dry ',
#  'igk direct flight multitasking matcha dry ',
#  'dphue cool blonde ',
#  'keranique the complete hair regrowth system color boost',
#  'igk 30000 feet volume ',
#  'paul mitchell neuro rinse ',
#  'the one by frederic fekkai the brilliant one color ',
#  'keranique deep hydration volumizing keratin for normal to dry hair ',
#  'bumble and bumble travel size pretapowder',
#  'alterna caviar moisture consumer trial kit',
#  'sun bum revitalizing dry ',
#  'wella nutricurls micellar  for curls',
#  'keracolor clenditioner',
#  'lanza healing remedy scalp balancing cleanser',
#  'klorane dry  with nettle natural tint',
#  'not your mothers naturals coconut milk african marula tree oil high moisture ',
#  'grow gorgeous online only grow gorgeous repair ',
#  'pura dor online only cleansing ',
#  'fairy tales static free detangling ',
#  'tigi bed head totally beachin cleansing jelly ',
#  'philosophy travel size amazing grace dry ',
#  'madison reed color protecting ',
#  'eva nyc mane magic 10in1 ',
#  'eva nyc tone it down blonde ',
#  'matrix biolage 3 butter control system ',
#  'loral hair expertise everpure cleansing balm',
#  'john frieda brilliant brunette color deepening ',
#  'keratin complex infusion therapy hydrating  ',
#  'house 99 by david beckham going big thickening ',
#  'john frieda brilliant brunette color deepening ',
#  'the one by frederic fekkai one more day dry ',
#  'chi argan oil plus moringa oil ',
#  'sun bum revitalizing detox ',
#  'keranique damage control replenishing keratin for dry damaged hair',
#  'aquage healing ',
#  'sun bum curls waves ',
#  'pura dor online only scalp therapy ',
#  'redken color extend vinegar hair rinse',
#  'delectable online only the everything powder',
#  'sheamoisture manuka honey mafura oil intensive hydration ',
#  'matrix total results prosolutionist alternate action clarifying ',
#  'got 2b fresh it up clean refresh dry ',
#  'drybar travel size triple sec 3in1 finishing ',
#  'matrix biolage raw nourish ',
#  'alterna bamboo volume abundant volume ',
#  'matrix travel size biolage colorlast ',
#  'sheamoisture raw shea butter restorative ',
#  'lanza healing nourish stimulating ',
#  'matrix total results the rebond ',
#  'aquage seaextend volumizing ',
#  'brite make me pastel purple ',
#  'paul mitchell neuro lather ',
#  'matrix travel size biolage colorlast ',
#  'its a 10 brightening  for blondes',
#  'sun bum curls waves ',
#  'grow gorgeous online only rescue repair ',
#  'the one by frederic fekkai the brilliant one color ',
#  'keranique color boost revitalizing keratin  for colortreated hair',
#  'alterna caviar antiaging restructuring bond repair ',
#  'american crew daily ',
#  'not your mothers clean freak dry  unscented',
#  'redken travel size color extend magnetics ',
#  'lime crime online only color ',
#  'dphue apple cider vinegar dry ',
#  'the body shop online only ginger scalp care ',
#  'matrix biolage raw scalp care antidandruff ',
#  'bumble and bumble online only bbfull potential ',
#  'brite make me pastel purple ',
#  'matrix biolage raw uplift ',
#  'ogx thick full biotin collagen ',
#  'ogx coconut miracle oil ',
#  'drybar drybar x kopari lil charcoal charmers kit',
#  'aquage equalizing detangler',
#  'igk low key cleansing walnut scalp scrub',
#  'klorane  with centaury shine enhancing and antiyellowing',
#  'kyn perfect ',
#  'ogx hydrating teatree mint ',
#  'kiehls since 1851 amino acid ',
#  'matrix total results the rebond ',
#  'madison reed color protecting ',
#  'bumble and bumble surf foam wash ',
#  'not your mothers plump for joy thickening ',
#  'tgin quench 3in1 cleansing cowash  and detangler',
#  'redken travel size color extend blondage color depositing purple ',
#  'ulta watermelon 3in1 juice smoothie',
#  'paul mitchell travel size tea tree special ',
#  'dphue cool brunette ',
#  'redken travel size color extend magnetics ',
#  'babo botanicals online only swim sport ',
#  'sheamoisture raw shea butter extramoisture detangler',
#  'ouidad curl immersion coconut cleansing  no lather',
#  'eva nyc mane magic 10in1 ',
#  'not your mothers passion fruit kombucha awapuhi ginger youth revival ',
#  'alterna caviar antiaging restructuring bond repair ',
#  'matrix biolage raw recover ',
#  'chi keratin reconstructing ',
#  'pacifica pineapple curls curl defining ',
#  'ogx quenching coconut curls ',
#  'keracolor travel size color clenditioner',
#  'dphue cool blonde ',
#  'frank body stimulating scalp scrub',
#  'hask keratin protein smoothing deep  packette',
#  'paul mitchell travel size tea tree special ',
#  'matrix biolage advanced oil renew ',
#  'fairy tales super charge detangling ',
#  'txtr by cantu acv tea tree soothing ',
#  'babo botanicals online only smoothing ',
#  'babo botanicals online only moisturizing baby  wash',
#  'chi aloe vera with agave nectar detangling ',
#  'biosilk silk therapy ',
#  'pacifica pineapple curls curl defining ',
#  'ogx quenching coconut curls curling butter  or ',
#  'psssst travel size instant dry   for normaloily hair',
#  'matrix biolage raw recover ',
#  'sheamoisture 100 virgin coconut oil daily hydration ',
#  'bumble and bumble online only bbquenching ',
#  'hask keratin protein smoothing ',
#  'ogx coconut miracle oil ',
#  'hask chia seed volumizing dry ',
#  'matrix biolage raw nourish ',
#  'drybar southern belle volumeboosting ',
#  'tigi travel size bed head rockaholic dirty secret dry ',
#  'sexy hair hair laundry dry ',
#  'alterna caviar antiaging smoothing antifrizz ',
#  'bumble and bumble online only bbquenching ',
#  'john frieda radiant red boosting ',
#  'hair food honey apricot sulfate free moisture ',
#  'mixed chicks deep ',
#  'matrix biolage raw uplift ',
#  'aquage color protecting ',
#  'redken travel size color extend blondage color depositing purple ',
#  'joico blonde life violet ',
#  'loral ever deep nourish conditoner',
#  'drybar detox dry ',
#  'ouidad playcurl volumizing ',
#  'not your mothers travel size clean freak dry ',
#  'babo botanicals online only smoothing  wash',
#  'sheamoisture raw shea butter moisture retention ',
#  'nexxus humectress ing mist for normal to dry hair',
#  'grow gorgeous online only hair density  intense',
#  'fairy tales super charge detangling ',
#  'not your mothers plump for joy thickening ',
#  'brite make me pastel pink ',
#  'tigi bed head for men daily clean up ',
#  'sexy hair curl enhancing ',
#  'nexxus emergence  for weak and damaged hair',
#  'ouidad water works clarifying ',
#  'living proof travel size perfect hair day phd ',
#  'sheamoisture 100 virgin coconut oil daily hydration ',
#  'sheamoisture manuka honey mafura oil intensive hydration ',
#  'igk thirsty girl coconut milk antifrizz ',
#  'aquage smoothing ',
#  'unwash dry cleanser',
#  'txtr by cantu leavein   ',
#  'john frieda frizz ease beyond smooth frizz immunity ',
#  'bumble and bumble surf  rinse ',
#  'sexy hair curl enhancing ',
#  'the one by frederic fekkai the universal one everyday ',
#  'viviscal densifying ',
#  'hair food honey apricot sulfate free moisture ',
#  'unwash antiresidue cleanse',
#  'igk thirsty girl coconut milk antifrizz ',
#  'biosilk silk therapy ',
#  'bumble and bumble online only bbfull potential ',
#  'bumble and bumble bb pretapowder tres invisible nourishing dry  with hibiscus extract',
#  'chi aloe vera with agave nectar curl enhancing ',
#  'tresemme moisture rich  with pump',
#  'maui moisture thicken restore bamboo fibers ',
#  'joico joifull volumizing ',
#  'tresemme moisture rich  with pump',
#  'pureology travel size hydrate sheer ',
#  'brite make me pastel pink ',
#  'loral everpure moisture ',
#  'lanza color care debrass blue ',
#  'living proof travel size full ',
#  'hask argan oil repairing deep  packette',
#  'john frieda luxurious volume thickening ',
#  'ogx extra strength tea tree mint ',
#  'ouidad playcurl volumizing ',
#  'ogx quenching coconut curls ',
#  'chi keratin reconstructing ',
#  'system professional color save ',
#  'sheamoisture african water mint ginger detox refresh hair scalp ',
#  'love beauty and planet smooth and serene argan oil lavender ',
#  'batiste pink pineapple dry  fruity carefree',
#  'paul mitchell travel size awapuhi wild ginger moisturizing lather ',
#  'jack black doubleheader   ',
#  'not your mothers beach babe moisturizing ',
#  'redken pillow proof two day extender dry ',
#  'klorane nourishing  with mango butter',
#  'got 2b fresh it up tropical boost dry ',
#  'carols daughter monoi repairing ',
#  'aquage vitalizing ',
#  'maui moisture heal hydrate shea butter ',
#  'sheamoisture african black soap bamboo charcoal deep cleansing ',
#  'bumble and bumble online only bbmending ',
#  'not your mothers passion fruit kombucha awapuhi ginger youth revival ',
#  'redken travel size all soft ',
#  'devacurl travel size lowpoo delight weightless waves mild lather cleanser',
#  'pureology travel size hydrate sheer ',
#  'hempz pure hemp ultrahydrating healthy herbal hair mask deep ',
#  'fairy tales lifeguard clarifying ',
#  'maui moisture curl quench coconut oil ',
#  'sheamoisture purple rice water ',
#  'carols daughter monoi repairing ',
#  'not your mothers beach babe moisturizing ',
#  'loral everpure moisture ',
#  'aquage seaextend silkening oil foam',
#  'living proof ban brassiness mini transformation kit for blondes highlights',
#  'hask keratin protein smoothing ',
#  'redken travel size frizz dismiss sulfatefree ',
#  'psssst texture and body dry  for fine hair',
#  'alterna caviar antiaging smoothing antifrizz ',
#  'batiste travel size hint of color dry ',
#  'matrix biolage advanced oil renew ',
#  'lanza healing remedy scalp balancing ',
#  'maui moisture thicken restore bamboo fibers ',
#  'jack black true volume thickening ',
#  'living proof travel size perfect hair day phd ',
#  'pravana intense therapy nourish lightweight healing ',
#  'john frieda radiant red boosting ',
#  'redken travel size frizz dismiss sulfatefree ',
#  'eva nyc clean it up ',
#  'rusk hydrate01  for dry hair',
#  'kiehls since 1851 amino acid ',
#  'house 99 by david beckham polish up invigorating body hair wash',
#  'drybar detox brunettes dry ',
#  'loral everpure volume ',
#  'maui moisture color protection sea minerals ',
#  'klorane  with quinine and b vitamins',
#  'klorane hydrating mango butter trial kit',
#  'eva nyc soften up ',
#  'joico joifull volumizing ',
#  'bumble and bumble online only bbmending ',
#  'dphue cool brunette ',
#  'bumble and bumble bbcurl ',
#  'bosley online only bosdefense nourishing  for non colortreated hair',
#  'pravana intense therapy cleanse lightweight healing ',
#  'sheamoisture purple rice water strength color care ',
#  'alterna bamboo volume abundant volume ',
#  'philosophy fresh  dry ',
#  'batiste hint of color dry  divine dark',
#  'redken travel size all soft ',
#  'maui moisture heal hydrate shea butter ',
#  'batiste hydrating dry ',
#  'john frieda luxurious volume thickening ',
#  'unwash charcoal detox scalp scrub',
#  'ogx renewing argan oil of morocco intense moisturizing treatment',
#  'living proof travel size perfect hair day phd triple detox ',
#  'wella nutricurls  for waves',
#  'nioxin scalp optimizing cleanser',
#  'system professional repair ',
#  'living proof travel size full ',
#  'matrix travel size biolage hydrasource ',
#  'rusk repair01  for dry hair',
#  'paul mitchell travel size awapuhi wild ginger keratin  rinse',
#  'not your mothers travel size beach babe texturizing dry ',
#  'maui moisture curl quench coconut oil ',
#  'john frieda frizz ease beyond smooth frizz immunity ',
#  'the one by frederic fekkai the universal one everyday ',
#  'drybar southern belle volumeboosting ',
#  'phyto phytocyane densifying treatment ',
#  'we are paradoxx online only secret weapon 3in1 ',
#  'marc anthony frizz sealing ',
#  'klorane nourishing  with mango butter',
#  'klorane oil control  with nettle',
#  'keranique damage control scalp replenishing for dry damaged hair',
#  'pravana travel size the perfect blonde ',
#  'biosilk hydrating therapy ',
#  'igk travel size jet lag invisible dry ',
#  'macadamia professional weightless moisture ing mist',
#  'hair food tea tree oil lavender sulfate free ',
#  'socozy online only splash swim 3 in 1    body wash',
#  'not your mothers clean freak tinted dry light to dark brown',
#  'kenra professional frizz control ',
#  'redken travel size color extend ',
#  'joico blonde life violet ',
#  'viviscal densifying ',
#  'pravana nevo moisture rich sulfatefree ',
#  'batiste dry ',
#  'hask monoi coconut oil nourishing deep  packette',
#  'paul mitchell travel size tea tree lavender mint moisturizing ',
#  'pacifica salty waves texturizing ',
#  'hask orchid white truffle moisture rich ',
#  'hask unwined red wine inspired dry ',
#  'redken travel size extreme ',
#  'matrix online only total results length goals sulfatefree  for extensions',
#  'matrix biolage raw scalp care rebalance ',
#  'redken travel size extreme ',
#  'love beauty and planet murumuru butter and rose blooming color ',
#  'paul mitchell travel size tea tree special color ',
#  'pacifica coconut damage mask',
#  'matrix travel size biolage colorlast purple ',
#  'unwash travel size dry cleanser',
#  'matrix online only total results length goals  for extensions',
#  'maui moisture color protection sea minerals ',
#  'nexxus diametress volume  for fine and flat hair',
#  'paul mitchell travel size tea tree lemon sage thickening ',
#  'babo botanicals online only moisturizing ',
#  'sun bum online only sun bum hair tripper',
#  'carols daughter black vanilla moisture shine leavein ',
#  'keranique curl preserve nourishing keratin  for curly textured hair',
#  'sheamoisture green coconut activated charcoal buildup blaster',
#  'mizani scalp care pyrithione zinc antidandruff ',
#  'devacurl travel size one  delight weightless waves ',
#  'hask chamomile argan oil blonde care ',
#  'hask cucumber aloe water ',
#  'redken travel size color extend ',
#  'living proof online only perfect hair day system bundle',
#  'bumble and bumble travel size bb pretapowder tres invisible dry  with french pink clay',
#  'matrix travel size biolage hydrasource ',
#  'sheamoisture green coconut activated charcoal exfoliating hair mud',
#  'hask superfruit healthy deep ',
#  'thick head online only clear head antithinning 2in1   ',
#  'pureology travel size strength cure ',
#  'flora curl online only curl refresh clay wash',
#  'hask unwined caberernet sauvignon deep ',
#  'matrix total results keep me vivid trial kit',
#  'babo botanicals online only smoothing detangling ',
#  'ag hair simply dry ',
#  'duke cannon supply co online only news anchor 2 in 1 hair wash tea tree formula',
#  'hask cactus water ',
#  'noughty wave hello curl defining ',
#  'marc anthony curl defining ',
#  'kenra professional frizz control ',
#  'mizani true textures  cleansing ',
#  'living proof travel size no frizz ',
#  'philosophy pure grace dry ',
#  'love beauty and planet smooth and serene argan oil lavender ',
#  'matrix travel size total results so silver ',
#  'loral everpure volume ',
#  'carols daughter cactus rose water sulfatefree ',
#  'matrix style link mineral play back dry ',
#  'paul mitchell travel size tea tree special color ',
#  'rusk platinumx ',
#  'aquage dry ',
#  'sheamoisture red palm oil cocoa butter  or  ',
#  'carols daughter cactus rose water lightweight ',
#  'system professional color save ',
#  'hask cactus water ',
#  'john frieda sheer blonde color renew tone restoring ',
#  'keranique curl preserve scalp nourishing  for curly textured hair',
#  'punky colour intrabond revitalizing leavein  ',
#  'paul mitchell invisiblewear brunette dry ',
#  'pureology travel size style protect refresh go dry ',
#  'sexy hair strong sexy hair strengthening ',
#  'sheamoisture green coconut activated charcoal ',
#  'pureology travel size strength cure ',
#  'loral ever deep nourish ',
#  'biosilk silk therapy with organic coconut oil moisturizing ',
#  'tresemme keratin smooth ',
#  'bosley online only bosdefense volumizing  for non colortreated hair',
#  'neuma neublonde detangling rinse',
#  'dphue travel size apple cider vinegar scalp scrub',
#  'hask unwined brut ros deep ',
#  'hask unwined pinot grigio deep ',
#  'hask orchid white truffle moisture rich ',
#  'marc anthony deep repair aloe vera jasmine oil deep ing packet',
#  'not your mothers travel size plump for joy body building dry ',
#  'socozy online only cinch 3 in 1    body wash',
#  'hair food vanilla bean jasmine sulfate free smoothing ',
#  'system professional hydrate ',
#  'carols daughter black vanilla moisture shine hydrating ',
#  'love beauty and planet murumuru butter and rose blooming color ',
#  'hair food tea tree oil lavender sulfate free purifying ',
#  'ogx coconut miracle oil dry ',
#  'drybar travel size on the rocks clarifying charcoal ',
#  'pacifica salty waves texturizing ',
#  'klorane soothing antiirritating  with peony',
#  'loral everpure blonde ',
#  'ogx antibreakage keratin oil ',
#  'house 99 by david beckham twice as smart taming   ',
#  'drybar online only travel size detox brunettes dry ',
#  'sexy hair healthy mini trio',
#  'fairy tales curlyq ',
#  'bumble and bumble travel size bbthickening ',
#  'paul mitchell travel size clarifying  three',
#  'its a 10 blow dry glossing glaze ',
#  'noughty wave hello curl defining ',
#  'maui moisture lightweight hydration hibiscus water ',
#  'nexxus emergence  for weak and damaged hair',
#  'neuma neublonde platinum ',
#  'loral everpure blonde ',
#  'living proof travel size restore ',
#  'living proof travel size no frizz ',
#  'love beauty and planet volume and bounty coconut water mimosa flower ',
#  'hask tea tree rosemary ',
#  'its a 10 miracle blow dry glossing ',
#  'kenra professional travel size volume dry ',
#  'ogx ever straight brazilian keratin therapy ',
#  'maui moisture lightweight hydration hibiscus water ',
#  'jack black nourishing hair scalp ',
#  'kyn rose gold ',
#  'hask argan dry ',
#  'ogx orchid oil ',
#  'ogx orchid oil ',
#  'unwash curls dry cleanser',
#  'sheamoisture coconut hibiscus curl shine ',
#  'biosilk silk therapy with organic coconut oil moisturizing ',
#  'nexxus blonde assure ',
#  'love beauty and planet volume and bounty coconut water mimosa flower ',
#  'pureology travel size strength cure best blonde purple ',
#  'hask biotin thickening dry ',
#  'john frieda sheer blonde color renew tone restoring  ',
#  'redken travel size high rise volume lifting ',
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# ### Get rid of any product catagory items that do not have relevant words

# %%
required_product_words = ['shampoo', 'conditioner', 'poo', 'lopoo', 'nopoo', 'plop', 'diffuse', 'condish', 'STC',
                         'conditioner', 'gel', 'product', 'styler', 'LO', 'Leave in', 'RO']

# %%
searchfor = required_product_words
relevant_products_column_df = df[df['products'].str.contains('hair' or 'shampoo' or 'conditioner' or 'poo' or 'lopoo' or 'nopoo' or 'plop' or 'diffuse' or 'condish' or 'STC' or
                         'conditioner' or 'gel' or 'product' or 'styler' or 'LO' or 'Leave in' or 'RO', na =False)] 
relevant_products_column_df.reset_index(drop=True, inplace=True)
relevant_products_column_df.head(10)
# Out:
#   curl_pattern density porosity texture  \
# 0           2b     NaN      NaN  coarse
# 1           4a     NaN      NaN     NaN
# 2           3a     NaN      NaN     NaN
# 3           3b     NaN      NaN     NaN
# 4           2c   thick     high    fine
# 5           3a   thick     high    fine
# 6           4a     NaN      NaN     NaN
# 7           2b    thin      NaN     NaN
# 8           3a    thin      NaN     NaN
# 9           2b     NaN     high    fine
#
#                                             products  curl_catagory
# 0  poo deva nopoo co wash suave naturals rinse ou...              2
# 1  deeplyenrichedoils com show me some love check...              7
# 2  hair type and lots of it hair color ranges fro...              4
# 3  hair type and lots of it hair color ranges fro...              5
# 4   mostly with some and a very strange curl wave...              3
# 5   mostly with some and a very strange curl wave...              4
# 6   demcalicurls hair type big chop june 2006 rel...              7
# 7  former then modified now too lazy p type i k a...              2
# 8  former then modified now too lazy p type i k a...              4
# 9   very hair low poo living proof restore shampo...              2

# %%
# Just for Funsies check how many relevant full signatures we have'
# 339!!! Not a lot
full_sets_only_df = relevant_products_column_df.dropna()
print(full_sets_only_df.shape)
full_sets_only_df.head()
# Out:
# (339, 6)
#    curl_pattern density porosity texture  \
# 4            2c   thick     high    fine
# 5            3a   thick     high    fine
# 11           2c  medium     high    fine
# 14           2a  medium      low    fine
# 16           3b   thick      low  coarse
#
#                                              products  curl_catagory
# 4    mostly with some and a very strange curl wave...              3
# 5    mostly with some and a very strange curl wave...              4
# 11  wavy  fii on the fia system current products l...              3
# 14        still working on a solid hair care routine               1
# 16   my hair  strands virgin hair armpit length cu...              5

# %% [markdown]
# ### Psuedocode plan
# #### Do steps 1-4 in this notebook
#
#
# 1. Assume only relevant words are now in products.
#
# 2. deal with acronymns in products now.
#       get a list of name brands and extract common names from in front of products like Kinky Curly CC or KCCC both correct to Kinky Curly Curling Custard
#
# 3. create 1-6 ngrams from each (completly cleaned of acronymns and for relevance) products row and then cycle through those and compare to a list of products do fuzzy matching and if the match is above X percent assign that product to a new list which will become a new column. Asign nan to ones where nothing comes up at all'
#
# 4. Inspect new products only catagory to make sure everythign looks like products
#
# 5. Perform TFIDF and run the models again looking at all scoring metrics
#
# 6. If time correct improperly balanced classes with up or downsampling and run again

# %% [markdown]
# ---

# %% [markdown]
# ### Step 2
# #### Deal with acronymns

# %%
acronymn_dict = {'jessicurl': 'jc',
                'kinky curly curling custard': ['KCCC', 'KC curling custard', 'kinky curly cc', 'kc custard', 'kinky curly custard'],
                'la Looks Sport Look Gel': ['la looks', 'la looks gel', 'la looks sport gel', 'la look sports gel'],
                'kinky curly knot today': ['kc knot today', 'kinky curly kt', 'kckt', 'kinky curly not today', 'kc not today', 'kcnt', 'kinky curly nt'],
                'as i am coconut cowash': ['as i am coconut co-wash', 'as i am coconut co wash', 'asiam coconut cowash', 'asiam coconut co wash', 'asiam cowash', 'asiam cowash'],
                'herbal essence totally twisted mousse': ['he tt', 'hett', 'he totally twisted', 'herbal essence tt', 'he mousse', 'he moose', 'herbal essence moose', 'herbal essence mousse'],
                'devacurl': 'deva'
                }

# %%
# Check on frequency of n-grams

def generate_ngrams(s, n):
    '''
    s- the string you want to parse into ngrams
    n - the number of n for each ngrams
    '''
    # Convert to lowercases
    s = s.lower()
    
    # Replace all none alphanumeric characters with spaces
    s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
    
    # Break sentence in the token, remove empty tokens
    tokens = [token for token in s.split(" ") if token != ""]
    
    # Use the zip function to help us generate n-grams
    # Concatentate the tokens into ngrams and return
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
# all quimtagrams in the product set

result = [generate_ngrams(x, 5) for x in relevant_products_column_df['products']]
result
# Out:
# [['poo deva nopoo co wash',
#   'deva nopoo co wash suave',
#   'nopoo co wash suave naturals',
#   'co wash suave naturals rinse',
#   'wash suave naturals rinse out',
#   'suave naturals rinse out leave',
#   'naturals rinse out leave in',
#   'rinse out leave in deva',
#   'out leave in deva one',
#   'leave in deva one condition',
#   'in deva one condition products',
#   'deva one condition products deva',
#   'one condition products deva arcangell',
#   'condition products deva arcangell deva',
#   'products deva arcangell deva mister',
#   'deva arcangell deva mister right',
#   'arcangell deva mister right c',
#   'deva mister right c overly',
#   'mister right c overly porous',
#   'right c overly porous hair'],
#  ['deeplyenrichedoils com show me some',
#   'com show me some love',
#   'show me some love check',
#   'me some love check out',
#   'some love check out my',
#   'love check out my website',
#   'check out my website your',
#   'out my website your vision',
#   'my website your vision will',
#   'website your vision will become',
#   'your vision will become clear',
#   'vision will become clear only',
#   'will become clear only when',
#   'become clear only when you',
#   'clear only when you look',
#   'only when you look into',
#   'when you look into your',
#   'you look into your heart',
#   'look into your heart who',
#   'into your heart who looks',
#   'your heart who looks outside',
#   'heart who looks outside dreams',
#   'who looks outside dreams who',
#   'looks outside dreams who looks',
#   'outside dreams who looks inside',
#   'dreams who looks inside awakens',
#   'who looks inside awakens hair',
#   'looks inside awakens hair type',
#   'inside awakens hair type products',
#   'awakens hair type products aloe',
#   'hair type products aloe vera',
#   'type products aloe vera juice',
#   'products aloe vera juice glycerin',
#   'aloe vera juice glycerin shea',
#   'vera juice glycerin shea butter',
#   'juice glycerin shea butter jamaican',
#   'glycerin shea butter jamaican black',
#   'shea butter jamaican black castor',
#   'butter jamaican black castor oil',
#   'jamaican black castor oil grape',
#   'black castor oil grape seed',
#   'castor oil grape seed oil',
#   'oil grape seed oil coconut',
#   'grape seed oil coconut oil',
#   'seed oil coconut oil rosemary',
#   'oil coconut oil rosemary essential',
#   'coconut oil rosemary essential oil',
#   'oil rosemary essential oil tea',
#   'rosemary essential oil tea tree',
#   'essential oil tea tree oil',
#   'oil tea tree oil and',
#   'tea tree oil and may',
#   'tree oil and may more'],
#  ['hair type and lots of',
#   'type and lots of it',
#   'and lots of it hair',
#   'lots of it hair color',
#   'of it hair color ranges',
#   'it hair color ranges from',
#   'hair color ranges from dark',
#   'color ranges from dark brown',
#   'ranges from dark brown to',
#   'from dark brown to light',
#   'dark brown to light brown',
#   'brown to light brown with',
#   'to light brown with blonde',
#   'light brown with blonde and',
#   'brown with blonde and red',
#   'with blonde and red highlights',
#   'blonde and red highlights thrown',
#   'and red highlights thrown in',
#   'red highlights thrown in from',
#   'highlights thrown in from the',
#   'thrown in from the sun',
#   'in from the sun haha',
#   'from the sun haha i',
#   'the sun haha i ve',
#   'sun haha i ve never',
#   'haha i ve never had',
#   'i ve never had two',
#   've never had two people',
#   'never had two people call',
#   'had two people call it',
#   'two people call it the',
#   'people call it the same',
#   'call it the same color',
#   'it the same color p',
#   'the same color p started',
#   'same color p started 3',
#   'color p started 3 1',
#   'p started 3 1 09',
#   'started 3 1 09 and',
#   '3 1 09 and i',
#   '1 09 and i am',
#   '09 and i am loving',
#   'and i am loving it',
#   'i am loving it i',
#   'am loving it i can',
#   'loving it i can t',
#   'it i can t wait',
#   'i can t wait to',
#   'can t wait to see',
#   't wait to see the',
#   'wait to see the results',
#   'to see the results after',
#   'see the results after a',
#   'the results after a couple',
#   'results after a couple of',
#   'after a couple of months',
#   'a couple of months i',
#   'couple of months i ve',
#   'of months i ve become',
#   'months i ve become a',
#   'i ve become a curly',
#   've become a curly girl',
#   'become a curly girl fanatic',
#   'a curly girl fanatic love7'],
#  ['hair type and lots of',
#   'type and lots of it',
#   'and lots of it hair',
#   'lots of it hair color',
#   'of it hair color ranges',
#   'it hair color ranges from',
#   'hair color ranges from dark',
#   'color ranges from dark brown',
#   'ranges from dark brown to',
#   'from dark brown to light',
#   'dark brown to light brown',
#   'brown to light brown with',
#   'to light brown with blonde',
#   'light brown with blonde and',
#   'brown with blonde and red',
#   'with blonde and red highlights',
#   'blonde and red highlights thrown',
#   'and red highlights thrown in',
#   'red highlights thrown in from',
#   'highlights thrown in from the',
#   'thrown in from the sun',
#   'in from the sun haha',
#   'from the sun haha i',
#   'the sun haha i ve',
#   'sun haha i ve never',
#   'haha i ve never had',
#   'i ve never had two',
#   've never had two people',
#   'never had two people call',
#   'had two people call it',
#   'two people call it the',
#   'people call it the same',
#   'call it the same color',
#   'it the same color p',
#   'the same color p started',
#   'same color p started 3',
#   'color p started 3 1',
#   'p started 3 1 09',
#   'started 3 1 09 and',
#   '3 1 09 and i',
#   '1 09 and i am',
#   '09 and i am loving',
#   'and i am loving it',
#   'i am loving it i',
#   'am loving it i can',
#   'loving it i can t',
#   'it i can t wait',
#   'i can t wait to',
#   'can t wait to see',
#   't wait to see the',
#   'wait to see the results',
#   'to see the results after',
#   'see the results after a',
#   'the results after a couple',
#   'results after a couple of',
#   'after a couple of months',
#   'a couple of months i',
#   'couple of months i ve',
#   'of months i ve become',
#   'months i ve become a',
#   'i ve become a curly',
#   've become a curly girl',
#   'become a curly girl fanatic',
#   'a curly girl fanatic love7'],
#  ['mostly with some and a',
#   'with some and a very',
#   'some and a very strange',
#   'and a very strange curl',
#   'a very strange curl wave',
#   'very strange curl wave pattern',
#   'strange curl wave pattern started',
#   'curl wave pattern started properly',
#   'wave pattern started properly as',
#   'pattern started properly as of',
#   'started properly as of 6',
#   'properly as of 6 31',
#   'as of 6 31 2009',
#   'of 6 31 2009 cowash',
#   '6 31 2009 cowash suave',
#   '31 2009 cowash suave naturals',
#   '2009 cowash suave naturals ocean',
#   'cowash suave naturals ocean breeze',
#   'suave naturals ocean breeze or',
#   'naturals ocean breeze or juicy',
#   'ocean breeze or juicy green',
#   'breeze or juicy green apple',
#   'or juicy green apple rinse',
#   'juicy green apple rinse out',
#   'green apple rinse out burt',
#   'apple rinse out burt s',
#   'rinse out burt s bees',
#   'out burt s bees super',
#   'burt s bees super shiny',
#   's bees super shiny leave',
#   'bees super shiny leave in',
#   'super shiny leave in live',
#   'shiny leave in live clean',
#   'leave in live clean intense',
#   'in live clean intense moisturizing',
#   'live clean intense moisturizing gel',
#   'clean intense moisturizing gel hesmu',
#   'intense moisturizing gel hesmu right',
#   'moisturizing gel hesmu right now',
#   'gel hesmu right now growing',
#   'hesmu right now growing hair',
#   'right now growing hair past',
#   'now growing hair past shoulder',
#   'growing hair past shoulder length',
#   'hair past shoulder length looking',
#   'past shoulder length looking to',
#   'shoulder length looking to take',
#   'length looking to take decent',
#   'looking to take decent hair',
#   'to take decent hair picture',
#   'take decent hair picture my',
#   'decent hair picture my avatar',
#   'hair picture my avatar is',
#   'picture my avatar is my',
#   'my avatar is my first',
#   'avatar is my first day',
#   'is my first day of'],
#  ['mostly with some and a',
#   'with some and a very',
#   'some and a very strange',
#   'and a very strange curl',
#   'a very strange curl wave',
#   'very strange curl wave pattern',
#   'strange curl wave pattern started',
#   'curl wave pattern started properly',
#   'wave pattern started properly as',
#   'pattern started properly as of',
#   'started properly as of 6',
#   'properly as of 6 31',
#   'as of 6 31 2009',
#   'of 6 31 2009 cowash',
#   '6 31 2009 cowash suave',
#   '31 2009 cowash suave naturals',
#   '2009 cowash suave naturals ocean',
#   'cowash suave naturals ocean breeze',
#   'suave naturals ocean breeze or',
#   'naturals ocean breeze or juicy',
#   'ocean breeze or juicy green',
#   'breeze or juicy green apple',
#   'or juicy green apple rinse',
#   'juicy green apple rinse out',
#   'green apple rinse out burt',
#   'apple rinse out burt s',
#   'rinse out burt s bees',
#   'out burt s bees super',
#   'burt s bees super shiny',
#   's bees super shiny leave',
#   'bees super shiny leave in',
#   'super shiny leave in live',
#   'shiny leave in live clean',
#   'leave in live clean intense',
#   'in live clean intense moisturizing',
#   'live clean intense moisturizing gel',
#   'clean intense moisturizing gel hesmu',
#   'intense moisturizing gel hesmu right',
#   'moisturizing gel hesmu right now',
#   'gel hesmu right now growing',
#   'hesmu right now growing hair',
#   'right now growing hair past',
#   'now growing hair past shoulder',
#   'growing hair past shoulder length',
#   'hair past shoulder length looking',
#   'past shoulder length looking to',
#   'shoulder length looking to take',
#   'length looking to take decent',
#   'looking to take decent hair',
#   'to take decent hair picture',
#   'take decent hair picture my',
#   'decent hair picture my avatar',
#   'hair picture my avatar is',
#   'picture my avatar is my',
#   'my avatar is my first',
#   'avatar is my first day',
#   'is my first day of'],
#  ['demcalicurls hair type big chop',
#   'hair type big chop june',
#   'type big chop june 2006',
#   'big chop june 2006 relaxer',
#   'chop june 2006 relaxer free',
#   'june 2006 relaxer free since',
#   '2006 relaxer free since november',
#   'relaxer free since november 2006',
#   'free since november 2006 favorite',
#   'since november 2006 favorite products',
#   'november 2006 favorite products ampro',
#   '2006 favorite products ampro pro',
#   'favorite products ampro pro styl',
#   'products ampro pro styl protein',
#   'ampro pro styl protein styling',
#   'pro styl protein styling gel',
#   'styl protein styling gel hold',
#   'protein styling gel hold 7',
#   'styling gel hold 7 redken',
#   'gel hold 7 redken soft',
#   'hold 7 redken soft curls',
#   '7 redken soft curls shampoo',
#   'redken soft curls shampoo and',
#   'soft curls shampoo and conditioner',
#   'curls shampoo and conditioner sta',
#   'shampoo and conditioner sta sof',
#   'and conditioner sta sof fro',
#   'conditioner sta sof fro hair',
#   'sta sof fro hair scalp',
#   'sof fro hair scalp spray',
#   'fro hair scalp spray extra',
#   'hair scalp spray extra dry',
#   'scalp spray extra dry sta',
#   'spray extra dry sta sof',
#   'extra dry sta sof fro',
#   'dry sta sof fro rub',
#   'sta sof fro rub on',
#   'sof fro rub on hair',
#   'fro rub on hair scalp',
#   'rub on hair scalp conditioner',
#   'on hair scalp conditioner extra',
#   'hair scalp conditioner extra dry',
#   'scalp conditioner extra dry staying',
#   'conditioner extra dry staying strong',
#   'extra dry staying strong in',
#   'dry staying strong in this',
#   'staying strong in this curly',
#   'strong in this curly revolution',
#   'in this curly revolution is',
#   'this curly revolution is strutting',
#   'curly revolution is strutting my',
#   'revolution is strutting my reguardless',
#   'is strutting my reguardless of',
#   'strutting my reguardless of what',
#   'my reguardless of what everyone',
#   'reguardless of what everyone else',
#   'of what everyone else s',
#   'what everyone else s opinion',
#   'everyone else s opinion is'],
#  ['former then modified now too',
#   'then modified now too lazy',
#   'modified now too lazy p',
#   'now too lazy p type',
#   'too lazy p type i',
#   'lazy p type i k',
#   'p type i k and',
#   'type i k and still',
#   'i k and still rather',
#   'k and still rather annoyed',
#   'and still rather annoyed with',
#   'still rather annoyed with my',
#   'rather annoyed with my hair',
#   'annoyed with my hair p'],
#  ['former then modified now too',
#   'then modified now too lazy',
#   'modified now too lazy p',
#   'now too lazy p type',
#   'too lazy p type i',
#   'lazy p type i k',
#   'p type i k and',
#   'type i k and still',
#   'i k and still rather',
#   'k and still rather annoyed',
#   'and still rather annoyed with',
#   'still rather annoyed with my',
#   'rather annoyed with my hair',
#   'annoyed with my hair p'],
#  ['very hair low poo living',
#   'hair low poo living proof',
#   'low poo living proof restore',
#   'poo living proof restore shampoo',
#   'living proof restore shampoo rinse',
#   'proof restore shampoo rinse out',
#   'restore shampoo rinse out living',
#   'shampoo rinse out living proof',
#   'rinse out living proof restore',
#   'out living proof restore conditioner',
#   'living proof restore conditioner leave',
#   'proof restore conditioner leave in',
#   'restore conditioner leave in living',
#   'conditioner leave in living proof',
#   'leave in living proof curl',
#   'in living proof curl leave',
#   'living proof curl leave in',
#   'proof curl leave in or',
#   'curl leave in or garnier',
#   'leave in or garnier 1',
#   'in or garnier 1 minute',
#   'or garnier 1 minute mask',
#   'garnier 1 minute mask papaya',
#   '1 minute mask papaya treatments',
#   'minute mask papaya treatments restore',
#   'mask papaya treatments restore repair',
#   'papaya treatments restore repair leave',
#   'treatments restore repair leave in',
#   'restore repair leave in \xa0',
#   'repair leave in \xa0 styling',
#   'leave in \xa0 styling \xa0living',
#   'in \xa0 styling \xa0living proof',
#   '\xa0 styling \xa0living proof in',
#   'styling \xa0living proof in shower',
#   '\xa0living proof in shower styler',
#   'proof in shower styler with',
#   'in shower styler with ouidad',
#   'shower styler with ouidad advanced',
#   'styler with ouidad advanced climate',
#   'with ouidad advanced climate control',
#   'ouidad advanced climate control gel',
#   'advanced climate control gel stronger',
#   'climate control gel stronger hold'],
#  ['very hair low poo living',
#   'hair low poo living proof',
#   'low poo living proof restore',
#   'poo living proof restore shampoo',
#   'living proof restore shampoo rinse',
#   'proof restore shampoo rinse out',
#   'restore shampoo rinse out living',
#   'shampoo rinse out living proof',
#   'rinse out living proof restore',
#   'out living proof restore conditioner',
#   'living proof restore conditioner leave',
#   'proof restore conditioner leave in',
#   'restore conditioner leave in living',
#   'conditioner leave in living proof',
#   'leave in living proof curl',
#   'in living proof curl leave',
#   'living proof curl leave in',
#   'proof curl leave in or',
#   'curl leave in or garnier',
#   'leave in or garnier 1',
#   'in or garnier 1 minute',
#   'or garnier 1 minute mask',
#   'garnier 1 minute mask papaya',
#   '1 minute mask papaya treatments',
#   'minute mask papaya treatments restore',
#   'mask papaya treatments restore repair',
#   'papaya treatments restore repair leave',
#   'treatments restore repair leave in',
#   'restore repair leave in \xa0',
#   'repair leave in \xa0 styling',
#   'leave in \xa0 styling \xa0living',
#   'in \xa0 styling \xa0living proof',
#   '\xa0 styling \xa0living proof in',
#   'styling \xa0living proof in shower',
#   '\xa0living proof in shower styler',
#   'proof in shower styler with',
#   'in shower styler with ouidad',
#   'shower styler with ouidad advanced',
#   'styler with ouidad advanced climate',
#   'with ouidad advanced climate control',
#   'ouidad advanced climate control gel',
#   'advanced climate control gel stronger',
#   'climate control gel stronger hold'],
#  ['wavy fii on the fia',
#   'fii on the fia system',
#   'on the fia system current',
#   'the fia system current products',
#   'fia system current products low',
#   'system current products low poo',
#   'current products low poo jc',
#   'products low poo jc gls',
#   'low poo jc gls or',
#   'poo jc gls or jc',
#   'jc gls or jc hcc',
#   'gls or jc hcc co',
#   'or jc hcc co wash',
#   'jc hcc co wash suave',
#   'hcc co wash suave naturals',
#   'co wash suave naturals coconut',
#   'wash suave naturals coconut also',
#   'suave naturals coconut also do',
#   'naturals coconut also do water',
#   'coconut also do water wash',
#   'also do water wash rinse',
#   'do water wash rinse out',
#   'water wash rinse out ao',
#   'wash rinse out ao gpb',
#   'rinse out ao gpb mop',
#   'out ao gpb mop c',
#   'ao gpb mop c hydrating',
#   'gpb mop c hydrating conditioner',
#   'mop c hydrating conditioner leave',
#   'c hydrating conditioner leave in',
#   'hydrating conditioner leave in kckt',
#   'conditioner leave in kckt stylers',
#   'leave in kckt stylers bb',
#   'in kckt stylers bb fsg',
#   'kckt stylers bb fsg brhg',
#   'stylers bb fsg brhg jc',
#   'bb fsg brhg jc oil',
#   'fsg brhg jc oil blend',
#   'brhg jc oil blend bb',
#   'jc oil blend bb hemp',
#   'oil blend bb hemp grapeseed',
#   'blend bb hemp grapeseed clary',
#   'bb hemp grapeseed clary sage',
#   'hemp grapeseed clary sage hair',
#   'grapeseed clary sage hair and',
#   'clary sage hair and body',
#   'sage hair and body butter',
#   'hair and body butter deep',
#   'and body butter deep treatments',
#   'body butter deep treatments nexxus',
#   'butter deep treatments nexxus emergencee',
#   'deep treatments nexxus emergencee pt',
#   'treatments nexxus emergencee pt jessicurl',
#   'nexxus emergencee pt jessicurl wdt',
#   'emergencee pt jessicurl wdt occasional',
#   'pt jessicurl wdt occasional acv',
#   'jessicurl wdt occasional acv rinses',
#   'wdt occasional acv rinses mod',
#   'occasional acv rinses mod since',
#   'acv rinses mod since june',
#   'rinses mod since june 2009'],
#  ['a href tickerfactory com target',
#   'href tickerfactory com target blank',
#   'tickerfactory com target blank napptural',
#   'com target blank napptural anniversary',
#   'target blank napptural anniversary 6',
#   'blank napptural anniversary 6 27',
#   'napptural anniversary 6 27 08',
#   'anniversary 6 27 08 hair',
#   '6 27 08 hair loves',
#   '27 08 hair loves ecostyler',
#   '08 hair loves ecostyler olive',
#   'hair loves ecostyler olive oil',
#   'loves ecostyler olive oil gel',
#   'ecostyler olive oil gel protein',
#   'olive oil gel protein conditioners',
#   'oil gel protein conditioners hair',
#   'gel protein conditioners hair hates',
#   'protein conditioners hair hates sulfates',
#   'conditioners hair hates sulfates daily',
#   'hair hates sulfates daily hair',
#   'hates sulfates daily hair drenchings',
#   'sulfates daily hair drenchings with',
#   'daily hair drenchings with water',
#   'hair drenchings with water gels',
#   'drenchings with water gels with',
#   'with water gels with alot',
#   'water gels with alot heavy',
#   'gels with alot heavy pvp',
#   'with alot heavy pvp s'],
#  ['a href tickerfactory com target',
#   'href tickerfactory com target blank',
#   'tickerfactory com target blank napptural',
#   'com target blank napptural anniversary',
#   'target blank napptural anniversary 6',
#   'blank napptural anniversary 6 27',
#   'napptural anniversary 6 27 08',
#   'anniversary 6 27 08 hair',
#   '6 27 08 hair loves',
#   '27 08 hair loves ecostyler',
#   '08 hair loves ecostyler olive',
#   'hair loves ecostyler olive oil',
#   'loves ecostyler olive oil gel',
#   'ecostyler olive oil gel protein',
#   'olive oil gel protein conditioners',
#   'oil gel protein conditioners hair',
#   'gel protein conditioners hair hates',
#   'protein conditioners hair hates sulfates',
#   'conditioners hair hates sulfates daily',
#   'hair hates sulfates daily hair',
#   'hates sulfates daily hair drenchings',
#   'sulfates daily hair drenchings with',
#   'daily hair drenchings with water',
#   'hair drenchings with water gels',
#   'drenchings with water gels with',
#   'with water gels with alot',
#   'water gels with alot heavy',
#   'gels with alot heavy pvp',
#   'with alot heavy pvp s'],
#  ['still working on a solid',
#   'working on a solid hair',
#   'on a solid hair care',
#   'a solid hair care routine'],
#  ['love1 hair type f ii',
#   'hair type f ii porous',
#   'type f ii porous likes',
#   'f ii porous likes protein',
#   'ii porous likes protein products',
#   'porous likes protein products still',
#   'likes protein products still experimenting'],
#  ['my hair strands virgin hair',
#   'hair strands virgin hair armpit',
#   'strands virgin hair armpit length',
#   'virgin hair armpit length curly',
#   'hair armpit length curly current',
#   'armpit length curly current products',
#   'length curly current products diy',
#   'curly current products diy shampoo',
#   'current products diy shampoo tresemme',
#   'products diy shampoo tresemme aloe',
#   'diy shampoo tresemme aloe conditioner',
#   'shampoo tresemme aloe conditioner it',
#   'tresemme aloe conditioner it s',
#   'aloe conditioner it s a',
#   'conditioner it s a 10',
#   'it s a 10 leave',
#   's a 10 leave in',
#   'a 10 leave in sweet',
#   '10 leave in sweet almond',
#   'leave in sweet almond oil',
#   'in sweet almond oil tresemme',
#   'sweet almond oil tresemme mousse',
#   'almond oil tresemme mousse current',
#   'oil tresemme mousse current length',
#   'tresemme mousse current length goal',
#   'mousse current length goal waist',
#   'current length goal waist length',
#   'length goal waist length curly'],
#  ['my hair crushed my dreams',
#   'hair crushed my dreams everyg',
#   'crushed my dreams everyg i',
#   'my dreams everyg i wanted',
#   'dreams everyg i wanted to',
#   'everyg i wanted to be',
#   'i wanted to be my',
#   'wanted to be my curly',
#   'to be my curly hair',
#   'be my curly hair was',
#   'my curly hair was the',
#   'curly hair was the death',
#   'hair was the death of',
#   'was the death of me',
#   'the death of me afro',
#   'death of me afro hair',
#   'of me afro hair type',
#   'me afro hair type mixture',
#   'afro hair type mixture of',
#   'hair type mixture of and'],
#  ['my hair crushed my dreams',
#   'hair crushed my dreams everyg',
#   'crushed my dreams everyg i',
#   'my dreams everyg i wanted',
#   'dreams everyg i wanted to',
#   'everyg i wanted to be',
#   'i wanted to be my',
#   'wanted to be my curly',
#   'to be my curly hair',
#   'be my curly hair was',
#   'my curly hair was the',
#   'curly hair was the death',
#   'hair was the death of',
#   'was the death of me',
#   'the death of me afro',
#   'death of me afro hair',
#   'of me afro hair type',
#   'me afro hair type mixture',
#   'afro hair type mixture of',
#   'hair type mixture of and'],
#  ['public fotki com kaymoore combo',
#   'fotki com kaymoore combo with',
#   'com kaymoore combo with in',
#   'kaymoore combo with in the',
#   'combo with in the front',
#   'with in the front hair',
#   'in the front hair goal',
#   'the front hair goal shoulder',
#   'front hair goal shoulder length',
#   'hair goal shoulder length and',
#   'goal shoulder length and curly',
#   'shoulder length and curly before',
#   'length and curly before april',
#   'and curly before april 2010',
#   'curly before april 2010 call',
#   'before april 2010 call me',
#   'april 2010 call me kinky',
#   '2010 call me kinky call',
#   'call me kinky call me',
#   'me kinky call me nappy',
#   'kinky call me nappy it',
#   'call me nappy it s',
#   'me nappy it s just',
#   'nappy it s just semantics',
#   'it s just semantics sigpic',
#   's just semantics sigpic sigpic',
#   'just semantics sigpic sigpic products',
#   'semantics sigpic sigpic products i',
#   'sigpic sigpic products i am',
#   'sigpic products i am currently',
#   'products i am currently loving',
#   'i am currently loving trader',
#   'am currently loving trader joe',
#   'currently loving trader joe s',
#   'loving trader joe s nourish',
#   'trader joe s nourish conditioner',
#   'joe s nourish conditioner anita',
#   's nourish conditioner anita grant',
#   'nourish conditioner anita grant rhassoul',
#   'conditioner anita grant rhassoul deep',
#   'anita grant rhassoul deep conditioner',
#   'grant rhassoul deep conditioner anita',
#   'rhassoul deep conditioner anita grant',
#   'deep conditioner anita grant cafe',
#   'conditioner anita grant cafe latte',
#   'anita grant cafe latte suave',
#   'grant cafe latte suave naturals',
#   'cafe latte suave naturals coconut',
#   'latte suave naturals coconut conditioner'],
#  ['public fotki com kaymoore combo',
#   'fotki com kaymoore combo with',
#   'com kaymoore combo with in',
#   'kaymoore combo with in the',
#   'combo with in the front',
#   'with in the front hair',
#   'in the front hair goal',
#   'the front hair goal shoulder',
#   'front hair goal shoulder length',
#   'hair goal shoulder length and',
#   'goal shoulder length and curly',
#   'shoulder length and curly before',
#   'length and curly before april',
#   'and curly before april 2010',
#   'curly before april 2010 call',
#   'before april 2010 call me',
#   'april 2010 call me kinky',
#   '2010 call me kinky call',
#   'call me kinky call me',
#   'me kinky call me nappy',
#   'kinky call me nappy it',
#   'call me nappy it s',
#   'me nappy it s just',
#   'nappy it s just semantics',
#   'it s just semantics sigpic',
#   's just semantics sigpic sigpic',
#   'just semantics sigpic sigpic products',
#   'semantics sigpic sigpic products i',
#   'sigpic sigpic products i am',
#   'sigpic products i am currently',
#   'products i am currently loving',
#   'i am currently loving trader',
#   'am currently loving trader joe',
#   'currently loving trader joe s',
#   'loving trader joe s nourish',
#   'trader joe s nourish conditioner',
#   'joe s nourish conditioner anita',
#   's nourish conditioner anita grant',
#   'nourish conditioner anita grant rhassoul',
#   'conditioner anita grant rhassoul deep',
#   'anita grant rhassoul deep conditioner',
#   'grant rhassoul deep conditioner anita',
#   'rhassoul deep conditioner anita grant',
#   'deep conditioner anita grant cafe',
#   'conditioner anita grant cafe latte',
#   'anita grant cafe latte suave',
#   'grant cafe latte suave naturals',
#   'cafe latte suave naturals coconut',
#   'latte suave naturals coconut conditioner'],
#  ['co wash suave naturals lavender',
#   'wash suave naturals lavender co',
#   'suave naturals lavender co rinse',
#   'naturals lavender co rinse nature',
#   'lavender co rinse nature s',
#   'co rinse nature s gate',
#   'rinse nature s gate pomegranate',
#   'nature s gate pomegranate and',
#   's gate pomegranate and sunflower',
#   'gate pomegranate and sunflower leave',
#   'pomegranate and sunflower leave in',
#   'and sunflower leave in suave',
#   'sunflower leave in suave naturals',
#   'leave in suave naturals lavender',
#   'in suave naturals lavender styling',
#   'suave naturals lavender styling fsg',
#   'naturals lavender styling fsg suave',
#   'lavender styling fsg suave sculpting',
#   'styling fsg suave sculpting gel',
#   'fsg suave sculpting gel aussie',
#   'suave sculpting gel aussie sprunch',
#   'sculpting gel aussie sprunch other',
#   'gel aussie sprunch other my',
#   'aussie sprunch other my hair',
#   'sprunch other my hair likes',
#   'other my hair likes honey',
#   'my hair likes honey and',
#   'hair likes honey and olive',
#   'likes honey and olive oil',
#   'honey and olive oil dts',
#   'and olive oil dts and',
#   'olive oil dts and sometimes',
#   'oil dts and sometimes i',
#   'dts and sometimes i use',
#   'and sometimes i use sulfate',
#   'sometimes i use sulfate free',
#   'i use sulfate free shampoo',
#   'use sulfate free shampoo sulfate',
#   'sulfate free shampoo sulfate free',
#   'free shampoo sulfate free since',
#   'shampoo sulfate free since 6',
#   'sulfate free since 6 1',
#   'free since 6 1 09'],
#  ['recovering from heat damaged almost',
#   'from heat damaged almost like',
#   'heat damaged almost like transitioning',
#   'damaged almost like transitioning because',
#   'almost like transitioning because most',
#   'like transitioning because most of',
#   'transitioning because most of my',
#   'because most of my hair',
#   'most of my hair is',
#   'of my hair is straight',
#   'my hair is straight it',
#   'hair is straight it won',
#   'is straight it won t',
#   'straight it won t curl',
#   'it won t curl thsi',
#   'won t curl thsi is',
#   't curl thsi is due',
#   'curl thsi is due to',
#   'thsi is due to sooo',
#   'is due to sooo many',
#   'due to sooo many years',
#   'to sooo many years of',
#   'sooo many years of using',
#   'many years of using heat',
#   'years of using heat without',
#   'of using heat without stoping',
#   'using heat without stoping braid',
#   'heat without stoping braid out',
#   'without stoping braid out and',
#   'stoping braid out and twist',
#   'braid out and twist out',
#   'out and twist out are',
#   'and twist out are my',
#   'twist out are my staple',
#   'out are my staple styles',
#   'are my staple styles right',
#   'my staple styles right now',
#   'staple styles right now not',
#   'styles right now not using',
#   'right now not using heat',
#   'now not using heat since',
#   'not using heat since december',
#   'using heat since december 2011',
#   'heat since december 2011 still',
#   'since december 2011 still experimenting',
#   'december 2011 still experimenting with',
#   '2011 still experimenting with products'],
#  ['recovering from heat damaged almost',
#   'from heat damaged almost like',
#   'heat damaged almost like transitioning',
#   'damaged almost like transitioning because',
#   'almost like transitioning because most',
#   'like transitioning because most of',
#   'transitioning because most of my',
#   'because most of my hair',
#   'most of my hair is',
#   'of my hair is straight',
#   'my hair is straight it',
#   'hair is straight it won',
#   'is straight it won t',
#   'straight it won t curl',
#   'it won t curl thsi',
#   'won t curl thsi is',
#   't curl thsi is due',
#   'curl thsi is due to',
#   'thsi is due to sooo',
#   'is due to sooo many',
#   'due to sooo many years',
#   'to sooo many years of',
#   'sooo many years of using',
#   'many years of using heat',
#   'years of using heat without',
#   'of using heat without stoping',
#   'using heat without stoping braid',
#   'heat without stoping braid out',
#   'without stoping braid out and',
#   'stoping braid out and twist',
#   'braid out and twist out',
#   'out and twist out are',
#   'and twist out are my',
#   'twist out are my staple',
#   'out are my staple styles',
#   'are my staple styles right',
#   'my staple styles right now',
#   'staple styles right now not',
#   'styles right now not using',
#   'right now not using heat',
#   'now not using heat since',
#   'not using heat since december',
#   'using heat since december 2011',
#   'heat since december 2011 still',
#   'since december 2011 still experimenting',
#   'december 2011 still experimenting with',
#   '2011 still experimenting with products'],
#  ['niiin photos public fotki com',
#   'photos public fotki com herfsthaar',
#   'public fotki com herfsthaar hair'],
#  ['niiin photos public fotki com',
#   'photos public fotki com herfsthaar',
#   'public fotki com herfsthaar hair'],
#  ['i seem to have quite',
#   'seem to have quite a',
#   'to have quite a large',
#   'have quite a large voluminous',
#   'quite a large voluminous blend',
#   'a large voluminous blend of',
#   'large voluminous blend of and',
#   'voluminous blend of and hair'],
#  ['i seem to have quite',
#   'seem to have quite a',
#   'to have quite a large',
#   'have quite a large voluminous',
#   'quite a large voluminous blend',
#   'a large voluminous blend of',
#   'large voluminous blend of and',
#   'voluminous blend of and hair'],
#  ['naturally curly hair new hairstyle',
#   'curly hair new hairstyle is',
#   'hair new hairstyle is now',
#   'new hairstyle is now a',
#   'hairstyle is now a modified',
#   'is now a modified stacked',
#   'now a modified stacked bob',
#   'a modified stacked bob hair',
#   'modified stacked bob hair now',
#   'stacked bob hair now colored',
#   'bob hair now colored with',
#   'hair now colored with redken',
#   'now colored with redken shades',
#   'colored with redken shades eq',
#   'with redken shades eq brownish',
#   'redken shades eq brownish coppery',
#   'shades eq brownish coppery color',
#   'eq brownish coppery color genius',
#   'brownish coppery color genius is',
#   'coppery color genius is 1',
#   'color genius is 1 inspiration',
#   'genius is 1 inspiration and',
#   'is 1 inspiration and 99',
#   '1 inspiration and 99 perspiration',
#   'inspiration and 99 perspiration thomas',
#   'and 99 perspiration thomas a',
#   '99 perspiration thomas a edison'],
#  ['hair all over date of',
#   'all over date of last',
#   'over date of last relaxer',
#   'date of last relaxer feb',
#   'of last relaxer feb 28',
#   'last relaxer feb 28 2009',
#   'relaxer feb 28 2009 gonappy',
#   'feb 28 2009 gonappy blogspot',
#   '28 2009 gonappy blogspot com'],
#  ['public fotki com jackiecoh 91908',
#   'fotki com jackiecoh 91908 pw',
#   'com jackiecoh 91908 pw curls',
#   'jackiecoh 91908 pw curls curls',
#   '91908 pw curls curls hair',
#   'pw curls curls hair deva',
#   'curls curls hair deva lowpoo',
#   'curls hair deva lowpoo deva',
#   'hair deva lowpoo deva angell',
#   'deva lowpoo deva angell img',
#   'lowpoo deva angell img file',
#   'deva angell img file prod',
#   'angell img file prod jcohen',
#   'img file prod jcohen my',
#   'file prod jcohen my 20documents',
#   'prod jcohen my 20documents my',
#   'jcohen my 20documents my 20pictures',
#   'my 20documents my 20pictures image',
#   '20documents my 20pictures image 133',
#   'my 20pictures image 133 jpg',
#   '20pictures image 133 jpg img'],
#  ['public fotki com jackiecoh 91908',
#   'fotki com jackiecoh 91908 pw',
#   'com jackiecoh 91908 pw curls',
#   'jackiecoh 91908 pw curls curls',
#   '91908 pw curls curls hair',
#   'pw curls curls hair deva',
#   'curls curls hair deva lowpoo',
#   'curls hair deva lowpoo deva',
#   'hair deva lowpoo deva angell',
#   'deva lowpoo deva angell img',
#   'lowpoo deva angell img file',
#   'deva angell img file prod',
#   'angell img file prod jcohen',
#   'img file prod jcohen my',
#   'file prod jcohen my 20documents',
#   'prod jcohen my 20documents my',
#   'jcohen my 20documents my 20pictures',
#   'my 20documents my 20pictures image',
#   '20documents my 20pictures image 133',
#   'my 20pictures image 133 jpg',
#   '20pictures image 133 jpg img'],
#  [],
#  ['text i k font going',
#   'i k font going back',
#   'k font going back and',
#   'font going back and forth',
#   'going back and forth between',
#   'back and forth between herbal',
#   'and forth between herbal essence',
#   'forth between herbal essence don',
#   'between herbal essence don t',
#   'herbal essence don t fade',
#   'essence don t fade on',
#   'don t fade on me',
#   't fade on me shampoo',
#   'fade on me shampoo and',
#   'on me shampoo and condish',
#   'me shampoo and condish and',
#   'shampoo and condish and l',
#   'and condish and l oreal',
#   'condish and l oreal sulfate',
#   'and l oreal sulfate free',
#   'l oreal sulfate free shampoo',
#   'oreal sulfate free shampoo stylers',
#   'sulfate free shampoo stylers not',
#   'free shampoo stylers not your',
#   'shampoo stylers not your mother',
#   'stylers not your mother s',
#   'not your mother s curl',
#   'your mother s curl cream',
#   'mother s curl cream la',
#   's curl cream la bella',
#   'curl cream la bella sports',
#   'cream la bella sports gel',
#   'la bella sports gel aussie',
#   'bella sports gel aussie sprunch',
#   'sports gel aussie sprunch spray',
#   'gel aussie sprunch spray color',
#   'aussie sprunch spray color font',
#   'sprunch spray color font my',
#   'spray color font my waves',
#   'color font my waves are',
#   'font my waves are finally',
#   'my waves are finally getting',
#   'waves are finally getting stronger',
#   'are finally getting stronger thanks',
#   'finally getting stronger thanks to',
#   'getting stronger thanks to weekly',
#   'stronger thanks to weekly pts',
#   'thanks to weekly pts and',
#   'to weekly pts and longer',
#   'weekly pts and longer hair',
#   'pts and longer hair in',
#   'and longer hair in general',
#   'longer hair in general still',
#   'hair in general still trying',
#   'in general still trying to',
#   'general still trying to grow',
#   'still trying to grow it',
#   'trying to grow it out',
#   'to grow it out though',
#   'grow it out though headbang',
#   'it out though headbang mod',
#   'out though headbang mod since',
#   'though headbang mod since december',
#   'headbang mod since december 10',
#   'mod since december 10 i',
#   'since december 10 i have',
#   'december 10 i have celiac',
#   '10 i have celiac s',
#   'i have celiac s disease',
#   'have celiac s disease so',
#   'celiac s disease so no',
#   's disease so no gluten',
#   'disease so no gluten please',
#   'so no gluten please my',
#   'no gluten please my hair',
#   'gluten please my hair is',
#   'please my hair is basically',
#   'my hair is basically my',
#   'hair is basically my hobby',
#   'is basically my hobby balancedbeauty',
#   'basically my hobby balancedbeauty blogspot',
#   'my hobby balancedbeauty blogspot com'],
#  ['just started this natural hair',
#   'started this natural hair journey',
#   'this natural hair journey have',
#   'natural hair journey have lots',
#   'hair journey have lots to',
#   'journey have lots to learn',
#   'have lots to learn what',
#   'lots to learn what i',
#   'to learn what i know',
#   'learn what i know k',
#   'what i know k i',
#   'i know k i know',
#   'know k i know so',
#   'k i know so far',
#   'i know so far mostly',
#   'know so far mostly w',
#   'so far mostly w some',
#   'far mostly w some high',
#   'mostly w some high hair',
#   'w some high hair seems',
#   'some high hair seems to',
#   'high hair seems to love',
#   'hair seems to love eco',
#   'seems to love eco styler',
#   'to love eco styler gel',
#   'love eco styler gel suave',
#   'eco styler gel suave tresseme',
#   'styler gel suave tresseme condish',
#   'gel suave tresseme condish protein',
#   'suave tresseme condish protein product',
#   'tresseme condish protein product junkie',
#   'condish protein product junkie in',
#   'protein product junkie in the',
#   'product junkie in the making',
#   'junkie in the making p'],
#  ['just started this natural hair',
#   'started this natural hair journey',
#   'this natural hair journey have',
#   'natural hair journey have lots',
#   'hair journey have lots to',
#   'journey have lots to learn',
#   'have lots to learn what',
#   'lots to learn what i',
#   'to learn what i know',
#   'learn what i know k',
#   'what i know k i',
#   'i know k i know',
#   'know k i know so',
#   'k i know so far',
#   'i know so far mostly',
#   'know so far mostly w',
#   'so far mostly w some',
#   'far mostly w some high',
#   'mostly w some high hair',
#   'w some high hair seems',
#   'some high hair seems to',
#   'high hair seems to love',
#   'hair seems to love eco',
#   'seems to love eco styler',
#   'to love eco styler gel',
#   'love eco styler gel suave',
#   'eco styler gel suave tresseme',
#   'styler gel suave tresseme condish',
#   'gel suave tresseme condish protein',
#   'suave tresseme condish protein product',
#   'tresseme condish protein product junkie',
#   'condish protein product junkie in',
#   'protein product junkie in the',
#   'product junkie in the making',
#   'junkie in the making p'],
#  ['jessie since june 30 2010',
#   'since june 30 2010 currently',
#   'june 30 2010 currently experimenting',
#   '30 2010 currently experimenting with',
#   '2010 currently experimenting with aohr',
#   'currently experimenting with aohr no',
#   'experimenting with aohr no poo',
#   'with aohr no poo and',
#   'aohr no poo and conditioner',
#   'no poo and conditioner ao',
#   'poo and conditioner ao blue',
#   'and conditioner ao blue green',
#   'conditioner ao blue green algae',
#   'ao blue green algae hair',
#   'blue green algae hair rescue',
#   'green algae hair rescue elucence',
#   'algae hair rescue elucence volume',
#   'hair rescue elucence volume designing',
#   'rescue elucence volume designing foam',
#   'elucence volume designing foam ag',
#   'volume designing foam ag re',
#   'designing foam ag re coil',
#   'foam ag re coil curl',
#   'ag re coil curl junkie',
#   're coil curl junkie curl',
#   'coil curl junkie curl fuel',
#   'curl junkie curl fuel curl',
#   'junkie curl fuel curl enhancing',
#   'curl fuel curl enhancing spray'],
#  ['jessie since june 30 2010',
#   'since june 30 2010 currently',
#   'june 30 2010 currently experimenting',
#   '30 2010 currently experimenting with',
#   '2010 currently experimenting with aohr',
#   'currently experimenting with aohr no',
#   'experimenting with aohr no poo',
#   'with aohr no poo and',
#   'aohr no poo and conditioner',
#   'no poo and conditioner ao',
#   'poo and conditioner ao blue',
#   'and conditioner ao blue green',
#   'conditioner ao blue green algae',
#   'ao blue green algae hair',
#   'blue green algae hair rescue',
#   'green algae hair rescue elucence',
#   'algae hair rescue elucence volume',
#   'hair rescue elucence volume designing',
#   'rescue elucence volume designing foam',
#   'elucence volume designing foam ag',
#   'volume designing foam ag re',
#   'designing foam ag re coil',
#   'foam ag re coil curl',
#   'ag re coil curl junkie',
#   're coil curl junkie curl',
#   'coil curl junkie curl fuel',
#   'curl junkie curl fuel curl',
#   'junkie curl fuel curl enhancing',
#   'curl fuel curl enhancing spray'],
#  ['with almost straight hair on',
#   'almost straight hair on top',
#   'straight hair on top c',
#   'hair on top c curls',
#   'on top c curls according',
#   'top c curls according to',
#   'c curls according to my',
#   'curls according to my stylist',
#   'according to my stylist modified',
#   'to my stylist modified looking',
#   'my stylist modified looking for',
#   'stylist modified looking for my',
#   'modified looking for my next',
#   'looking for my next low',
#   'for my next low no',
#   'my next low no poo',
#   'next low no poo curls',
#   'low no poo curls ccc',
#   'no poo curls ccc anyg',
#   'poo curls ccc anyg kbb',
#   'curls ccc anyg kbb acv',
#   'ccc anyg kbb acv and',
#   'anyg kbb acv and honey',
#   'kbb acv and honey or',
#   'acv and honey or molasses',
#   'and honey or molasses rinses',
#   'honey or molasses rinses cj',
#   'or molasses rinses cj h',
#   'molasses rinses cj h b',
#   'rinses cj h b deep',
#   'cj h b deep fix',
#   'h b deep fix styling',
#   'b deep fix styling with',
#   'deep fix styling with kccc',
#   'fix styling with kccc b',
#   'styling with kccc b a',
#   'with kccc b a gel',
#   'kccc b a gel fote',
#   'b a gel fote avg',
#   'a gel fote avg bb',
#   'gel fote avg bb s',
#   'fote avg bb s fsg',
#   'avg bb s fsg komaza',
#   'bb s fsg komaza chp'],
#  ['with almost straight hair on',
#   'almost straight hair on top',
#   'straight hair on top c',
#   'hair on top c curls',
#   'on top c curls according',
#   'top c curls according to',
#   'c curls according to my',
#   'curls according to my stylist',
#   'according to my stylist modified',
#   'to my stylist modified looking',
#   'my stylist modified looking for',
#   'stylist modified looking for my',
#   'modified looking for my next',
#   'looking for my next low',
#   'for my next low no',
#   'my next low no poo',
#   'next low no poo curls',
#   'low no poo curls ccc',
#   'no poo curls ccc anyg',
#   'poo curls ccc anyg kbb',
#   'curls ccc anyg kbb acv',
#   'ccc anyg kbb acv and',
#   'anyg kbb acv and honey',
#   'kbb acv and honey or',
#   'acv and honey or molasses',
#   'and honey or molasses rinses',
#   'honey or molasses rinses cj',
#   'or molasses rinses cj h',
#   'molasses rinses cj h b',
#   'rinses cj h b deep',
#   'cj h b deep fix',
#   'h b deep fix styling',
#   'b deep fix styling with',
#   'deep fix styling with kccc',
#   'fix styling with kccc b',
#   'styling with kccc b a',
#   'with kccc b a gel',
#   'kccc b a gel fote',
#   'b a gel fote avg',
#   'a gel fote avg bb',
#   'gel fote avg bb s',
#   'fote avg bb s fsg',
#   'avg bb s fsg komaza',
#   'bb s fsg komaza chp'],
#  ['b hair that fro s',
#   'hair that fro s more',
#   'that fro s more than',
#   'fro s more than curls',
#   's more than curls co',
#   'more than curls co wash',
#   'than curls co wash tressemme',
#   'curls co wash tressemme he',
#   'co wash tressemme he avon',
#   'wash tressemme he avon leave',
#   'tressemme he avon leave in',
#   'he avon leave in sm',
#   'avon leave in sm shea',
#   'leave in sm shea butter',
#   'in sm shea butter conditioner',
#   'sm shea butter conditioner smch',
#   'shea butter conditioner smch smoothie',
#   'butter conditioner smch smoothie deep',
#   'conditioner smch smoothie deep treat',
#   'smch smoothie deep treat avon',
#   'smoothie deep treat avon at',
#   'deep treat avon at masks',
#   'treat avon at masks henna',
#   'avon at masks henna amla',
#   'at masks henna amla avanti',
#   'masks henna amla avanti stylers',
#   'henna amla avanti stylers aloe',
#   'amla avanti stylers aloe vera',
#   'avanti stylers aloe vera butter',
#   'stylers aloe vera butter eco',
#   'aloe vera butter eco styler',
#   'vera butter eco styler on',
#   'butter eco styler on dry',
#   'eco styler on dry hair',
#   'styler on dry hair sm',
#   'on dry hair sm products',
#   'dry hair sm products my',
#   'hair sm products my fotki',
#   'sm products my fotki 1',
#   'products my fotki 1 22',
#   'my fotki 1 22 my',
#   'fotki 1 22 my twitter',
#   '1 22 my twitter my',
#   '22 my twitter my youtube'],
#  ['i k password hair public',
#   'k password hair public fotki',
#   'password hair public fotki com',
#   'hair public fotki com amandag',
#   'public fotki com amandag hair'],
#  ['i m down for anyg',
#   'm down for anyg that',
#   'down for anyg that s',
#   'for anyg that s natural',
#   'anyg that s natural none',
#   'that s natural none of',
#   's natural none of that',
#   'natural none of that paraben',
#   'none of that paraben ish',
#   'of that paraben ish lol',
#   'that paraben ish lol last',
#   'paraben ish lol last relaxer',
#   'ish lol last relaxer dec',
#   'lol last relaxer dec 18th',
#   'last relaxer dec 18th 2010',
#   'relaxer dec 18th 2010 big',
#   'dec 18th 2010 big chop',
#   '18th 2010 big chop 31st',
#   '2010 big chop 31st june',
#   'big chop 31st june 2011',
#   'chop 31st june 2011 hairtype',
#   '31st june 2011 hairtype i',
#   'june 2011 hairtype i can',
#   '2011 hairtype i can only',
#   'hairtype i can only select',
#   'i can only select one',
#   'can only select one but',
#   'only select one but i',
#   'select one but i m',
#   'one but i m a',
#   'but i m a and',
#   'i m a and as',
#   'm a and as my',
#   'a and as my hair',
#   'and as my hair got',
#   'as my hair got longer',
#   'my hair got longer i',
#   'hair got longer i discovered',
#   'got longer i discovered that',
#   'longer i discovered that the',
#   'i discovered that the middle',
#   'discovered that the middle of',
#   'that the middle of my',
#   'the middle of my hair',
#   'middle of my hair was',
#   'of my hair was more',
#   'my hair was more and',
#   'hair was more and the',
#   'was more and the outter',
#   'more and the outter was',
#   'and the outter was a',
#   'the outter was a mixture',
#   'outter was a mixture of',
#   'was a mixture of and',
#   'a mixture of and art',
#   'mixture of and art graphic',
#   'of and art graphic design',
#   'and art graphic design online',
#   'art graphic design online portfolio',
#   'graphic design online portfolio deviantart',
#   'design online portfolio deviantart page',
#   'online portfolio deviantart page health',
#   'portfolio deviantart page health beauty',
#   'deviantart page health beauty care',
#   'page health beauty care blog',
#   'health beauty care blog twitter',
#   'beauty care blog twitter irougelady'],
#  ['i m down for anyg',
#   'm down for anyg that',
#   'down for anyg that s',
#   'for anyg that s natural',
#   'anyg that s natural none',
#   'that s natural none of',
#   's natural none of that',
#   'natural none of that paraben',
#   'none of that paraben ish',
#   'of that paraben ish lol',
#   'that paraben ish lol last',
#   'paraben ish lol last relaxer',
#   'ish lol last relaxer dec',
#   'lol last relaxer dec 18th',
#   'last relaxer dec 18th 2010',
#   'relaxer dec 18th 2010 big',
#   'dec 18th 2010 big chop',
#   '18th 2010 big chop 31st',
#   '2010 big chop 31st june',
#   'big chop 31st june 2011',
#   'chop 31st june 2011 hairtype',
#   '31st june 2011 hairtype i',
#   'june 2011 hairtype i can',
#   '2011 hairtype i can only',
#   'hairtype i can only select',
#   'i can only select one',
#   'can only select one but',
#   'only select one but i',
#   'select one but i m',
#   'one but i m a',
#   'but i m a and',
#   'i m a and as',
#   'm a and as my',
#   'a and as my hair',
#   'and as my hair got',
#   'as my hair got longer',
#   'my hair got longer i',
#   'hair got longer i discovered',
#   'got longer i discovered that',
#   'longer i discovered that the',
#   'i discovered that the middle',
#   'discovered that the middle of',
#   'that the middle of my',
#   'the middle of my hair',
#   'middle of my hair was',
#   'of my hair was more',
# ...
#   'with coconut oil and avocado',
#   'coconut oil and avocado oil',
#   'oil and avocado oil once',
#   'and avocado oil once month'],
#  ['hair and absolutely love every',
#   'and absolutely love every minute',
#   'absolutely love every minute of',
#   'love every minute of it',
#   'every minute of it i',
#   'minute of it i ve',
#   'of it i ve gone',
#   'it i ve gone from',
#   'i ve gone from 1',
#   've gone from 1 inch',
#   'gone from 1 inch hair',
#   'from 1 inch hair to',
#   '1 inch hair to 30',
#   'inch hair to 30 inches',
#   'hair to 30 inches and',
#   'to 30 inches and everywhere',
#   '30 inches and everywhere in',
#   'inches and everywhere in between',
#   'and everywhere in between cyclops',
#   'everywhere in between cyclops conditioner',
#   'in between cyclops conditioner say',
#   'between cyclops conditioner say yes',
#   'cyclops conditioner say yes to',
#   'conditioner say yes to tomatoes',
#   'say yes to tomatoes leave',
#   'yes to tomatoes leave in',
#   'to tomatoes leave in conditioner',
#   'tomatoes leave in conditioner burt',
#   'leave in conditioner burt s',
#   'in conditioner burt s bees',
#   'conditioner burt s bees more',
#   'burt s bees more moisture',
#   's bees more moisture gel',
#   'bees more moisture gel l',
#   'more moisture gel l a',
#   'moisture gel l a looks',
#   'gel l a looks curl',
#   'l a looks curl last',
#   'a looks curl last relaxer',
#   'looks curl last relaxer june',
#   'curl last relaxer june 26',
#   'last relaxer june 26 2010',
#   'relaxer june 26 2010 big',
#   'june 26 2010 big chop',
#   '26 2010 big chop hair',
#   '2010 big chop hair cut',
#   'big chop hair cut july',
#   'chop hair cut july 29',
#   'hair cut july 29 2010'],
#  ['and since 07 01 08',
#   'since 07 01 08 my',
#   '07 01 08 my hair',
#   '01 08 my hair loves',
#   '08 my hair loves kccc',
#   'my hair loves kccc love7',
#   'hair loves kccc love7 nexxus',
#   'loves kccc love7 nexxus headress',
#   'kccc love7 nexxus headress weightless',
#   'love7 nexxus headress weightless leave',
#   'nexxus headress weightless leave in',
#   'headress weightless leave in he',
#   'weightless leave in he tt',
#   'leave in he tt loreal',
#   'in he tt loreal vive',
#   'he tt loreal vive pro',
#   'tt loreal vive pro nutri',
#   'loreal vive pro nutri gloss',
#   'vive pro nutri gloss for',
#   'pro nutri gloss for long',
#   'nutri gloss for long wavy',
#   'gloss for long wavy curly',
#   'for long wavy curly hair',
#   'long wavy curly hair my',
#   'wavy curly hair my hair',
#   'curly hair my hair hates',
#   'hair my hair hates magsulf',
#   'my hair hates magsulf jessicurl',
#   'hair hates magsulf jessicurl loob'],
#  ['and since 07 01 08',
#   'since 07 01 08 my',
#   '07 01 08 my hair',
#   '01 08 my hair loves',
#   '08 my hair loves kccc',
#   'my hair loves kccc love7',
#   'hair loves kccc love7 nexxus',
#   'loves kccc love7 nexxus headress',
#   'kccc love7 nexxus headress weightless',
#   'love7 nexxus headress weightless leave',
#   'nexxus headress weightless leave in',
#   'headress weightless leave in he',
#   'weightless leave in he tt',
#   'leave in he tt loreal',
#   'in he tt loreal vive',
#   'he tt loreal vive pro',
#   'tt loreal vive pro nutri',
#   'loreal vive pro nutri gloss',
#   'vive pro nutri gloss for',
#   'pro nutri gloss for long',
#   'nutri gloss for long wavy',
#   'gloss for long wavy curly',
#   'for long wavy curly hair',
#   'long wavy curly hair my',
#   'wavy curly hair my hair',
#   'curly hair my hair hates',
#   'hair my hair hates magsulf',
#   'my hair hates magsulf jessicurl',
#   'hair hates magsulf jessicurl loob'],
#  ['type actually not sure it',
#   'actually not sure it looks',
#   'not sure it looks c',
#   'sure it looks c but',
#   'it looks c but it',
#   'looks c but it has',
#   'c but it has some',
#   'but it has some very',
#   'it has some very straight',
#   'has some very straight hair',
#   'some very straight hair with',
#   'very straight hair with some',
#   'straight hair with some very',
#   'hair with some very kinky',
#   'with some very kinky curly',
#   'some very kinky curly coarse',
#   'very kinky curly coarse hair',
#   'kinky curly coarse hair and',
#   'curly coarse hair and ends',
#   'coarse hair and ends up',
#   'hair and ends up looking',
#   'and ends up looking since',
#   'ends up looking since october',
#   'up looking since october 2002',
#   'looking since october 2002 currently',
#   'since october 2002 currently using',
#   'october 2002 currently using bioterra',
#   '2002 currently using bioterra recondition',
#   'currently using bioterra recondition or',
#   'using bioterra recondition or lpvng',
#   'bioterra recondition or lpvng just',
#   'recondition or lpvng just made',
#   'or lpvng just made some',
#   'lpvng just made some homeade',
#   'just made some homeade fsg',
#   'made some homeade fsg and',
#   'some homeade fsg and love',
#   'homeade fsg and love it',
#   'fsg and love it have',
#   'and love it have used',
#   'love it have used jessicurl',
#   'it have used jessicurl deva',
#   'have used jessicurl deva products',
#   'used jessicurl deva products but',
#   'jessicurl deva products but am',
#   'deva products but am on',
#   'products but am on a',
#   'but am on a mission',
#   'am on a mission to',
#   'on a mission to care',
#   'a mission to care for',
#   'mission to care for my',
#   'to care for my hair',
#   'care for my hair in',
#   'for my hair in a',
#   'my hair in a budget',
#   'hair in a budget friendly',
#   'in a budget friendly way'],
#  ['type actually not sure it',
#   'actually not sure it looks',
#   'not sure it looks c',
#   'sure it looks c but',
#   'it looks c but it',
#   'looks c but it has',
#   'c but it has some',
#   'but it has some very',
#   'it has some very straight',
#   'has some very straight hair',
#   'some very straight hair with',
#   'very straight hair with some',
#   'straight hair with some very',
#   'hair with some very kinky',
#   'with some very kinky curly',
#   'some very kinky curly coarse',
#   'very kinky curly coarse hair',
#   'kinky curly coarse hair and',
#   'curly coarse hair and ends',
#   'coarse hair and ends up',
#   'hair and ends up looking',
#   'and ends up looking since',
#   'ends up looking since october',
#   'up looking since october 2002',
#   'looking since october 2002 currently',
#   'since october 2002 currently using',
#   'october 2002 currently using bioterra',
#   '2002 currently using bioterra recondition',
#   'currently using bioterra recondition or',
#   'using bioterra recondition or lpvng',
#   'bioterra recondition or lpvng just',
#   'recondition or lpvng just made',
#   'or lpvng just made some',
#   'lpvng just made some homeade',
#   'just made some homeade fsg',
#   'made some homeade fsg and',
#   'some homeade fsg and love',
#   'homeade fsg and love it',
#   'fsg and love it have',
#   'and love it have used',
#   'love it have used jessicurl',
#   'it have used jessicurl deva',
#   'have used jessicurl deva products',
#   'used jessicurl deva products but',
#   'jessicurl deva products but am',
#   'deva products but am on',
#   'products but am on a',
#   'but am on a mission',
#   'am on a mission to',
#   'on a mission to care',
#   'a mission to care for',
#   'mission to care for my',
#   'to care for my hair',
#   'care for my hair in',
#   'for my hair in a',
#   'my hair in a budget',
#   'hair in a budget friendly',
#   'in a budget friendly way'],
#  ['hair low elasticity according to',
#   'low elasticity according to curl',
#   'elasticity according to curl wizard'],
#  ['hair low elasticity according to',
#   'low elasticity according to curl',
#   'elasticity according to curl wizard'],
#  ['sigpic sigpic since june 12',
#   'sigpic since june 12 2009',
#   'since june 12 2009 type',
#   'june 12 2009 type and',
#   '12 2009 type and mix',
#   '2009 type and mix high',
#   'type and mix high on',
#   'and mix high on top',
#   'mix high on top uhg',
#   'high on top uhg in',
#   'on top uhg in back',
#   'top uhg in back co',
#   'uhg in back co wash',
#   'in back co wash eo',
#   'back co wash eo rosemary',
#   'co wash eo rosemary mint',
#   'wash eo rosemary mint suave',
#   'eo rosemary mint suave or',
#   'rosemary mint suave or jessicurl',
#   'mint suave or jessicurl cleansing',
#   'suave or jessicurl cleansing cream',
#   'or jessicurl cleansing cream leave',
#   'jessicurl cleansing cream leave in',
#   'cleansing cream leave in jessicurl',
#   'cream leave in jessicurl too',
#   'leave in jessicurl too shea',
#   'in jessicurl too shea or',
#   'jessicurl too shea or whatever',
#   'too shea or whatever i',
#   'shea or whatever i co',
#   'or whatever i co washed',
#   'whatever i co washed with',
#   'i co washed with styling',
#   'co washed with styling gel',
#   'washed with styling gel kccc',
#   'with styling gel kccc aussie',
#   'styling gel kccc aussie opposites',
#   'gel kccc aussie opposites attract',
#   'kccc aussie opposites attract spray',
#   'aussie opposites attract spray gel',
#   'opposites attract spray gel cj',
#   'attract spray gel cj smoog',
#   'spray gel cj smoog gelee',
#   'gel cj smoog gelee jessicurl',
#   'cj smoog gelee jessicurl rr',
#   'smoog gelee jessicurl rr and',
#   'gelee jessicurl rr and cc',
#   'jessicurl rr and cc technique',
#   'rr and cc technique clip',
#   'and cc technique clip and',
#   'cc technique clip and air',
#   'technique clip and air dry',
#   'clip and air dry hair',
#   'and air dry hair style',
#   'air dry hair style is',
#   'dry hair style is the',
#   'hair style is the final',
#   'style is the final tip',
#   'is the final tip off',
#   'the final tip off whether',
#   'final tip off whether or',
#   'tip off whether or not',
#   'off whether or not a',
#   'whether or not a woman',
#   'or not a woman really',
#   'not a woman really knows',
#   'a woman really knows herself',
#   'woman really knows herself hubert',
#   'really knows herself hubert de',
#   'knows herself hubert de givenchy'],
#  ['sigpic sigpic since june 12',
#   'sigpic since june 12 2009',
#   'since june 12 2009 type',
#   'june 12 2009 type and',
#   '12 2009 type and mix',
#   '2009 type and mix high',
#   'type and mix high on',
#   'and mix high on top',
#   'mix high on top uhg',
#   'high on top uhg in',
#   'on top uhg in back',
#   'top uhg in back co',
#   'uhg in back co wash',
#   'in back co wash eo',
#   'back co wash eo rosemary',
#   'co wash eo rosemary mint',
#   'wash eo rosemary mint suave',
#   'eo rosemary mint suave or',
#   'rosemary mint suave or jessicurl',
#   'mint suave or jessicurl cleansing',
#   'suave or jessicurl cleansing cream',
#   'or jessicurl cleansing cream leave',
#   'jessicurl cleansing cream leave in',
#   'cleansing cream leave in jessicurl',
#   'cream leave in jessicurl too',
#   'leave in jessicurl too shea',
#   'in jessicurl too shea or',
#   'jessicurl too shea or whatever',
#   'too shea or whatever i',
#   'shea or whatever i co',
#   'or whatever i co washed',
#   'whatever i co washed with',
#   'i co washed with styling',
#   'co washed with styling gel',
#   'washed with styling gel kccc',
#   'with styling gel kccc aussie',
#   'styling gel kccc aussie opposites',
#   'gel kccc aussie opposites attract',
#   'kccc aussie opposites attract spray',
#   'aussie opposites attract spray gel',
#   'opposites attract spray gel cj',
#   'attract spray gel cj smoog',
#   'spray gel cj smoog gelee',
#   'gel cj smoog gelee jessicurl',
#   'cj smoog gelee jessicurl rr',
#   'smoog gelee jessicurl rr and',
#   'gelee jessicurl rr and cc',
#   'jessicurl rr and cc technique',
#   'rr and cc technique clip',
#   'and cc technique clip and',
#   'cc technique clip and air',
#   'technique clip and air dry',
#   'clip and air dry hair',
#   'and air dry hair style',
#   'air dry hair style is',
#   'dry hair style is the',
#   'hair style is the final',
#   'style is the final tip',
#   'is the final tip off',
#   'the final tip off whether',
#   'final tip off whether or',
#   'tip off whether or not',
#   'off whether or not a',
#   'whether or not a woman',
#   'or not a woman really',
#   'not a woman really knows',
#   'a woman really knows herself',
#   'woman really knows herself hubert',
#   'really knows herself hubert de',
#   'knows herself hubert de givenchy'],
#  ['suze trying to succeed with',
#   'trying to succeed with growing',
#   'to succeed with growing healthy',
#   'succeed with growing healthy hair',
#   'with growing healthy hair with',
#   'growing healthy hair with safer',
#   'healthy hair with safer products',
#   'hair with safer products highly',
#   'with safer products highly porous',
#   'safer products highly porous fragile',
#   'products highly porous fragile hair',
#   'highly porous fragile hair partially',
#   'porous fragile hair partially resolved',
#   'fragile hair partially resolved w',
#   'hair partially resolved w henna',
#   'partially resolved w henna not',
#   'resolved w henna not just',
#   'w henna not just whatever',
#   'henna not just whatever works',
#   'not just whatever works hair',
#   'just whatever works hair type',
#   'whatever works hair type mixed',
#   'works hair type mixed product',
#   'hair type mixed product brands',
#   'type mixed product brands kinky',
#   'mixed product brands kinky curly',
#   'product brands kinky curly camille',
#   'brands kinky curly camille rose',
#   'kinky curly camille rose oyin',
#   'curly camille rose oyin hairobics',
#   'camille rose oyin hairobics giovanni',
#   'rose oyin hairobics giovanni aubrey',
#   'oyin hairobics giovanni aubrey organics'],
#  ['suze trying to succeed with',
#   'trying to succeed with growing',
#   'to succeed with growing healthy',
#   'succeed with growing healthy hair',
#   'with growing healthy hair with',
#   'growing healthy hair with safer',
#   'healthy hair with safer products',
#   'hair with safer products highly',
#   'with safer products highly porous',
#   'safer products highly porous fragile',
#   'products highly porous fragile hair',
#   'highly porous fragile hair partially',
#   'porous fragile hair partially resolved',
#   'fragile hair partially resolved w',
#   'hair partially resolved w henna',
#   'partially resolved w henna not',
#   'resolved w henna not just',
#   'w henna not just whatever',
#   'henna not just whatever works',
#   'not just whatever works hair',
#   'just whatever works hair type',
#   'whatever works hair type mixed',
#   'works hair type mixed product',
#   'hair type mixed product brands',
#   'type mixed product brands kinky',
#   'mixed product brands kinky curly',
#   'product brands kinky curly camille',
#   'brands kinky curly camille rose',
#   'kinky curly camille rose oyin',
#   'curly camille rose oyin hairobics',
#   'camille rose oyin hairobics giovanni',
#   'rose oyin hairobics giovanni aubrey',
#   'oyin hairobics giovanni aubrey organics'],
#  ['sigpic sigpic hair type yet',
#   'sigpic hair type yet crazy',
#   'hair type yet crazy huge',
#   'type yet crazy huge normal',
#   'yet crazy huge normal elasticity',
#   'crazy huge normal elasticity normal',
#   'huge normal elasticity normal i',
#   'normal elasticity normal i k',
#   'elasticity normal i k oily',
#   'normal i k oily scalp',
#   'i k oily scalp low',
#   'k oily scalp low poos',
#   'oily scalp low poos cj',
#   'scalp low poos cj daily',
#   'low poos cj daily fix',
#   'poos cj daily fix ao',
#   'cj daily fix ao green',
#   'daily fix ao green tea',
#   'fix ao green tea clarifying',
#   'ao green tea clarifying co',
#   'green tea clarifying co washing',
#   'tea clarifying co washing tresemme',
#   'clarifying co washing tresemme naturals',
#   'co washing tresemme naturals conditioner',
#   'washing tresemme naturals conditioner conditioner',
#   'tresemme naturals conditioner conditioner as',
#   'naturals conditioner conditioner as needed',
#   'conditioner conditioner as needed styling',
#   'conditioner as needed styling fsg',
#   'as needed styling fsg kccc',
#   'needed styling fsg kccc winter',
#   'styling fsg kccc winter favorite',
#   'fsg kccc winter favorite cj',
#   'kccc winter favorite cj curl',
#   'winter favorite cj curl fix',
#   'favorite cj curl fix cj',
#   'cj curl fix cj coffee',
#   'curl fix cj coffee coco',
#   'fix cj coffee coco curl',
#   'cj coffee coco curl cream',
#   'coffee coco curl cream lite',
#   'coco curl cream lite bsrhg',
#   'curl cream lite bsrhg a',
#   'cream lite bsrhg a must',
#   'lite bsrhg a must current',
#   'bsrhg a must current obsession',
#   'a must current obsession tresemme',
#   'must current obsession tresemme naturals',
#   'current obsession tresemme naturals moisturizing',
#   'obsession tresemme naturals moisturizing conditioner'],
#  ...]

# %%
result[0][2]
# Out:
# 'nopoo co wash suave naturals'

# %%
# look and see whats coming up the most

quadgram_list_of_lists = [generate_ngrams(x, 4) for x in relevant_products_column_df['products']]

quadragrams = []
for single_list in quadgram_list_of_lists:
    for x in single_list:
        quadragrams.append(x)
        
quadragram_df = pd.DataFrame({'quadragrams': quadragrams})
test = dict(quadragram_df.quadragrams.value_counts())
test
# Out:
# {'co wash suave naturals': 86,
#  'kinky curly knot today': 57,
#  'wash suave naturals coconut': 46,
#  'giovanni direct leave in': 40,
#  'kinky curly curling custard': 36,
#  'herbal essences totally twisted': 35,
#  'suave naturals tropical coconut': 32,
#  'la looks sport gel': 31,
#  'giovanni smooth as silk': 27,
#  'shea moisture curl enhancing': 26,
#  'but lots of it': 24,
#  'my hair loves protein': 23,
#  'trying to figure out': 22,
#  'moisture curl enhancing smoothie': 22,
#  'rinse out leave in': 21,
#  'as i am coconut': 21,
#  'leave in suave naturals': 21,
#  'leave in giovanni direct': 21,
#  'hair type i k': 20,
#  'still trying to figure': 19,
#  'curls in a bottle': 18,
#  'trader joe s tea': 18,
#  'of the curly crusaders': 18,
#  'trader joe s nourish': 18,
#  'hair solutions curl keeper': 18,
#  'order of the curly': 18,
#  'leave in kinky curly': 18,
#  'joe s tea tree': 18,
#  'suave naturals coconut conditioner': 18,
#  'in kinky curly knot': 17,
#  'curly hair solutions curl': 17,
#  'wash as i am': 17,
#  'co wash tresemme naturals': 17,
#  'tresemme naturals nourishing moisture': 17,
#  'devacurl heaven in hair': 17,
#  'essences set me up': 16,
#  'co wash leave in': 16,
#  'co wash as i': 16,
#  'i k my hair': 16,
#  'garnier fructis pure clean': 16,
#  'herbal essences set me': 16,
#  'co wash suave coconut': 16,
#  'aubrey organics honeysuckle rose': 15,
#  'hair type co wash': 15,
#  'poo giovanni 50 50': 15,
#  'knot today leave in': 15,
#  'i am coconut cowash': 15,
#  'la looks sports gel': 15,
#  'leave in shea moisture': 14,
#  'garnier fructis sleek and': 14,
#  'fotki public fotki com': 14,
#  'set me up gel': 14,
#  'on a good day': 14,
#  'conditioning balm leave in': 14,
#  'shea moisture coconut hibiscus': 14,
#  'the order of the': 14,
#  'kinky curly come clean': 14,
#  'low poo giovanni 50': 14,
#  'trying to grow out': 13,
#  'in the order of': 13,
#  'low poo co wash': 13,
#  'herbal essences hello hydration': 13,
#  'curl junkie repair me': 13,
#  'low poo shea moisture': 13,
#  's tea tree tingle': 13,
#  'garnier fructis triple nutrition': 12,
#  'hair but lots of': 12,
#  'l oreal evercreme cleansing': 12,
#  'oreal evercreme cleansing conditioner': 12,
#  'in giovanni direct leave': 12,
#  'sigpic sigpic hair type': 12,
#  'fructis sleek and shine': 12,
#  'aussie 3 minute miracle': 12,
#  'hair type with a': 12,
#  'to grow my hair': 12,
#  'gvp conditioning balm styling': 12,
#  'wash suave tropical coconut': 11,
#  'eco styler olive oil': 11,
#  'mixed chicks leave in': 11,
#  'joe s nourish spa': 11,
#  'gvp conditioning balm leave': 11,
#  'i am curling jelly': 11,
#  'suave naturals coconut condish': 11,
#  'devacurl set it free': 11,
#  'i love my hair': 11,
#  'shea butter leave in': 11,
#  'as i am curling': 11,
#  'no poo co wash': 11,
#  'co wash suave tropical': 11,
#  'k my hair is': 10,
#  'sm curl enhancing smoothie': 10,
#  'burt s bees super': 10,
#  'to love my hair': 10,
#  'coffee coco curl creme': 10,
#  'the curly girl method': 10,
#  'leave in garnier fructis': 10,
#  'biosilk rock hard gelee': 10,
#  'in suave naturals coconut': 10,
#  'with a bit of': 10,
#  'shea moisture strengthen restore': 10,
#  'and shine leave in': 10,
#  'cowash suave naturals coconut': 10,
#  'co wash tresseme naturals': 10,
#  'deva curl no poo': 10,
#  'learning to love my': 10,
#  'low poo l oreal': 10,
#  'my hair loves honey': 10,
#  's bees super shiny': 10,
#  'curly knot today styler': 10,
#  'font font quot font': 10,
#  'poo devacurl no poo': 10,
#  'to grow it out': 10,
#  'shea moisture curl style': 9,
#  'as i am cleansing': 9,
#  'hair type normal elasticity': 9,
#  'trying to grow it': 9,
#  'suave naturals coconut rinse': 9,
#  'leave in herbal essences': 9,
#  'hair polisher styling gel': 9,
#  'smooth as silk conditioner': 9,
#  'hibiscus curl and shine': 9,
#  'co wash l oreal': 9,
#  'vive pro nutri gloss': 9,
#  'deva b leave in': 9,
#  'jane carter nourish shine': 9,
#  'conditioner and leave in': 9,
#  'growing out my hair': 9,
#  'curly knot today leave': 9,
#  'essences totally twisted gel': 8,
#  '\xa0 \xa0 \xa0 \xa0': 8,
#  'shea moisture manuka honey': 8,
#  'leave in tresemme naturals': 8,
#  'leave in gvp conditioning': 8,
#  'poo once a week': 8,
#  'la looks mega mega': 8,
#  'tea tree triple treat': 8,
#  'moisture coconut and hibiscus': 8,
#  'wash devacurl no poo': 8,
#  'conditioner kinky curly knot': 8,
#  'pt ion effective care': 8,
#  'a little bit of': 8,
#  'tea tree oils protein': 8,
#  'conditioner as i am': 8,
#  'devacurl b leave in': 8,
#  'curl junkie daily fix': 8,
#  'and lots of it': 8,
#  'i k co wash': 8,
#  'as i am co': 8,
#  'suave coconut rinse out': 8,
#  'conditioner for curly hair': 8,
#  'gel la looks sport': 8,
#  'naturals coconut rinse out': 8,
#  'suave naturals coconut or': 8,
#  'nature s gate aloe': 8,
#  'totally twisted curl scrunching': 8,
#  'baobab tea tree oils': 8,
#  'dew point co wash': 8,
#  'in gvp conditioning balm': 8,
#  'essences totally twisted conditioner': 8,
#  'once a week leave': 8,
#  'shea moisture coconut and': 8,
#  'giovanni tea tree triple': 8,
#  'conditioner devacurl one condition': 8,
#  'conditioner burt s bees': 8,
#  'essences totally twisted curl': 8,
#  'trying to find a': 8,
#  'conditioner aubrey organics honeysuckle': 8,
#  'twisted curl scrunching gel': 8,
#  'shampoo once a week': 8,
#  'all over the place': 8,
#  'i am not this': 8,
#  'wash suave naturals tropical': 8,
#  'still looking for the': 8,
#  'a week leave in': 8,
#  'to know my hair': 8,
#  'l oreal vive pro': 8,
#  'font quot cj font': 8,
#  'leave in curl junkie': 8,
#  'curl and style milk': 8,
#  'john frieda frizz ease': 8,
#  'looking for a good': 8,
#  'co wash devacurl no': 8,
#  'once in a while': 8,
#  'suave naturals rinse out': 8,
#  'pure clean styling gel': 7,
#  'tousle me softly mousse': 7,
#  'as i am leave': 7,
#  'out gvp conditioning balm': 7,
#  'channel youtube com user': 7,
#  'darcy s botanicals pumpkin': 7,
#  'wash deva no poo': 7,
#  'low poo live clean': 7,
#  'hair type low poo': 7,
#  'no poo devacurl no': 7,
#  'carol s daughter tui': 7,
#  'shampoo co wash suave': 7,
#  'cleansing conditioner for curly': 7,
#  'gf pure clean gel': 7,
#  'coconut and hibiscus curl': 7,
#  'rinse out gvp conditioning': 7,
#  'boots pink curl creme': 7,
#  'fructis pure clean styling': 7,
#  'sm curl style milk': 7,
#  'biotera curl creme and': 7,
#  'tresemme naturals leave in': 7,
#  'elasta qp mango butter': 7,
#  'vo5 vanilla mint tea': 7,
#  'co wash garnier fructis': 7,
#  'gel herbal essences totally': 7,
#  'wash and leave in': 7,
#  'shea moisture deep treatment': 7,
#  'l oreal sulfate free': 7,
#  'wash nature s gate': 7,
#  'sheamoisture coconut hibiscus curl': 7,
#  'kiss my face whenever': 7,
#  'sigpic sigpic last relaxer': 7,
#  'fantasia ic hair polisher': 7,
#  'still searching for my': 7,
#  'for second day hair': 7,
#  'my hair doesn t': 7,
#  'cj curls in a': 7,
#  'co wash and leave': 7,
#  'still trying to find': 7,
#  'naturals tropical coconut conditioner': 7,
#  'conditioner garnier fructis sleek': 7,
#  'grow my hair out': 7,
#  'type co wash suave': 7,
#  'i am leave in': 7,
#  'leave in conditioner and': 7,
#  'moisture deep treatment masque': 7,
#  'shea moisture moisture retention': 7,
#  'i am cleansing pudding': 7,
#  'giovanni 50 50 co': 7,
#  'hair type last relaxer': 7,
#  'coconut hibiscus curl enhancing': 7,
#  'co wash with suave': 7,
#  'youtube channel youtube com': 7,
#  'can t get enough': 7,
#  'ro gvp conditioning balm': 7,
#  'shea butter moisture retention': 7,
#  'as a leave in': 7,
#  'coco curl creme lite': 7,
#  'i am co wash': 7,
#  'naturals nourishing moisture conditioner': 7,
#  'i k i have': 7,
#  'ecostyler olive oil gel': 7,
#  'garnier fructis sleek shine': 7,
#  'a mix of and': 7,
#  'bella lots of curls': 6,
#  'chs curl keeper kccc': 6,
#  'devacurl ultra defining gel': 6,
#  'pantene curl defining mousse': 6,
#  'biolage conditioning balm styling': 6,
#  'i am coconut co': 6,
#  '50 50 balanced hydrating': 6,
#  'and hibiscus curl and': 6,
#  'condish\xa0 kccc curlsmith souffl': 6,
#  'souffl ufdcm mga sculpting': 6,
#  'in canada hot summers': 6,
#  'a little mixed in': 6,
#  'rinse out suave naturals': 6,
#  'li kinky curly knot': 6,
#  'pt cj repair me': 6,
#  'coconut oil castor oil': 6,
#  'coconut oil and jojoba': 6,
#  'dry dry as i': 6,
#  'this skin i am': 6,
#  'a week co wash': 6,
#  'wash cj daily fix': 6,
#  'and kinky curly curling': 6,
#  'curlsmith cowash lhdc condish\xa0': 6,
#  'to have hair so': 6,
#  'biolage cleansing conditioner for': 6,
#  'on a mission to': 6,
#  'repear towel then diffuse': 6,
#  'conditioner styling products la': 6,
#  'low poo giovanni ttt': 6,
#  'my hair is so': 6,
#  'with low poo co': 6,
#  'lhdc condish\xa0 kccc curlsmith': 6,
#  'and my hair is': 6,
#  'with hair repear towel': 6,
#  'hot summers freezing winters': 6,
#  'my goal is to': 6,
#  'conditioner suave naturals coconut': 6,
#  'condish curlsmith cowash lhdc': 6,
#  'jessicurl too shea conditioner': 6,
#  'co wash nature s': 6,
#  't wait to see': 6,
#  'can t wait to': 6,
#  'curl junkie pattern pusha': 6,
#  '50 50 co wash': 6,
#  'coarse live in canada': 6,
#  'shoulder length when curly': 6,
#  'live in canada hot': 6,
#  'raw shea butter moisture': 6,
#  'am not this skin': 6,
#  'poo co wash suave': 6,
#  'gvp conditioning balm stylers': 6,
#  'coconut oil shea butter': 6,
#  'i love my curls': 6,
#  'sleek and shine leave': 6,
#  'my hair is a': 6,
#  'my hair hates protein': 6,
#  'apl bsl mbl wl': 6,
#  'aveda be curly curl': 6,
#  'hair type mixture of': 6,
#  'not this skin i': 6,
#  'with some in the': 6,
#  'mga sculpting gel\xa0 scrunch': 6,
#  'tj nourishing spa cond': 6,
#  'if i m a': 6,
#  'herbal essence set me': 6,
#  'hair type currently using': 6,
#  'to figure out and': 6,
#  'inecto pure coconut oil': 6,
#  'one condition leave in': 6,
#  'herbal essence totally twisted': 6,
#  'coconut hibiscus curl and': 6,
#  'hair type with some': 6,
#  'hair type current length': 6,
#  'pre poo coconut oil': 6,
#  'devacurl no poo one': 6,
#  'some in the back': 6,
#  'kccc curlsmith souffl ufdcm': 6,
#  'the rest of my': 6,
#  'my hair is low': 6,
#  'curlsmith souffl ufdcm mga': 6,
#  'low poo yes to': 6,
#  'still searching for hg': 6,
#  'i m a pj': 6,
#  'jessicurl too shea or': 6,
#  'my hair back to': 6,
#  'dry dry dry as': 6,
#  'am cleansing pudding soultanicals': 6,
#  'today leave in conditioner': 6,
#  'current products co wash': 6,
#  'shampoo conditioner shea moisture': 6,
#  'canada hot summers freezing': 6,
#  'pudding soultanicals deep condish': 6,
#  'soultanicals deep condish curlsmith': 6,
#  'dt devacurl heaven in': 6,
#  'cowash lhdc condish\xa0 kccc': 6,
#  'carol s daughter hair': 6,
#  'extra virgin olive oil': 6,
#  'giovanni 50 50 balanced': 6,
#  'hair goal shoulder length': 6,
#  'is not my first': 6,
#  'tree oils protein free': 6,
#  'oil and jojoba oil': 6,
#  'shampoo giovanni tea tree': 6,
#  'type co wash tresemme': 6,
#  'botanicals pumpkin seed moisturizing': 6,
#  'curls rock curl amplifier': 6,
#  'wash suave naturals or': 6,
#  'products i am currently': 6,
#  'k i m a': 6,
#  'winters dry dry dry': 6,
#  'ic hair polisher styling': 6,
#  'getting to know my': 6,
#  'mainly coarse live in': 6,
#  'a lot of it': 6,
#  'towel then diffuse or': 6,
#  'kc come clean co': 6,
#  'summers freezing winters dry': 6,
#  'giovanni leave in conditioner': 6,
#  'moisture curl style milk': 6,
#  'conditioner jessicurl too shea': 6,
#  'cleansing pudding soultanicals deep': 6,
#  'pumpkin seed moisturizing conditioner': 6,
#  'nature s gate herbal': 6,
#  'condish gvp conditioning balm': 6,
#  's botanicals pumpkin seed': 6,
#  'tea tree tingle shampoo': 6,
#  'gel kinky curly curling': 6,
#  'hair lots of it': 6,
#  'ufdcm mga sculpting gel\xa0': 6,
#  'pro nutri gloss for': 6,
#  'sculpting gel\xa0 scrunch with': 6,
#  'poo kc come clean': 6,
#  'freezing winters dry dry': 6,
#  'my hair type is': 6,
#  'burt s bees more': 6,
#  'or air protein cnpf': 6,
#  'figure out my hair': 6,
#  'growing out a pixie': 6,
#  's bees more moisture': 6,
#  'la bella lots of': 6,
#  'hair and lots of': 6,
#  'conditioner giovanni direct leave': 6,
#  'cleansers cj daily fix': 6,
#  'i don t know': 6,
#  'hair repear towel then': 6,
#  'every week or so': 6,
#  'hair type on top': 6,
#  'jojoba oil coconut oil': 6,
#  'hair type mix of': 6,
#  'products devacurl no poo': 6,
#  'scrunch with hair repear': 6,
#  'my hair loves the': 6,
#  'set up and above': 6,
#  'weighs my hair down': 6,
#  'youtube com watch v': 6,
#  'nature s gate jojoba': 6,
#  'hold shine moisture mist': 6,
#  'garnier sleek and shine': 6,
#  'leave in kckt styling': 6,
#  'diffuse or air protein': 6,
#  'deep condish curlsmith cowash': 6,
#  'type on a good': 6,
#  'jessicurl gentle lather shampoo': 6,
#  'with the help of': 6,
#  'no poo one condition': 6,
#  'matrix biolage cleansing conditioner': 6,
#  'yes to cucumbers color': 6,
#  'then diffuse or air': 6,
#  'gel\xa0 scrunch with hair': 6,
#  'dry as i am': 6,
#  'i k i m': 6,
#  'products vo5 moisture milks': 5,
#  'to find a routine': 5,
#  'curly knot today and': 5,
#  'suave naturals coconut and': 5,
#  'works for my hair': 5,
#  'naturals coconut leave in': 5,
#  'to figure out what': 5,
#  'leave in mixed chicks': 5,
#  'shea moisture curl shine': 5,
#  'gel l a looks': 5,
#  'for a few months': 5,
#  'moisture coconut hibiscus curl': 5,
#  'suave tropical coconut conditioner': 5,
#  'shampoo kinky curly come': 5,
#  'out trader joe s': 5,
#  's nourish spa conditioner': 5,
#  'font quot hair type': 5,
#  'firm hold styling gel': 5,
#  'length trying to grow': 5,
#  'wash l oreal ever': 5,
#  'the earth aloe vera': 5,
#  'natural all my life': 5,
#  'paul mitchell sculpting foam': 5,
#  'stylers ag re coil': 5,
#  'gel la looks mega': 5,
#  'acv rinse co wash': 5,
#  'he tousle me softly': 5,
#  'wash l oreal evercreme': 5,
#  'once a week or': 5,
#  'to care for my': 5,
#  'sm raw shea butter': 5,
#  'edensity bodyworks coconut shea': 5,
#  'poo once a month': 5,
#  'take care of my': 5,
#  'hair public fotki com': 5,
#  'once every week or': 5,
#  'lots and lots of': 5,
#  'hair and normal elasticity': 5,
#  'co wash v05 moisture': 5,
#  'hair likes coconut oil': 5,
#  'junkie curls in a': 5,
#  'styler olive oil gel': 5,
#  'suave naturals coconut leave': 5,
#  'flickr com photos email\xa0protected': 5,
#  'la looks extreme sport': 5,
#  'of the earth aloe': 5,
#  'fote aloe vera gel': 5,
#  'dr bronner s peppermint': 5,
#  'wash v05 moisture milks': 5,
#  'coconut oil olive oil': 5,
#  'for 2nd day hair': 5,
#  'sm coconut hibiscus curl': 5,
#  'poo cj daily fix': 5,
#  'garnier pure clean gel': 5,
#  'i can get my': 5,
#  'hates coconut oil and': 5,
#  's daughter hair milk': 5,
#  'been natural all my': 5,
#  'elasticity my hair loves': 5,
#  'be curly curl enhancer': 5,
#  'naturals silicone free conditioner': 5,
#  'pantene relaxed and natural': 5,
#  'jessicurl rr and cc': 5,
#  'hair past shoulder length': 5,
#  'my hair seems to': 5,
#  'my hair has a': 5,
#  'depending on the day': 5,
#  'curl junkie curl assurance': 5,
#  'shea moisture leave in': 5,
#  'co wash tj s': 5,
#  'miss jessie s jelly': 5,
#  'curl assurance leave in': 5,
#  'i m currently using': 5,
#  'low poo elucence moisture': 5,
#  'care of my hair': 5,
#  'i k i am': 5,
#  'condish matrix conditioning balm': 5,
#  'trader joes tea tree': 5,
#  's gelatin treatment my': 5,
#  'paul mitchell super skinny': 5,
#  'trying to grow my': 5,
#  'suave naturals ocean breeze': 5,
#  'l oreal ever pure': 5,
#  'wash suave coconut rinse': 5,
#  'a work in progress': 5,
#  'currently using devacurl low': 5,
#  'the middle of my': 5,
#  'jessie s jelly soft': 5,
#  '2nd 3rd day hair': 5,
#  'life isn t about': 5,
#  'dt heaven in hair': 5,
#  'l a looks sport': 5,
#  'butter moisture retention shampoo': 5,
#  'frizz free volumizing foam': 5,
#  'once or twice a': 5,
#  'to figure out my': 5,
#  'with aloe vera gel': 5,
#  'hair hates coconut oil': 5,
#  'for wavy curly hair': 5,
#  'ro li tresemme naturals': 5,
#  'in need of a': 5,
#  'conditioner herbal essences hello': 5,
#  'queen helene royal curl': 5,
#  'album public fotki com': 5,
#  'curl shine co wash': 5,
#  'gf curl spray gel': 5,
#  'fruit of the earth': 5,
#  'to learn how to': 5,
#  'fructis triple nutrition conditioner': 5,
#  'in the front and': 5,
#  'devacurl light defining gel': 5,
#  'essence set me up': 5,
#  's gate tea tree': 5,
#  'curl booster fixative gel': 5,
#  'sl apl bsl mbl': 5,
#  'what if i m': 5,
#  'as a co wash': 5,
#  'still figuring this out': 5,
#  'hair last relaxer 10': 5,
#  'wen sweet almond mint': 5,
#  'products co wash suave': 5,
#  'generic biolage conditioning balm': 5,
#  'leave in beautiful curls': 5,
#  'jane carter solution nourish': 5,
#  'sm coconut and hibiscus': 5,
#  'coconut oil leave in': 5,
#  'currently using low poo': 5,
#  'style jessicurl gelebration spray': 5,
#  'looks extreme sport gel': 5,
#  'looking for a new': 5,
#  'and trying to figure': 5,
#  'curl junkie curl rehab': 5,
#  'darcy botanicals pumpkin seed': 5,
#  'curl junkie curls in': 5,
#  'he set me up': 5,
#  'herbal essences body envy': 5,
#  'gelatin treatment my hair': 5,
#  'and set it free': 5,
#  'am coconut co wash': 5,
#  'l oreal out of': 5,
#  'every 3 4 days': 5,
#  'angel and set it': 5,
#  'cj daily fix or': 5,
#  'garnier fructis curl shaping': 5,
#  'pics public fotki com': 5,
#  'current routine co wash': 5,
#  'shea moisture restorative conditioner': 5,
#  'homemade sea salt spray': 5,
#  'knot today shea moisture': 5,
#  'nature s gate tea': 5,
#  'co wash ro li': 5,
#  'ecstasy hair tea condish': 5,
#  'paul mitchell round trip': 5,
#  'curl shaping spray gel': 5,
#  'nexxus humectress leave in': 5,
#  'conditioner tresemme naturals nourishing': 5,
#  's jelly soft curls': 5,
#  'leave in tresseme naturals': 5,
#  'l oreal melting gel': 5,
#  'but a lot of': 5,
#  'looking for my hg': 5,
#  'for a new one': 5,
#  'skin i am not': 5,
#  'length my hair loves': 5,
#  'suave naturals coconut co': 5,
#  'aussie tizz no frizz': 5,
#  'love my curly hair': 5,
#  'manuka honey mafura oil': 5,
#  'in the back and': 5,
#  'condition jessicurl too shea': 5,
#  'a week or so': 5,
#  'cowash nature s gate': 5,
#  'mitchell super skinny serum': 5,
#  'aubrey organics island naturals': 5,
#  'what i m doing': 5,
#  'using devacurl low poo': 5,
#  'as i am cowash': 5,
#  'wash with suave coconut': 5,
#  'healthy sexy hair pumpkin': 5,
#  'a month co wash': 5,
#  'deva curl low poo': 5,
#  'out suave naturals coconut': 5,
#  'a gift from god': 5,
#  'what my hair likes': 5,
#  'oreal out of bed': 5,
#  'once a week with': 5,
#  'once a month or': 5,
#  'so far so good': 5,
#  'analysis co wash as': 4,
#  'fi 5 29 09': 4,
#  'deep conditioner anita grant': 4,
#  'li curl enhancer chs': 4,
#  'all residue removed to': 4,
#  'keeper kccc gel alba': 4,
#  'stylers shea moisture curl': 4,
#  'clear scalp hair therapy': 4,
#  'in vo5 conditioner half': 4,
#  'carol s daughter black': 4,
#  'moosture curl shine biolage': 4,
#  'creme lite font quot': 4,
#  'short haircut wash jessicurl': 4,
#  'l oreal pro vive': 4,
#  'experimenting with lots of': 4,
#  'for who i am': 4,
#  'knot today styler ag': 4,
#  'of and wash recently': 4,
#  'd rather wear jewels': 4,
#  'co wash vo5 conditioner': 4,
#  'a woman really knows': 4,
#  'beautiful curls leave in': 4,
#  'dime nickle size of': 4,
#  'africa s best herbal': 4,
#  'devacurl oc li cj': 4,
#  'and very frizz prone': 4,
#  'shampoo and ihm g': 4,
#  'evoo to sm masque': 4,
#  'cj cccc lite ciab': 4,
#  'using bioterra kmf in': 4,
#  'lightly scrunched on the': 4,
#  'botanicals pumpkin seed conditioner': 4,
#  'jojoba oil sometimes photobucket': 4,
#  'fsg aif brhg lals': 4,
#  'condish thank you nc': 4,
#  'shampoo jane carter solution': 4,
#  'curly hair font quot': 4,
#  'clear 100 protein free': 4,
#  'leave in style with': 4,
#  'coconut oil as a': 4,
#  'shampoo devacurl no poo': 4,
#  'bodyworks peppermint tea tree': 4,
#  'climate control heat humidity': 4,
#  'bbb cj sheam hehis': 4,
#  'little in the back': 4,
#  'i m growing it': 4,
#  'tn li smr cure': 4,
#  'tree tingle shampoo co': 4,
#  'that doesn t like': 4,
#  'gvpcb pt gelatin cnpf': 4,
#  'cj sheam hehis garnier': 4,
#  'shealoe cd chocolat oyin': 4,
#  'i want to try': 4,
#  'gel l oreal studio': 4,
#  'semantics sigpic sigpic products': 4,
#  'quot cj pattern pusha': 4,
#  'cd chocolat oyin hh': 4,
#  'and ihm g kinkier': 4,
#  'no poo one conditioner': 4,
#  'pw crazycurls youtube channel': 4,
#  'no idea where 1969': 4,
#  'water shampoo avoiding glycerin': 4,
#  'happy hair cleanse cjdf': 4,
#  'nml elasticity routine no': 4,
#  'public fotki com honey04': 4,
#  'rules quench as i': 4,
#  'hair since october 2012': 4,
#  'curl ecstasy hair tea': 4,
#  'hydrolyzed my hair hates': 4,
#  'y enebro once a': 4,
#  'sm souffle smoothie loob': 4,
#  'yes to cucumbers daily': 4,
#  'leave in conditioning cream': 4,
#  'since 2006 no idea': 4,
#  'recoil i have eliminated': 4,
#  'fotki com kaymoore combo': 4,
#  'i k hair type': 4,
#  '2 23 10 mix': 4,
#  'followed by acv rinse': 4,
#  'week scalp only rinse': 4,
#  'dt honey acv evoo': 4,
#  'gelebration spray awe inspiraling': 4,
#  'or font quot cj': 4,
#  '29 09 my hair': 4,
#  'since february 5 2010': 4,
#  'lemon aide want to': 4,
#  'curly type co wash': 4,
#  'still new to all': 4,
#  'coconut oil and honey': 4,
#  'tip off whether or': 4,
#  'of my hair is': 4,
#  'rather wear jewels in': 4,
#  'hold mousse caprice rizos': 4,
#  'far need to update': 4,
#  'mjssb huge pjjjjjjjj love4': 4,
#  'a dime nickle size': 4,
#  'jessicurl products yet but': 4,
#  'giovanni sas clarifying mix': 4,
#  'shampoo avoiding glycerin in': 4,
#  'conditioner f font quot': 4,
#  'love10 leave in giovanni': 4,
#  'update no pics with': 4,
#  'hibiscus hold shine moisture': 4,
#  'co wash and conditioner': 4,
#  'sheamoisture baobab tea tree': 4,
#  'perfect dew point co': 4,
#  'and at crown bangs': 4,
#  'type mixture of and': 4,
#  'in kc knot today': 4,
#  'type updated on june': 4,
#  'herself hubert de givenchy': 4,
#  'de aloe y enebro': 4,
#  'lite font quot font': 4,
#  'earth aloe vera gel': 4,
#  'in font quot cj': 4,
#  'thyroid normal and elasticity': 4,
#  'suave tropical coconut condish': 4,
#  'idea where 1969 came': 4,
#  'products yet but i': 4,
#  'latte suave naturals coconut': 4,
#  'angell set it free': 4,
#  'finally i found a': 4,
#  'with the jessicurl products': 4,
#  'control heat humidity gel': 4,
#  'kinky call me nappy': 4,
#  'the way it is': 4,
#  'wash jessicurl cleansing cream': 4,
#  'shampoo conditioner ouidad cq': 4,
#  'com kaymoore combo with': 4,
#  'hair when there is': 4,
#  'moisture conditioner co wash': 4,
#  'gate poo condish thank': 4,
#  'quot spring and fall': 4,
#  'gel deep treatments love': 4,
#  'li l oreal eversleek': 4,
#  'sulfate and silicone free': 4,
#  'so far need to': 4,
#  'from toothy10 font quot': 4,
#  'with some co wash': 4,
#  'light hold mousse caprice': 4,
#  'humidity a dime nickle': 4,
#  'owning a ferrari but': 4,
#  'needs all residue removed': 4,
#  'or not a woman': 4,
#  's body beautiful hair': 4,
#  '09 public fotki com': 4,
#  '5 2010 cat hair': 4,
#  'conditioner nature s gate': 4,
#  'quot cj font coffee': 4,
#  'organic care sul free': 4,
#  'wash suave naturals conditioner': 4,
#  'in font matrix biolage': 4,
#  'bobeam li ro bbb': 4,
#  'today styler ag recoil': 4,
#  '47 straight hair until': 4,
#  'up aussie tizz no': 4,
#  'one n only argan': 4,
#  'high dew point co': 4,
#  'font quot cj pattern': 4,
#  'font quot d font': 4,
#  'out what my hair': 4,
#  'loreal ever sleek once': 4,
#  'curl rehab leave in': 4,
#  'combo with in the': 4,
#  'tingle shampoo co wash': 4,
#  'ss fhg cjpp trying': 4,
#  'hair community type html': 4,
#  'naturals leave in sm': 4,
#  'long hair community type': 4,
#  'leave in sm curl': 4,
#  'font quot w font': 4,
#  'half conditioner gel vo5': 4,
#  '2012 hair type shampoo': 4,
#  'current products low poo': 4,
#  'low poo no poo': 4,
#  'color protect condition devacurl': 4,
#  'not my hair i': 4,
#  'low poo once in': 4,
#  'hair font font quot': 4,
#  'i am not my': 4,
#  'add in font quot': 4,
#  'vo5 conditioner two times': 4,
#  'mo or jojoba dt': 4,
#  'frizz be gone shea': 4,
#  'need to update no': 4,
#  'if there isnt currently': 4,
#  'no poo and conditioner': 4,
#  'gel tresemme bouncy curls': 4,
#  'free moptop detangler refresher': 4,
#  'some highlighted nml elasticity': 4,
#  'sm curl and style': 4,
#  'tresseme naturals silicone free': 4,
#  'long botticelli hair when': 4,
#  'the jessicurl products yet': 4,
#  'protect condition devacurl oc': 4,
#  'hair tea condish leave': 4,
#  'the final tip off': 4,
#  'when in need of': 4,
#  'chocolat oyin hh styling': 4,
#  'is in the hair': 4,
#  'smoothie loob oils mo': 4,
#  'kinkier mousse re coil': 4,
#  'smooth n shine curl': 4,
#  'poo dr bronner s': 4,
#  'keratin smr giovanni sas': 4,
#  'point add in font': 4,
#  'hair with some on': 4,
#  'co wash gvp conditioning': 4,
#  'top wavy underneath co': 4,
#  'moisturizing shampoo co wash': 4,
#  'hair type updated on': 4,
#  'sensitive forms of wheat': 4,
#  'i m a in': 4,
#  'poo condish thank you': 4,
#  'cj daily fix conditioners': 4,
#  'tons of volume and': 4,
#  'leave in deva curl': 4,
#  'font beauticurls strengthening hair': 4,
#  'leave in kc knot': 4,
#  'wash giovanni tea tree': 4,
#  'camille rose curl maker': 4,
#  'length a little past': 4,
#  'to sm masque gvpcb': 4,
#  'loves protein currently using': 4,
#  'and i can t': 4,
#  'hair until 6 2010': 4,
#  'type f m ii': 4,
#  'shoulder length and curly': 4,
#  'length heading for waist': 4,
#  'co wash devacurl one': 4,
#  'hair loves protein currently': 4,
#  'hair i am not': 4,
#  'for long wavy curly': 4,
#  'am currently loving trader': 4,
#  's nourish spa leave': 4,
#  'products for my hair': 4,
#  'out of bed texturizer': 4,
#  'hair cleansers cj daily': 4,
#  'castor and sweet almond': 4,
#  'shea butter coconut oil': 4,
#  'ro gvpcb ion eff': 4,
#  'type with some highlighted': 4,
#  'co wash suave nats': 4,
#  '2012 big chop october': 4,
#  'public fotki com kaymoore': 4,
#  'and wash recently changed': 4,
#  'with some at the': 4,
#  'li ro bbb cj': 4,
#  'dr bronner s organic': 4,
#  'am not my hair': 4,
#  'heaven in hair ouidad': 4,
#  'no pics with the': 4,
#  's coconut oil formula': 4,
#  'shampoo conditioner sm coconut': 4,
#  'very hair low poo': 4,
#  'any volume conditioner kinky': 4,
#  'leave in vo5 conditioner': 4,
#  'and curly before april': 4,
#  'grant rhassoul deep conditioner': 4,
#  'vida mascarilla hidratante de': 4,
#  'sport gel coconut oil': 4,
#  'curly knot today styling': 4,
#  'com 85mr2 pics of': 4,
#  'you want to see': 4,
#  'conditioner ouidad cq s': 4,
#  'devacurl no poo or': 4,
#  'everyg but agrecoil my': 4,
#  'pure coconut oil condish': 4,
#  'i am double butter': 4,
#  'cat hair type on': 4,
#  'protein currently using dermorganics': 4,
#  'vmm anyg spiral solutions': 4,
#  'thank you nc for': 4,
#  'hair has tons of': 4,
#  'aif brhg lals ps': 4,
#  'v05 passion fruit smoothie': 4,
#  'enhancer chs curl keeper': 4,
#  'font inter low dew': 4,
#  'of demulcents order of': 4,
#  'to update no pics': 4,
#  'natural hair type updated': 4,
#  'cjpp trying maybe ecostyler': 4,
#  're coil curl junkie': 4,
#  'pow loreal ever sleek': 4,
#  'v05 kiwi clarifying conditioner': 4,
#  'way that doesn t': 4,
#  'to cucumbers daily makeover': 4,
#  'a baby boomer\xa0youtu be': 4,
#  'shampoo every 3 4': 4,
#  'devacurl set up and': 4,
#  'v05 strawberries and cream': 4,
#  'quot font ouidad climate': 4,
#  'normal elasticity low poo': 4,
#  'to take care of': 4,
#  'pantene pro v curls': 4,
#  'before april 2010 call': 4,
#  'sm masque gvpcb pt': 4,
#  'wash recently changed to': 4,
#  'of volume and bounce': 4,
#  'y vida mascarilla hidratante': 4,
#  'how many times you': 4,
#  'the second time since': 4,
#  'aussie moist leave in': 4,
#  'pattern pusha font curl': 4,
#  'since october 2012 love5': 4,
#  'quot w font inter': 4,
#  'youtube com user teshonandfamily': 4,
#  'sleek and shine anti': 4,
#  'products trader joe s': 4,
#  'healthy natural hair type': 4,
#  'to grow out a': 4,
#  'a couple of years': 4,
#  'some c mixed in': 4,
#  'once a week co': 4,
#  'poo co wash devacurl': 4,
#  'i am a product': 4,
#  'olive oil shea butter': 4,
#  'herbal essence body envy': 4,
#  'sheam hehis garnier kbn': 4,
#  'hair rules quench as': 4,
#  'point co wash leave': 4,
#  'co wash sauve coconut': 4,
#  'free n clear 100': 4,
#  'to get any volume': 4,
#  'fall perfect dew point': 4,
#  'font coffee coco curl': 4,
#  's daughter black vanilla': 4,
#  'elsewhere i like protein': 4,
#  'deva heaven in hair': 4,
#  'care tn li smr': 4,
#  'generic value products conditioning': 4,
#  'com teshon pw crazycurls': 4,
#  'april 2010 call me': 4,
#  'co wash sauve naturals': 4,
#  'oreal vive pro nutri': 4,
#  'k i have hair': 4,
#  'dt bbb cj lather': 4,
#  'smooth as silk deep': 4,
#  'quench as i am': 4,
#  'want to try ky': 4,
#  'my natural hair journey': 4,
#  'light brown with blonde': 4,
#  'goobah caedran aqueous infusion': 4,
#  '23 10 mix and': 4,
#  'protein sensitive forms of': 4,
#  'styling fsg aif brhg': 4,
#  'a short haircut wash': 4,
#  'my curly hair and': 4,
#  'goal shoulder length and': 4,
#  'i can t wait': 4,
#  'coconut conditioner ro tresseme': 4,
#  'spray awe inspiraling spray': 4,
#  'essence frizz be gone': 4,
#  'front hair goal shoulder': 4,
#  'wheat keratin soy and': 4,
#  'still working on it': 4,
#  'gel coconut oil honey': 4,
#  'as silk deep moisture': 4,
#  'month hard water shampoo': 4,
#  'my first relaxer at': 4,
#  'trying maybe ecostyler cjrm': 4,
#  'to cucumbers color protection': 4,
#  'my hair loves oil': 4,
#  'ps gf curl spray': 4,
#  'cowash vo5 moisture milks': 4,
#  'hair conditioner f font': 4,
#  'a little in the': 4,
#  'faith in nature aloe': 4,
#  'no poo daily conditioner': 4,
#  'renpure keratin smr giovanni': 4,
#  'leave in giovanni smooth': 4,
#  'balanced hydrating calming conditioner': 4,
#  'long term transitioner hair': 4,
#  'anita grant cafe latte': 4,
#  'summer natures gate poo': 4,
#  'hehis garnier kbn shealoe': 4,
#  'week or so condition': 4,
#  'coconut hibiscus hold shine': 4,
#  'leave in giovanni leave': 4,
#  'gel brhg hugo naturals': 4,
#  'forms of wheat keratin': 4,
#  'ro bbb cj sheam': 4,
#  'brhg hugo naturals gel': 4,
#  'i love it my': 4,
#  'no rules just happy': 4,
#  'wash font quot leave': 4,
#  '2006 no idea where': 4,
#  'gel alba strong hold': 4,
#  'loving trader joe s': 4,
#  'on the sides and': 4,
#  'shampoo kc come clean': 4,
#  'gel still working on': 4,
#  'on june 14 2006': 4,
#  ...}

# %%
def fix_acronymns(product_string, n):
    '''
    product_string -  a string of potential products and other texts
    n - number to set the ngram too
    '''
    for i in range(n_min,n_max):
    
        ngram_strings = generate_ngrams(product_string, i)
        len_product_ngrams = len(ngram_strings)

        for x in range(len_product_ngrams):
        
            for official_product in product_list:   

                #ratio = fuzz.partial_ratio(ngram_strings[x], official_product)
                ratio = fuzz.token_set_ratio(ngram_strings[x], official_product)
                if ratio >= 98:
                    official_product_list.append(official_product)
                    ratio_list.append(ratio)
                #else:
                    #print(f'{ngram_strings[x]} and {official_product} had a ratio of {ratio}')
    
    return (official_product_list +ratio_list)

# %%
fix_acronymns(relevant_products_column_df.products[0], 4)
# Out:
# ['poo deva nopoo co',
#  'deva nopoo co wash',
#  'nopoo co wash suave',
#  'co wash suave naturals',
#  'wash suave naturals rinse',
#  'suave naturals rinse out',
#  'naturals rinse out leave',
#  'rinse out leave in',
#  'out leave in deva',
#  'leave in deva one',
#  'in deva one condition',
#  'deva one condition products',
#  'one condition products deva',
#  'condition products deva arcangell',
#  'products deva arcangell deva',
#  'deva arcangell deva mister',
#  'arcangell deva mister right',
#  'deva mister right c',
#  'mister right c overly',
#  'right c overly porous',
#  'c overly porous hair']

# %% [markdown]
# ### Find the products and extract them

# %%
def find_products(product_string, product_list, n_max=6, n_min=1):
    '''
    product_string -  a string of potential products and other texts
    product_list - a list with each element being an official product
    n - number to set the max ngram too
    '''
    official_product_list = []
    ratio_list = []
    for i in range(n_min,n_max):
    
        ngram_strings = generate_ngrams(product_string, i)
        len_product_ngrams = len(ngram_strings)

        for x in range(len_product_ngrams):
        
            for official_product in product_list:   

                #ratio = fuzz.partial_ratio(ngram_strings[x], official_product)
                ratio = fuzz.token_set_ratio(ngram_strings[x], official_product)
                if ratio >= 93 and ratio <= 99:
                    official_product_list.append(official_product)
                    ratio_list.append(ratio)
                #else:
                    #print(f'{ngram_strings[x]} and {official_product} had a ratio of {ratio}')
    
    return (official_product_list +ratio_list)

# %%
find_products(relevant_products_column_df.products[9], clean_no_acronymn_fix_products, n_max=5, n_min=2)
# Out:
# ['living proof perfect hair day phd 5in1 styling treatment',
#  'living proof no frizz nourishing styling ',
#  'living proof perfect hair day heat styling ',
#  'living proof no frizz weightless styling ',
#  'living proof travel size perfect hair day phd 5in1 styling treatment',
#  93,
#  93,
#  93,
#  93,
#  93]

# %%
relevant_products_column_df.products[9]
# Out:
# ' very hair low poo living proof restore shampoo rinse out living proof restore conditioner leave in living proof curl leave in or garnier 1 minute mask papaya treatments restore repair leave in \xa0 styling \xa0living proof in shower styler with ouidad advanced climate control gel stronger hold'

# %%
# Make sure to get rid of travel stuff
